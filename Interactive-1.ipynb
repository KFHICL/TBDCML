# %% [markdown]
# Connected to Python 3.12.7

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:27
#      25 import seaborn as sns
#      26 os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
# ---> 27 import tf_keras as keras # Legacy keras version which is equal to the one on the HPC
#
# ModuleNotFoundError: No module named 'tf_keras'

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC
# Out:
# WARNING:tensorflow:From c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
os.path.curdir
# Out:
# '.'

# %%
os.path.curdir()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.path.curdir()
#
# TypeError: 'str' object is not callable

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.getcwd()
# Out:
# 'c:\\Users\\kfh23\\OneDrive - Imperial College London\\KFH23_GENERAL\\PROJECTS\\20241029_MSc_Paper\\Code\\TBDCML'

# %%
os.path.join(os.getcwd(),'sweep_definition_test.csv')
# Out:
# 'c:\\Users\\kfh23\\OneDrive - Imperial College London\\KFH23_GENERAL\\PROJECTS\\20241029_MSc_Paper\\Code\\TBDCML\\sweep_definition_test.csv'

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))

# %%
sweep_params
# Out:
#    Index  trainValRatio  batchSize  layer1Kernel conv1Activation  pooling  \
# 0      1            0.9          8             3            silu        1
#
#    dropout  layer2  layer2Kernel conv2Activation  ...  skipConnections  \
# 0     0.15       1             3            silu  ...                1
#
#    dsAugmentation standardisation     loss  ActivationUp epsilon  Dataset  \
# 0               1        Standard  Custom5             1   0.001    LFC18
#
#    MC24_Features Epochs  type
# 0            All   1000   NaN
#
# [1 rows x 38 columns]

# %%
os.pardie
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 os.pardie
#
# AttributeError: module 'os' has no attribute 'pardie'

# %%
os.pardir
# Out:
# '..'

# %%
print(os.path.abspath(os.path.join(os.getcwd(), os.pardir)))
# Out:
# c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code

# %%
os.listdir('\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain')
# Out:
#   Cell In[13], line 1
#     os.listdir('\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain')
#                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 24-25: truncated \uXXXX escape

# %%
os.listdir(r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain')
# Out:
# ['20241017_1550_224_4kSamples',
#  'Gaudron2018',
#  'MatLabModel2024',
#  'MatLabModel2024_1000',
#  'MatLabModel2024_100SamplesVfConstant',
#  'MatLabModel2024_100SamplesVfVariable',
#  'MatLabModel2024_200',
#  'MatLabModel2024_500',
#  'MatLabModel2024_OLD_102Specimens']

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = '\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'
trainDat_path = os.path.join(trainDat_path,'Gaudron2018')
# Out:
#   Cell In[16], line 1
#     trainDat_path = '\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'
#                     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 24-25: truncated \uXXXX escape

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'
trainDat_path = os.path.join(trainDat_path,'Gaudron2018')

# %%
trainDat_path
# Out:
# '\\\\rds.imperial.ac.uk\\rds\\user\\kfh23\\home\\IndividualProject\\CNNTraining\\datain\\Gaudron2018'

# %%
os.listdir(trainDat_path)
# Out:
# ['Unnotched_TBDC_2022_0.csv',
#  'Unnotched_TBDC_2022_1.csv',
#  'Unnotched_TBDC_2022_10.csv',
#  'Unnotched_TBDC_2022_11.csv',
#  'Unnotched_TBDC_2022_12.csv',
#  'Unnotched_TBDC_2022_13.csv',
#  'Unnotched_TBDC_2022_14.csv',
#  'Unnotched_TBDC_2022_15.csv',
#  'Unnotched_TBDC_2022_16.csv',
#  'Unnotched_TBDC_2022_17.csv',
#  'Unnotched_TBDC_2022_18.csv',
#  'Unnotched_TBDC_2022_19.csv',
#  'Unnotched_TBDC_2022_2.csv',
#  'Unnotched_TBDC_2022_20.csv',
#  'Unnotched_TBDC_2022_21.csv',
#  'Unnotched_TBDC_2022_22.csv',
#  'Unnotched_TBDC_2022_23.csv',
#  'Unnotched_TBDC_2022_24.csv',
#  'Unnotched_TBDC_2022_25.csv',
#  'Unnotched_TBDC_2022_26.csv',
#  'Unnotched_TBDC_2022_27.csv',
#  'Unnotched_TBDC_2022_28.csv',
#  'Unnotched_TBDC_2022_29.csv',
#  'Unnotched_TBDC_2022_3.csv',
#  'Unnotched_TBDC_2022_30.csv',
#  'Unnotched_TBDC_2022_31.csv',
#  'Unnotched_TBDC_2022_32.csv',
#  'Unnotched_TBDC_2022_33.csv',
#  'Unnotched_TBDC_2022_34.csv',
#  'Unnotched_TBDC_2022_35.csv',
#  'Unnotched_TBDC_2022_36.csv',
#  'Unnotched_TBDC_2022_37.csv',
#  'Unnotched_TBDC_2022_38.csv',
#  'Unnotched_TBDC_2022_39.csv',
#  'Unnotched_TBDC_2022_4.csv',
#  'Unnotched_TBDC_2022_40.csv',
#  'Unnotched_TBDC_2022_41.csv',
#  'Unnotched_TBDC_2022_42.csv',
#  'Unnotched_TBDC_2022_43.csv',
#  'Unnotched_TBDC_2022_44.csv',
#  'Unnotched_TBDC_2022_45.csv',
#  'Unnotched_TBDC_2022_46.csv',
#  'Unnotched_TBDC_2022_47.csv',
#  'Unnotched_TBDC_2022_48.csv',
#  'Unnotched_TBDC_2022_49.csv',
#  'Unnotched_TBDC_2022_5.csv',
#  'Unnotched_TBDC_2022_50.csv',
#  'Unnotched_TBDC_2022_51.csv',
#  'Unnotched_TBDC_2022_52.csv',
#  'Unnotched_TBDC_2022_53.csv',
#  'Unnotched_TBDC_2022_54.csv',
#  'Unnotched_TBDC_2022_55.csv',
#  'Unnotched_TBDC_2022_56.csv',
#  'Unnotched_TBDC_2022_57.csv',
#  'Unnotched_TBDC_2022_58.csv',
#  'Unnotched_TBDC_2022_59.csv',
#  'Unnotched_TBDC_2022_6.csv',
#  'Unnotched_TBDC_2022_60.csv',
#  'Unnotched_TBDC_2022_61.csv',
#  'Unnotched_TBDC_2022_62.csv',
#  'Unnotched_TBDC_2022_63.csv',
#  'Unnotched_TBDC_2022_64.csv',
#  'Unnotched_TBDC_2022_65.csv',
#  'Unnotched_TBDC_2022_66.csv',
#  'Unnotched_TBDC_2022_67.csv',
#  'Unnotched_TBDC_2022_68.csv',
#  'Unnotched_TBDC_2022_69.csv',
#  'Unnotched_TBDC_2022_7.csv',
#  'Unnotched_TBDC_2022_70.csv',
#  'Unnotched_TBDC_2022_71.csv',
#  'Unnotched_TBDC_2022_72.csv',
#  'Unnotched_TBDC_2022_73.csv',
#  'Unnotched_TBDC_2022_74.csv',
#  'Unnotched_TBDC_2022_75.csv',
#  'Unnotched_TBDC_2022_76.csv',
#  'Unnotched_TBDC_2022_77.csv',
#  'Unnotched_TBDC_2022_78.csv',
#  'Unnotched_TBDC_2022_79.csv',
#  'Unnotched_TBDC_2022_8.csv',
#  'Unnotched_TBDC_2022_80.csv',
#  'Unnotched_TBDC_2022_81.csv',
#  'Unnotched_TBDC_2022_82.csv',
#  'Unnotched_TBDC_2022_83.csv',
#  'Unnotched_TBDC_2022_84.csv',
#  'Unnotched_TBDC_2022_85.csv',
#  'Unnotched_TBDC_2022_86.csv',
#  'Unnotched_TBDC_2022_87.csv',
#  'Unnotched_TBDC_2022_88.csv',
#  'Unnotched_TBDC_2022_89.csv',
#  'Unnotched_TBDC_2022_9.csv',
#  'Unnotched_TBDC_2022_90.csv',
#  'Unnotched_TBDC_2022_91.csv',
#  'Unnotched_TBDC_2022_92.csv',
#  'Unnotched_TBDC_2022_93.csv',
#  'Unnotched_TBDC_2022_94.csv',
#  'Unnotched_TBDC_2022_95.csv',
#  'Unnotched_TBDC_2022_96.csv',
#  'Unnotched_TBDC_2022_97.csv',
#  'Unnotched_TBDC_2022_98.csv',
#  'Unnotched_TBDC_2022_99.csv']

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features



# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path)) # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)




def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    sample = pd.read_csv(path)
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
            samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples))

    samples_array = np.array(samples_list)
    return headers_list, samples_array

# headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



for i,file in enumerate(os.listdir(trainDat_path)):
    print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
    filepath = os.path.join(trainDat_path,file)
    if i==0:
        headers, samples = loadSample(filepath)
        samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
    else:
        addSamp = loadSample(filepath)[1]
        samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 0 out of 100
# Now loading file number 1 out of 100
# Now loading file number 2 out of 100
# Now loading file number 3 out of 100
# Now loading file number 4 out of 100
# Now loading file number 5 out of 100
# Now loading file number 6 out of 100
# Now loading file number 7 out of 100
# Now loading file number 8 out of 100
# Now loading file number 9 out of 100
# Now loading file number 10 out of 100
# Now loading file number 11 out of 100
# Now loading file number 12 out of 100
# Now loading file number 13 out of 100
# Now loading file number 14 out of 100
# Now loading file number 15 out of 100
# Now loading file number 16 out of 100
# Now loading file number 17 out of 100
# Now loading file number 18 out of 100
# Now loading file number 19 out of 100
# Now loading file number 20 out of 100
# Now loading file number 21 out of 100
# Now loading file number 22 out of 100
# Now loading file number 23 out of 100
# Now loading file number 24 out of 100
# Now loading file number 25 out of 100
# Now loading file number 26 out of 100
# Now loading file number 27 out of 100
# Now loading file number 28 out of 100
# Now loading file number 29 out of 100
# Now loading file number 30 out of 100
# Now loading file number 31 out of 100
# Now loading file number 32 out of 100
# Now loading file number 33 out of 100
# Now loading file number 34 out of 100
# Now loading file number 35 out of 100
# Now loading file number 36 out of 100
# Now loading file number 37 out of 100
# Now loading file number 38 out of 100
# Now loading file number 39 out of 100
# Now loading file number 40 out of 100
# Now loading file number 41 out of 100
# Now loading file number 42 out of 100
# Now loading file number 43 out of 100
# Now loading file number 44 out of 100
# Now loading file number 45 out of 100
# Now loading file number 46 out of 100
# Now loading file number 47 out of 100
# Now loading file number 48 out of 100
# Now loading file number 49 out of 100
# Now loading file number 50 out of 100
# Now loading file number 51 out of 100
# Now loading file number 52 out of 100
# Now loading file number 53 out of 100
# Now loading file number 54 out of 100
# Now loading file number 55 out of 100
# Now loading file number 56 out of 100
# Now loading file number 57 out of 100
# Now loading file number 58 out of 100
# Now loading file number 59 out of 100
# Now loading file number 60 out of 100
# Now loading file number 61 out of 100
# Now loading file number 62 out of 100
# Now loading file number 63 out of 100
# Now loading file number 64 out of 100
# Now loading file number 65 out of 100
# Now loading file number 66 out of 100
# Now loading file number 67 out of 100
# Now loading file number 68 out of 100
# Now loading file number 69 out of 100
# Now loading file number 70 out of 100
# Now loading file number 71 out of 100
# Now loading file number 72 out of 100
# Now loading file number 73 out of 100
# Now loading file number 74 out of 100
# Now loading file number 75 out of 100
# Now loading file number 76 out of 100
# Now loading file number 77 out of 100
# Now loading file number 78 out of 100
# Now loading file number 79 out of 100
# Now loading file number 80 out of 100
# Now loading file number 81 out of 100
# Now loading file number 82 out of 100
# Now loading file number 83 out of 100
# Now loading file number 84 out of 100
# Now loading file number 85 out of 100
# Now loading file number 86 out of 100
# Now loading file number 87 out of 100
# Now loading file number 88 out of 100
# Now loading file number 89 out of 100
# Now loading file number 90 out of 100
# Now loading file number 91 out of 100
# Now loading file number 92 out of 100
# Now loading file number 93 out of 100
# Now loading file number 94 out of 100
# Now loading file number 95 out of 100
# Now loading file number 96 out of 100
# Now loading file number 97 out of 100
# Now loading file number 98 out of 100
# Now loading file number 99 out of 100

# %%
#####################################################################
# CNN Model definition
#####################################################################

def TBDCNet_modelCNN(inputShape, outputShape, params):
  '''
  This function returns a model based on the hyperparameters in the
  sweep definition

  Args
  ----------
  inputShape: the 55x20x3 input image shape
  outputShape: the prediction image shape (currently unused)
  params: The hyperparameters for the given sweep index

  Returns
  ----------
  model: tensorflow model

  '''
  # Kernel regularizer (both linear and quadratic)
  if params['L1kernel_regularizer'] > 0 and params['L2kernel_regularizer'] > 0: 
     regularizer = tf.keras.regularizers.L1L2(l1=params['L1kernel_regularizer'], l2=params['L2kernel_regularizer'])
  elif params['L1kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L1(params['L1kernel_regularizer'])
  elif params['L2kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L2(params['L2kernel_regularizer'])
  else:
    regularizer = None

  # Define the model architecture. Each convolutional layer has settings related to the kernel size, 
  # activation function, and regularizer. After each convolutional layer there may be a batch-
  # normalization layer, a max pooling layer, and a dropout layer. The number of convolutional layers
  # is given in the sweep definition


  input = tf.keras.layers.Input(shape=inputShape) # Shape (Long, short, inputs)
  x = input


  x = tf.keras.layers.Conv2D(filters = 32, kernel_size=(int(params['layer1Kernel']), int(params['layer1Kernel'])),activation=params['conv1Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
  if params['batchNorm'] == 1:
    x = tf.keras.layers.BatchNormalization()(x)
  if params['pooling'] == 1:
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
  if params['dropout'] > 0:
    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
  encoder1 = x # Use this if skip connections need to be used


  if params['layer2'] == 1:
    x = tf.keras.layers.Conv2D(filters = 64, kernel_size=(int(params['layer2Kernel']), int(params['layer2Kernel'])),activation=params['conv2Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
    if params['batchNorm'] == 1:
      x = tf.keras.layers.BatchNormalization()(x)
    if params['pooling'] == 1:
       x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
    if params['dropout'] > 0:
       x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
    encoder2 = x
        

    if params['layer3'] == 1:
        x = tf.keras.layers.Conv2D(filters = 128, kernel_size=(int(params['layer3Kernel']), int(params['layer3Kernel'])),activation=params['conv3Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
        if params['batchNorm'] == 1:
           x = tf.keras.layers.BatchNormalization()(x)
        if params['pooling'] == 1:
           x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
        if params['dropout'] > 0:
           x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
        encoder3 = x


        if params['layer4'] == 1:
            x = tf.keras.layers.Conv2D(filters = 256, kernel_size=(int(params['layer4Kernel']), int(params['layer4Kernel'])),activation=params['conv4Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
            if params['batchNorm'] == 1:
                x = tf.keras.layers.BatchNormalization()(x)
            if params['pooling'] == 1:
                x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
            if params['dropout'] > 0:
                x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
            encoder4 = x


            if params['layer5'] == 1:
                x = tf.keras.layers.Conv2D(filters = 512, kernel_size=(int(params['layer5Kernel']), int(params['layer5Kernel'])),activation=params['conv5Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                if params['batchNorm'] == 1:
                    x = tf.keras.layers.BatchNormalization()(x)
                if params['pooling'] == 1:
                    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                if params['dropout'] > 0:
                    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                encoder5 = x


                if params['layer6'] == 1:
                    x = tf.keras.layers.Conv2D(filters = 1024, kernel_size=(int(params['layer6Kernel']), int(params['layer6Kernel'])),activation=params['conv6Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                    if params['batchNorm'] == 1:
                        x = tf.keras.layers.BatchNormalization()(x)
                    if params['pooling'] == 1:
                        x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                    if params['dropout'] > 0:
                        x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                    encoder6 = x

                    if params['ActivationUp'] == 0:
                       temp_activation = 'linear'
                    else:
                       temp_activation = params['conv6Activation']

                    x = tf.keras.layers.Conv2DTranspose(filters = 512, kernel_size = (int(params['layer6Kernel']),int(params['layer6Kernel'])),  padding='same',activation=temp_activation)(x)
                    if params['skipConnections'] == 1:
                      x = tf.keras.layers.Concatenate()([x, encoder5])


                if params['ActivationUp'] == 0:
                    temp_activation = 'linear'
                else:
                    temp_activation = params['conv5Activation']

                x = tf.keras.layers.Conv2DTranspose(filters = 256, kernel_size = (int(params['layer5Kernel']),int(params['layer5Kernel'])),  padding='same',activation=temp_activation)(x)
                if params['skipConnections'] == 1:
                  x = tf.keras.layers.Concatenate()([x, encoder4])
            
            
            if params['type'] == 'dense':
              y = tf.keras.layers.Flatten()(x)
              y = tf.keras.layers.Dense(64, activation='relu')(y)
              y = tf.keras.layers.Dense(outputShape[0]*outputShape[1])(y)
              y = tf.keras.layers.Reshape(outputShape)(y)

            if params['ActivationUp'] == 0:
                temp_activation = 'linear'
            else:
                temp_activation = params['conv4Activation']
            
            x = tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (int(params['layer4Kernel']),int(params['layer4Kernel'])),  padding='same',activation=temp_activation)(x)
            if params['skipConnections'] == 1:
              x = tf.keras.layers.Concatenate()([x, encoder3])

        if params['ActivationUp'] == 0:
            temp_activation = 'linear'
        else:
            temp_activation = params['conv3Activation']
        
        x = tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (int(params['layer3Kernel']),int(params['layer3Kernel'])),  padding='same',activation=temp_activation)(x)
        if params['skipConnections'] == 1:
          x = tf.keras.layers.Concatenate()([x, encoder2])

    if params['ActivationUp'] == 0:
        temp_activation = 'linear'
    else:
        temp_activation = params['conv2Activation']
    
    x = tf.keras.layers.Conv2DTranspose(filters = 32, kernel_size = (int(params['layer2Kernel']),int(params['layer2Kernel'])),  padding='same',activation=temp_activation)(x)
    if params['skipConnections'] == 1:
      x = tf.keras.layers.Concatenate()([x, encoder1])

   # Custom activation function is linear between 0 and 1 and otherwise constant
  def custom_activation(x):
      return tf.math.minimum(K.relu(x), 1)

  x = tf.keras.layers.Conv2DTranspose(filters = 1, kernel_size = (int(params['layer1Kernel']),int(params['layer1Kernel'])),  padding='same',activation='linear')(x)

  if params['type'] == 'dense': # For the dense model we jsut pull the output y
     output = y
  else:
    output = x

  model = tf.keras.Model(inputs=input, outputs=output) # Create model

  # Default initial learning rate is 0.001. If the the decay rate is 1 this will be held constant.
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=params['initial_lr'],
    decay_steps=steps_per_epoch*epochs,
    decay_rate=params['lr_decay_rate'])

  def custom_loss(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.nn.relu(y_true))))
    loss = tf.reduce_mean(loss)
    return loss
  
  def custom_loss5(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.math.multiply(tf.nn.relu(y_true),5))))
    loss = tf.reduce_mean(loss)
    return loss

  def peak_loss(y_true,y_pred):
    peakVal = tf.reduce_max(y_true, keepdims=True)
    cond = tf.equal(y_true, peakVal)
    # peakLoc = tf.where(cond)
    # peakLoc_1d = tf.squeeze(peakLoc)
    errorGrid = tf.math.subtract(y_true,y_pred)
    zeroGrid = tf.math.subtract(y_true,y_true) # Grid of zeros so we only get loss in peak location
    # peakPred = y_pred[peakLoc_1d.numpy()[0]]
    # peakPred = tf.slice(y_pred, peakLoc, [1,1])
    loss = tf.where(cond, errorGrid, zeroGrid)
    loss = tf.reduce_mean(loss)

    # loss = peakPred-peakVal
    return loss


#   Loss functions can be swept
  if params['loss'] == 'MSE':
    lossfunc = tf.keras.losses.MeanSquaredError()
  elif params['loss'] == 'MAE':
    lossfunc = tf.keras.losses.MeanAbsoluteError()
  elif params['loss'] == 'Custom':
    lossfunc = custom_loss
  elif params['loss'] == 'Peak':
    lossfunc = peak_loss
  elif params['loss'] == 'Custom5':
    lossfunc = custom_loss5
    



  # Compile model with the optimizer in the sweep definition
  if params['optimizer'] == 'Adadelta':
     model.compile(optimizer=tf.keras.optimizers.Adadelta(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  elif params['optimizer'] == 'Nadam':
     model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  else:
     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])

  return model

# %%
#####################################################################
# Training callbacks
#####################################################################

# Checkpoints to allow saving best model at various points
# checkpoint_path = 'training_checkpoints_{jn}_{num}/cp.ckpt'.format(jn='TESTJOB', num = 1)
checkpoint_path = 'training_checkpoints_{jn}_{num}/model.weights.h5'.format(jn='TESTJOB', num = 1)
checkpoint_dir = os.path.dirname(checkpoint_path)

try:
  os.mkdir(checkpoint_dir) # Make checkpoint directory
except:
  pass

# Save best weights to checkpoint
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_best_only = True,
                                                 monitor = 'val_loss',
                                                 verbose=1)

# Early stopping callback which monitors improvements and stops training if
# it stagnates.
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', # Monitor validation loss
    min_delta=0, # Minimum improvement to consider an improvement
    patience=60, # Number of epochs with no improvement before stopping training
    verbose=1, # Records message when earlystopping
    mode='auto',
    baseline=None, 
    restore_best_weights=False # Do not restore best weights after early stopping, we do this manually to allow recording of the full training history
)

# %%
#####################################################################
# Model instantiation
#####################################################################

tf.keras.backend.clear_session() # Clear the state and frees up memory

# CNN Model creation
modelCNN = TBDCNet_modelCNN(inputShape = train_in_shape[1:], outputShape = train_out_shape[1:], params = params)
modelCNNname = 'CNNModel1'
# Out:
# WARNING:tensorflow:From c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
#####################################################################
# Model training
#####################################################################

# Known issue: sometimes throws error related to the shape of the labels...
# Fit model to Failure index
modelCNN_history = modelCNN.fit(train_ds,
                                epochs=epochs,
                                steps_per_epoch=steps_per_epoch,
                                validation_data=val_ds,
                                validation_steps = validation_steps,
                                callbacks=[early_stopping_monitor, cp_callback]
                                )
# Out:
# Epoch 1/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 5.1624 - mean_absolute_error: 0.8134 - mean_squared_error: 1.0340
# Epoch 1: val_loss improved from inf to 3.09950, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - loss: 5.0638 - mean_absolute_error: 0.8143 - mean_squared_error: 1.0347 - val_loss: 3.0995 - val_mean_absolute_error: 0.7927 - val_mean_squared_error: 0.9662
# Epoch 2/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 2.6940 - mean_absolute_error: 0.7843 - mean_squared_error: 0.9452
# Epoch 2: val_loss improved from 3.09950 to 2.80162, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2.6966 - mean_absolute_error: 0.7825 - mean_squared_error: 0.9418 - val_loss: 2.8016 - val_mean_absolute_error: 0.6812 - val_mean_squared_error: 0.7624
# Epoch 3/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 2.5023 - mean_absolute_error: 0.7388 - mean_squared_error: 0.8560
# Epoch 3: val_loss improved from 2.80162 to 2.61160, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 2.5024 - mean_absolute_error: 0.7373 - mean_squared_error: 0.8532 - val_loss: 2.6116 - val_mean_absolute_error: 0.6434 - val_mean_squared_error: 0.6997
# Epoch 4/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 2.4608 - mean_absolute_error: 0.6765 - mean_squared_error: 0.7546
# Epoch 4: val_loss did not improve from 2.61160
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 2.4461 - mean_absolute_error: 0.6774 - mean_squared_error: 0.7555 - val_loss: 2.6653 - val_mean_absolute_error: 0.6188 - val_mean_squared_error: 0.6444
# Epoch 5/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2.1187 - mean_absolute_error: 0.6493 - mean_squared_error: 0.7031
# Epoch 5: val_loss improved from 2.61160 to 2.45289, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2.1174 - mean_absolute_error: 0.6501 - mean_squared_error: 0.7049 - val_loss: 2.4529 - val_mean_absolute_error: 0.6106 - val_mean_squared_error: 0.6480
# Epoch 6/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 2.4019 - mean_absolute_error: 0.6400 - mean_squared_error: 0.7170
# Epoch 6: val_loss improved from 2.45289 to 2.35533, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 2.3945 - mean_absolute_error: 0.6401 - mean_squared_error: 0.7170 - val_loss: 2.3553 - val_mean_absolute_error: 0.6127 - val_mean_squared_error: 0.6522
# Epoch 7/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.8522 - mean_absolute_error: 0.6339 - mean_squared_error: 0.6779
# Epoch 7: val_loss improved from 2.35533 to 2.21865, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.8582 - mean_absolute_error: 0.6334 - mean_squared_error: 0.6773 - val_loss: 2.2187 - val_mean_absolute_error: 0.6109 - val_mean_squared_error: 0.6686
# Epoch 8/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.9293 - mean_absolute_error: 0.6274 - mean_squared_error: 0.6910
# Epoch 8: val_loss improved from 2.21865 to 2.18964, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.9264 - mean_absolute_error: 0.6263 - mean_squared_error: 0.6887 - val_loss: 2.1896 - val_mean_absolute_error: 0.6129 - val_mean_squared_error: 0.6626
# Epoch 9/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.8858 - mean_absolute_error: 0.6243 - mean_squared_error: 0.6876
# Epoch 9: val_loss improved from 2.18964 to 2.08259, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.8821 - mean_absolute_error: 0.6234 - mean_squared_error: 0.6856 - val_loss: 2.0826 - val_mean_absolute_error: 0.5904 - val_mean_squared_error: 0.6443
# Epoch 10/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.8702 - mean_absolute_error: 0.6019 - mean_squared_error: 0.6583
# Epoch 10: val_loss did not improve from 2.08259
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.8639 - mean_absolute_error: 0.6015 - mean_squared_error: 0.6574 - val_loss: 2.1015 - val_mean_absolute_error: 0.5915 - val_mean_squared_error: 0.6464
# Epoch 11/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.8220 - mean_absolute_error: 0.5914 - mean_squared_error: 0.6583
# Epoch 11: val_loss improved from 2.08259 to 2.01939, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.8080 - mean_absolute_error: 0.5902 - mean_squared_error: 0.6553 - val_loss: 2.0194 - val_mean_absolute_error: 0.5859 - val_mean_squared_error: 0.6322
# Epoch 12/1000
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 1.6066 - mean_absolute_error: 0.5947 - mean_squared_error: 0.6441
# Epoch 12: val_loss did not improve from 2.01939
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.6122 - mean_absolute_error: 0.5946 - mean_squared_error: 0.6452 - val_loss: 2.1902 - val_mean_absolute_error: 0.5549 - val_mean_squared_error: 0.5750
# Epoch 13/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.6182 - mean_absolute_error: 0.5647 - mean_squared_error: 0.5958
# Epoch 13: val_loss improved from 2.01939 to 2.00792, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 1.6175 - mean_absolute_error: 0.5659 - mean_squared_error: 0.5983 - val_loss: 2.0079 - val_mean_absolute_error: 0.5556 - val_mean_squared_error: 0.5733
# Epoch 14/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.6662 - mean_absolute_error: 0.5806 - mean_squared_error: 0.6270
# Epoch 14: val_loss improved from 2.00792 to 1.99965, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 1.6590 - mean_absolute_error: 0.5800 - mean_squared_error: 0.6258 - val_loss: 1.9997 - val_mean_absolute_error: 0.5611 - val_mean_squared_error: 0.5885
# Epoch 15/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.5806 - mean_absolute_error: 0.5554 - mean_squared_error: 0.5851
# Epoch 15: val_loss improved from 1.99965 to 1.96127, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 1.5818 - mean_absolute_error: 0.5565 - mean_squared_error: 0.5871 - val_loss: 1.9613 - val_mean_absolute_error: 0.6054 - val_mean_squared_error: 0.6642
# Epoch 16/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.6296 - mean_absolute_error: 0.5892 - mean_squared_error: 0.6467
# Epoch 16: val_loss improved from 1.96127 to 1.90228, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.6276 - mean_absolute_error: 0.5881 - mean_squared_error: 0.6447 - val_loss: 1.9023 - val_mean_absolute_error: 0.5569 - val_mean_squared_error: 0.5818
# Epoch 17/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.5443 - mean_absolute_error: 0.5646 - mean_squared_error: 0.5922
# Epoch 17: val_loss improved from 1.90228 to 1.86786, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 1.5456 - mean_absolute_error: 0.5641 - mean_squared_error: 0.5919 - val_loss: 1.8679 - val_mean_absolute_error: 0.5815 - val_mean_squared_error: 0.6303
# Epoch 18/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.4513 - mean_absolute_error: 0.5597 - mean_squared_error: 0.5850
# Epoch 18: val_loss did not improve from 1.86786
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.4573 - mean_absolute_error: 0.5592 - mean_squared_error: 0.5842 - val_loss: 1.9098 - val_mean_absolute_error: 0.5901 - val_mean_squared_error: 0.6594
# Epoch 19/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.5244 - mean_absolute_error: 0.5781 - mean_squared_error: 0.6297
# Epoch 19: val_loss improved from 1.86786 to 1.82664, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 1.5225 - mean_absolute_error: 0.5772 - mean_squared_error: 0.6276 - val_loss: 1.8266 - val_mean_absolute_error: 0.5592 - val_mean_squared_error: 0.5839
# Epoch 20/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.3955 - mean_absolute_error: 0.5445 - mean_squared_error: 0.5642
# Epoch 20: val_loss improved from 1.82664 to 1.76954, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 1.3970 - mean_absolute_error: 0.5449 - mean_squared_error: 0.5646 - val_loss: 1.7695 - val_mean_absolute_error: 0.5600 - val_mean_squared_error: 0.5991
# Epoch 21/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.4172 - mean_absolute_error: 0.5569 - mean_squared_error: 0.5932
# Epoch 21: val_loss did not improve from 1.76954
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1.4186 - mean_absolute_error: 0.5568 - mean_squared_error: 0.5932 - val_loss: 2.0552 - val_mean_absolute_error: 0.5272 - val_mean_squared_error: 0.5213
# Epoch 22/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.4377 - mean_absolute_error: 0.5149 - mean_squared_error: 0.5100
# Epoch 22: val_loss did not improve from 1.76954
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 1.4399 - mean_absolute_error: 0.5164 - mean_squared_error: 0.5126 - val_loss: 1.7815 - val_mean_absolute_error: 0.5547 - val_mean_squared_error: 0.5873
# Epoch 23/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.4189 - mean_absolute_error: 0.5463 - mean_squared_error: 0.5722
# Epoch 23: val_loss did not improve from 1.76954
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 1.4249 - mean_absolute_error: 0.5468 - mean_squared_error: 0.5731 - val_loss: 2.1181 - val_mean_absolute_error: 0.5333 - val_mean_squared_error: 0.5375
# Epoch 24/1000
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.4852 - mean_absolute_error: 0.5333 - mean_squared_error: 0.5357
# Epoch 24: val_loss did not improve from 1.76954
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1.4870 - mean_absolute_error: 0.5354 - mean_squared_error: 0.5405 - val_loss: 1.8531 - val_mean_absolute_error: 0.5510 - val_mean_squared_error: 0.5720
# Epoch 25/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.5573 - mean_absolute_error: 0.5592 - mean_squared_error: 0.6048
# Epoch 25: val_loss did not improve from 1.76954
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 1.5503 - mean_absolute_error: 0.5585 - mean_squared_error: 0.6025 - val_loss: 1.7726 - val_mean_absolute_error: 0.5540 - val_mean_squared_error: 0.5842
# Epoch 26/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.4381 - mean_absolute_error: 0.5527 - mean_squared_error: 0.5877
# Epoch 26: val_loss improved from 1.76954 to 1.76934, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 1.4327 - mean_absolute_error: 0.5517 - mean_squared_error: 0.5854 - val_loss: 1.7693 - val_mean_absolute_error: 0.5392 - val_mean_squared_error: 0.5526
# Epoch 27/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.5715 - mean_absolute_error: 0.5563 - mean_squared_error: 0.5882
# Epoch 27: val_loss did not improve from 1.76934
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.5624 - mean_absolute_error: 0.5563 - mean_squared_error: 0.5884 - val_loss: 1.7822 - val_mean_absolute_error: 0.5533 - val_mean_squared_error: 0.5726
# Epoch 28/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.4001 - mean_absolute_error: 0.5456 - mean_squared_error: 0.5646
# Epoch 28: val_loss improved from 1.76934 to 1.73763, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1.4021 - mean_absolute_error: 0.5453 - mean_squared_error: 0.5645 - val_loss: 1.7376 - val_mean_absolute_error: 0.5497 - val_mean_squared_error: 0.5796
# Epoch 29/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.4847 - mean_absolute_error: 0.5479 - mean_squared_error: 0.5763
# Epoch 29: val_loss did not improve from 1.73763
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 1.4830 - mean_absolute_error: 0.5477 - mean_squared_error: 0.5759 - val_loss: 1.7752 - val_mean_absolute_error: 0.5281 - val_mean_squared_error: 0.5337
# Epoch 30/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.3014 - mean_absolute_error: 0.5190 - mean_squared_error: 0.5220
# Epoch 30: val_loss did not improve from 1.73763
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.3018 - mean_absolute_error: 0.5196 - mean_squared_error: 0.5233 - val_loss: 1.7808 - val_mean_absolute_error: 0.5330 - val_mean_squared_error: 0.5427
# Epoch 31/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.3918 - mean_absolute_error: 0.5304 - mean_squared_error: 0.5411
# Epoch 31: val_loss did not improve from 1.73763
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 1.3909 - mean_absolute_error: 0.5304 - mean_squared_error: 0.5418 - val_loss: 1.7506 - val_mean_absolute_error: 0.5342 - val_mean_squared_error: 0.5539
# Epoch 32/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.3200 - mean_absolute_error: 0.5223 - mean_squared_error: 0.5303
# Epoch 32: val_loss did not improve from 1.73763
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 1.3253 - mean_absolute_error: 0.5229 - mean_squared_error: 0.5311 - val_loss: 1.8527 - val_mean_absolute_error: 0.5375 - val_mean_squared_error: 0.5452
# Epoch 33/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.4843 - mean_absolute_error: 0.5501 - mean_squared_error: 0.5674
# Epoch 33: val_loss did not improve from 1.73763
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1.4756 - mean_absolute_error: 0.5491 - mean_squared_error: 0.5664 - val_loss: 1.7744 - val_mean_absolute_error: 0.5305 - val_mean_squared_error: 0.5429
# Epoch 34/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.4072 - mean_absolute_error: 0.5392 - mean_squared_error: 0.5688
# Epoch 34: val_loss improved from 1.73763 to 1.70780, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 1.4082 - mean_absolute_error: 0.5391 - mean_squared_error: 0.5680 - val_loss: 1.7078 - val_mean_absolute_error: 0.5244 - val_mean_squared_error: 0.5349
# Epoch 35/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.2959 - mean_absolute_error: 0.5175 - mean_squared_error: 0.5212
# Epoch 35: val_loss did not improve from 1.70780
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 1.2967 - mean_absolute_error: 0.5173 - mean_squared_error: 0.5208 - val_loss: 1.7249 - val_mean_absolute_error: 0.5226 - val_mean_squared_error: 0.5253
# Epoch 36/1000
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.3711 - mean_absolute_error: 0.5241 - mean_squared_error: 0.5297
# Epoch 36: val_loss did not improve from 1.70780
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 1.3662 - mean_absolute_error: 0.5235 - mean_squared_error: 0.5284 - val_loss: 1.7166 - val_mean_absolute_error: 0.5397 - val_mean_squared_error: 0.5700
# Epoch 37/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.2552 - mean_absolute_error: 0.5191 - mean_squared_error: 0.5310
# Epoch 37: val_loss improved from 1.70780 to 1.68734, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 1.2582 - mean_absolute_error: 0.5191 - mean_squared_error: 0.5309 - val_loss: 1.6873 - val_mean_absolute_error: 0.5175 - val_mean_squared_error: 0.5235
# Epoch 38/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1954 - mean_absolute_error: 0.5035 - mean_squared_error: 0.4890
# Epoch 38: val_loss improved from 1.68734 to 1.65949, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 1.1992 - mean_absolute_error: 0.5041 - mean_squared_error: 0.4904 - val_loss: 1.6595 - val_mean_absolute_error: 0.5118 - val_mean_squared_error: 0.5097
# Epoch 39/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 1.2630 - mean_absolute_error: 0.5096 - mean_squared_error: 0.5211
# Epoch 39: val_loss did not improve from 1.65949
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.2599 - mean_absolute_error: 0.5090 - mean_squared_error: 0.5194 - val_loss: 1.7285 - val_mean_absolute_error: 0.5027 - val_mean_squared_error: 0.4939
# Epoch 40/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.3153 - mean_absolute_error: 0.5064 - mean_squared_error: 0.5038
# Epoch 40: val_loss improved from 1.65949 to 1.63975, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.3184 - mean_absolute_error: 0.5071 - mean_squared_error: 0.5055 - val_loss: 1.6398 - val_mean_absolute_error: 0.5161 - val_mean_squared_error: 0.5297
# Epoch 41/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 1.2917 - mean_absolute_error: 0.5136 - mean_squared_error: 0.5106
# Epoch 41: val_loss did not improve from 1.63975
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 1.2970 - mean_absolute_error: 0.5133 - mean_squared_error: 0.5101 - val_loss: 1.7032 - val_mean_absolute_error: 0.5206 - val_mean_squared_error: 0.5329
# Epoch 42/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.4151 - mean_absolute_error: 0.5256 - mean_squared_error: 0.5433
# Epoch 42: val_loss did not improve from 1.63975
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1.4108 - mean_absolute_error: 0.5248 - mean_squared_error: 0.5416 - val_loss: 1.7191 - val_mean_absolute_error: 0.5037 - val_mean_squared_error: 0.4885
# Epoch 43/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 1.2910 - mean_absolute_error: 0.4969 - mean_squared_error: 0.4868
# Epoch 43: val_loss did not improve from 1.63975
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.2901 - mean_absolute_error: 0.4970 - mean_squared_error: 0.4871 - val_loss: 1.6900 - val_mean_absolute_error: 0.5177 - val_mean_squared_error: 0.5273
# Epoch 44/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.3335 - mean_absolute_error: 0.5163 - mean_squared_error: 0.5267
# Epoch 44: val_loss did not improve from 1.63975
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 1.3339 - mean_absolute_error: 0.5163 - mean_squared_error: 0.5267 - val_loss: 1.7010 - val_mean_absolute_error: 0.4990 - val_mean_squared_error: 0.4927
# Epoch 45/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.2186 - mean_absolute_error: 0.4846 - mean_squared_error: 0.4655
# Epoch 45: val_loss improved from 1.63975 to 1.61929, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 1.2202 - mean_absolute_error: 0.4847 - mean_squared_error: 0.4656 - val_loss: 1.6193 - val_mean_absolute_error: 0.5023 - val_mean_squared_error: 0.5058
# Epoch 46/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.2664 - mean_absolute_error: 0.4940 - mean_squared_error: 0.4841
# Epoch 46: val_loss did not improve from 1.61929
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 1.2644 - mean_absolute_error: 0.4941 - mean_squared_error: 0.4844 - val_loss: 1.6223 - val_mean_absolute_error: 0.4944 - val_mean_squared_error: 0.4790
# Epoch 47/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.2692 - mean_absolute_error: 0.4937 - mean_squared_error: 0.4928
# Epoch 47: val_loss did not improve from 1.61929
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 1.2674 - mean_absolute_error: 0.4937 - mean_squared_error: 0.4924 - val_loss: 1.6561 - val_mean_absolute_error: 0.4909 - val_mean_squared_error: 0.4752
# Epoch 48/1000
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 1.2420 - mean_absolute_error: 0.4949 - mean_squared_error: 0.4821
# Epoch 48: val_loss improved from 1.61929 to 1.60257, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 1.2407 - mean_absolute_error: 0.4950 - mean_squared_error: 0.4829 - val_loss: 1.6026 - val_mean_absolute_error: 0.4965 - val_mean_squared_error: 0.4970
# Epoch 49/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 1.2251 - mean_absolute_error: 0.4895 - mean_squared_error: 0.4856
# Epoch 49: val_loss improved from 1.60257 to 1.57063, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 1.2244 - mean_absolute_error: 0.4896 - mean_squared_error: 0.4851 - val_loss: 1.5706 - val_mean_absolute_error: 0.4916 - val_mean_squared_error: 0.4793
# Epoch 50/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.1732 - mean_absolute_error: 0.4938 - mean_squared_error: 0.4748
# Epoch 50: val_loss did not improve from 1.57063
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 1.1745 - mean_absolute_error: 0.4935 - mean_squared_error: 0.4749 - val_loss: 1.6106 - val_mean_absolute_error: 0.4801 - val_mean_squared_error: 0.4621
# Epoch 51/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.3542 - mean_absolute_error: 0.4959 - mean_squared_error: 0.4997
# Epoch 51: val_loss improved from 1.57063 to 1.55720, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 1.3477 - mean_absolute_error: 0.4954 - mean_squared_error: 0.4984 - val_loss: 1.5572 - val_mean_absolute_error: 0.4854 - val_mean_squared_error: 0.4689
# Epoch 52/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 1.1441 - mean_absolute_error: 0.4720 - mean_squared_error: 0.4480
# Epoch 52: val_loss improved from 1.55720 to 1.52196, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.1463 - mean_absolute_error: 0.4720 - mean_squared_error: 0.4478 - val_loss: 1.5220 - val_mean_absolute_error: 0.4866 - val_mean_squared_error: 0.4791
# Epoch 53/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.1978 - mean_absolute_error: 0.5033 - mean_squared_error: 0.4992
# Epoch 53: val_loss did not improve from 1.52196
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 1.1981 - mean_absolute_error: 0.5031 - mean_squared_error: 0.4992 - val_loss: 1.6369 - val_mean_absolute_error: 0.4703 - val_mean_squared_error: 0.4414
# Epoch 54/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.2521 - mean_absolute_error: 0.4730 - mean_squared_error: 0.4451
# Epoch 54: val_loss did not improve from 1.52196
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 1.2491 - mean_absolute_error: 0.4738 - mean_squared_error: 0.4473 - val_loss: 1.5838 - val_mean_absolute_error: 0.4859 - val_mean_squared_error: 0.4790
# Epoch 55/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.2352 - mean_absolute_error: 0.4851 - mean_squared_error: 0.4675
# Epoch 55: val_loss did not improve from 1.52196
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 1.2300 - mean_absolute_error: 0.4847 - mean_squared_error: 0.4664 - val_loss: 1.5793 - val_mean_absolute_error: 0.4880 - val_mean_squared_error: 0.4729
# Epoch 56/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.1452 - mean_absolute_error: 0.4851 - mean_squared_error: 0.4788
# Epoch 56: val_loss improved from 1.52196 to 1.52186, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 1.1459 - mean_absolute_error: 0.4853 - mean_squared_error: 0.4788 - val_loss: 1.5219 - val_mean_absolute_error: 0.5049 - val_mean_squared_error: 0.5152
# Epoch 57/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.1947 - mean_absolute_error: 0.4977 - mean_squared_error: 0.4930
# Epoch 57: val_loss improved from 1.52186 to 1.51934, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 1.1905 - mean_absolute_error: 0.4966 - mean_squared_error: 0.4904 - val_loss: 1.5193 - val_mean_absolute_error: 0.4746 - val_mean_squared_error: 0.4487
# Epoch 58/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1998 - mean_absolute_error: 0.4772 - mean_squared_error: 0.4549
# Epoch 58: val_loss did not improve from 1.51934
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1.1980 - mean_absolute_error: 0.4773 - mean_squared_error: 0.4554 - val_loss: 1.5453 - val_mean_absolute_error: 0.4767 - val_mean_squared_error: 0.4550
# Epoch 59/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1146 - mean_absolute_error: 0.4630 - mean_squared_error: 0.4298
# Epoch 59: val_loss did not improve from 1.51934
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 1.1163 - mean_absolute_error: 0.4636 - mean_squared_error: 0.4309 - val_loss: 1.5200 - val_mean_absolute_error: 0.4895 - val_mean_squared_error: 0.4921
# Epoch 60/1000
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 1.1584 - mean_absolute_error: 0.4735 - mean_squared_error: 0.4578
# Epoch 60: val_loss did not improve from 1.51934
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.1559 - mean_absolute_error: 0.4747 - mean_squared_error: 0.4592 - val_loss: 1.6313 - val_mean_absolute_error: 0.4741 - val_mean_squared_error: 0.4447
# Epoch 61/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 1.1424 - mean_absolute_error: 0.4743 - mean_squared_error: 0.4450
# Epoch 61: val_loss did not improve from 1.51934
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 1.1404 - mean_absolute_error: 0.4740 - mean_squared_error: 0.4445 - val_loss: 1.5308 - val_mean_absolute_error: 0.4783 - val_mean_squared_error: 0.4686
# Epoch 62/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 1.1990 - mean_absolute_error: 0.4746 - mean_squared_error: 0.4583
# Epoch 62: val_loss improved from 1.51934 to 1.51333, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 1.1932 - mean_absolute_error: 0.4743 - mean_squared_error: 0.4574 - val_loss: 1.5133 - val_mean_absolute_error: 0.4698 - val_mean_squared_error: 0.4421
# Epoch 63/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 1.2608 - mean_absolute_error: 0.4800 - mean_squared_error: 0.4709
# Epoch 63: val_loss did not improve from 1.51333
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 1.2539 - mean_absolute_error: 0.4797 - mean_squared_error: 0.4701 - val_loss: 1.5224 - val_mean_absolute_error: 0.4704 - val_mean_squared_error: 0.4463
# Epoch 64/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 1.1835 - mean_absolute_error: 0.4623 - mean_squared_error: 0.4265
# Epoch 64: val_loss improved from 1.51333 to 1.48527, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 1.1826 - mean_absolute_error: 0.4625 - mean_squared_error: 0.4266 - val_loss: 1.4853 - val_mean_absolute_error: 0.4839 - val_mean_squared_error: 0.4723
# Epoch 65/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.1071 - mean_absolute_error: 0.4820 - mean_squared_error: 0.4608
# Epoch 65: val_loss did not improve from 1.48527
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 
val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.5260 - mean_absolute_error: 0.3268 - mean_squared_error: 0.2061 - val_loss: 1.1638 - val_mean_absolute_error: 0.3625 - val_mean_squared_error: 0.2508
# Epoch 370/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.4987 - mean_absolute_error: 0.3234 - mean_squared_error: 0.2028
# Epoch 370: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.4996 - mean_absolute_error: 0.3236 - mean_squared_error: 0.2030 - val_loss: 1.0814 - val_mean_absolute_error: 0.3607 - val_mean_squared_error: 0.2517
# Epoch 371/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.4996 - mean_absolute_error: 0.3248 - mean_squared_error: 0.2048
# Epoch 371: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.5003 - mean_absolute_error: 0.3248 - mean_squared_error: 0.2046 - val_loss: 1.1459 - val_mean_absolute_error: 0.3569 - val_mean_squared_error: 0.2400
# Epoch 372/1000
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.5152 - mean_absolute_error: 0.3330 - mean_squared_error: 0.2087
# Epoch 372: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.5128 - mean_absolute_error: 0.3322 - mean_squared_error: 0.2075 - val_loss: 1.0744 - val_mean_absolute_error: 0.3606 - val_mean_squared_error: 0.2496
# Epoch 373/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.5115 - mean_absolute_error: 0.3340 - mean_squared_error: 0.2145
# Epoch 373: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.5121 - mean_absolute_error: 0.3336 - mean_squared_error: 0.2139 - val_loss: 1.1031 - val_mean_absolute_error: 0.3538 - val_mean_squared_error: 0.2408
# Epoch 374/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.5036 - mean_absolute_error: 0.3278 - mean_squared_error: 0.2046
# Epoch 374: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.5048 - mean_absolute_error: 0.3277 - mean_squared_error: 0.2044 - val_loss: 1.0749 - val_mean_absolute_error: 0.3613 - val_mean_squared_error: 0.2491
# Epoch 375/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.5085 - mean_absolute_error: 0.3259 - mean_squared_error: 0.2057
# Epoch 375: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.5086 - mean_absolute_error: 0.3258 - mean_squared_error: 0.2053 - val_loss: 1.2106 - val_mean_absolute_error: 0.3581 - val_mean_squared_error: 0.2406
# Epoch 376/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.5907 - mean_absolute_error: 0.3303 - mean_squared_error: 0.2074
# Epoch 376: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.5878 - mean_absolute_error: 0.3304 - mean_squared_error: 0.2077 - val_loss: 1.1481 - val_mean_absolute_error: 0.3597 - val_mean_squared_error: 0.2452
# Epoch 377/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.5243 - mean_absolute_error: 0.3244 - mean_squared_error: 0.2028
# Epoch 377: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.5245 - mean_absolute_error: 0.3247 - mean_squared_error: 0.2032 - val_loss: 1.1530 - val_mean_absolute_error: 0.3618 - val_mean_squared_error: 0.2491
# Epoch 378/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.5370 - mean_absolute_error: 0.3262 - mean_squared_error: 0.2037
# Epoch 378: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.5385 - mean_absolute_error: 0.3263 - mean_squared_error: 0.2039 - val_loss: 1.1838 - val_mean_absolute_error: 0.3634 - val_mean_squared_error: 0.2528
# Epoch 379/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.5879 - mean_absolute_error: 0.3369 - mean_squared_error: 0.2190
# Epoch 379: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.5859 - mean_absolute_error: 0.3363 - mean_squared_error: 0.2182 - val_loss: 1.1008 - val_mean_absolute_error: 0.3639 - val_mean_squared_error: 0.2544
# Epoch 380/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.5817 - mean_absolute_error: 0.3426 - mean_squared_error: 0.2260
# Epoch 380: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.5816 - mean_absolute_error: 0.3423 - mean_squared_error: 0.2255 - val_loss: 1.1300 - val_mean_absolute_error: 0.3525 - val_mean_squared_error: 0.2381
# Epoch 381/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.5464 - mean_absolute_error: 0.3331 - mean_squared_error: 0.2161
# Epoch 381: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.5459 - mean_absolute_error: 0.3329 - mean_squared_error: 0.2159 - val_loss: 1.1306 - val_mean_absolute_error: 0.3597 - val_mean_squared_error: 0.2483
# Epoch 382/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.5260 - mean_absolute_error: 0.3251 - mean_squared_error: 0.2031
# Epoch 382: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.5270 - mean_absolute_error: 0.3255 - mean_squared_error: 0.2035 - val_loss: 1.1564 - val_mean_absolute_error: 0.3627 - val_mean_squared_error: 0.2490
# Epoch 383/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.5541 - mean_absolute_error: 0.3268 - mean_squared_error: 0.2041
# Epoch 383: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.5563 - mean_absolute_error: 0.3272 - mean_squared_error: 0.2047 - val_loss: 1.2285 - val_mean_absolute_error: 0.3694 - val_mean_squared_error: 0.2622
# Epoch 384/1000
# 10/11 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.5815 - mean_absolute_error: 0.3385 - mean_squared_error: 0.2190
# Epoch 384: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.5772 - mean_absolute_error: 0.3377 - mean_squared_error: 0.2175 - val_loss: 1.2668 - val_mean_absolute_error: 0.3833 - val_mean_squared_error: 0.2757
# Epoch 385/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.5627 - mean_absolute_error: 0.3337 - mean_squared_error: 0.2107
# Epoch 385: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.5626 - mean_absolute_error: 0.3339 - mean_squared_error: 0.2110 - val_loss: 1.1521 - val_mean_absolute_error: 0.3618 - val_mean_squared_error: 0.2532
# Epoch 386/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.5656 - mean_absolute_error: 0.3347 - mean_squared_error: 0.2166
# Epoch 386: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 0.5641 - mean_absolute_error: 0.3345 - mean_squared_error: 0.2163 - val_loss: 1.1711 - val_mean_absolute_error: 0.3551 - val_mean_squared_error: 0.2380
# Epoch 387/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.5694 - mean_absolute_error: 0.3270 - mean_squared_error: 0.2055
# Epoch 387: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.5678 - mean_absolute_error: 0.3272 - mean_squared_error: 0.2058 - val_loss: 1.1536 - val_mean_absolute_error: 0.3583 - val_mean_squared_error: 0.2422
# Epoch 388/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.5223 - mean_absolute_error: 0.3347 - mean_squared_error: 0.2115
# Epoch 388: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.5214 - mean_absolute_error: 0.3344 - mean_squared_error: 0.2113 - val_loss: 1.1247 - val_mean_absolute_error: 0.3613 - val_mean_squared_error: 0.2478
# Epoch 389/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.5734 - mean_absolute_error: 0.3333 - mean_squared_error: 0.2131
# Epoch 389: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.5731 - mean_absolute_error: 0.3331 - mean_squared_error: 0.2129 - val_loss: 1.1044 - val_mean_absolute_error: 0.3653 - val_mean_squared_error: 0.2550
# Epoch 390/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.5165 - mean_absolute_error: 0.3334 - mean_squared_error: 0.2127
# Epoch 390: val_loss did not improve from 1.02981
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.5158 - mean_absolute_error: 0.3327 - mean_squared_error: 0.2119 - val_loss: 1.1221 - val_mean_absolute_error: 0.3625 - val_mean_squared_error: 0.2520
# Epoch 390: early stopping

# %%
#####################################################################
# Data export
#####################################################################

trainingHist = modelCNN_history.history # save training history
modelCNN.load_weights(checkpoint_path) # load best model weights

predCNN = modelCNN.predict(X_train) # Make prediction
predCNN_val = modelCNN.predict(X_val) # Prediction of only validation data
predCNNShape = predCNN.shape
predCNN_valShape = predCNN_val.shape

# Inverse standardisation
if params['standardisation'] == 0:
   predCNN_invStandard = predCNN
   predCNN_val_invStandard = predCNN_val
   ground_truth_invStandard = y_train
   ground_truth_val_invStandard = y_val
else:
   predCNN_invStandard = Yscaler.inverse_transform(predCNN.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
   predCNN_invStandard = predCNN_invStandard.reshape(predCNNShape)
   predCNN_val_invStandard = Yscaler.inverse_transform(predCNN_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
   predCNN_val_invStandard = predCNN_val_invStandard.reshape(predCNN_valShape)
   
   ground_truth_invStandard =  Yscaler.inverse_transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
   ground_truth_invStandard = ground_truth_invStandard.reshape(y_trainShape)
   ground_truth_val_invStandard = Yscaler.inverse_transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
   ground_truth_val_invStandard = ground_truth_val_invStandard.reshape(y_valShape)


# RMSE
RMSE = tf.keras.metrics.RootMeanSquaredError()
RMSE.update_state(ground_truth_invStandard,predCNN_invStandard)
print('RMSE for training set = ' + str(RMSE.result().numpy()))
if ground_truth_val_invStandard is not None:
    RMSE_val = tf.keras.metrics.RootMeanSquaredError()
    RMSE_val.update_state(ground_truth_val_invStandard,predCNN_val_invStandard)
    print('RMSE for validation set  = ' + str(RMSE_val.result().numpy()))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# RMSE for training set = 0.15606663
# RMSE for validation set  = 0.17189856

# %%
inputDat = np.zeros(samples2D.shape)
for i in range(0,samples2D.shape[-1]): # Un-normalise all input features
    inputDat[:,:,:,i] = samples2D[:,:,:,i]

with open(histOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(trainingHist, f, indent=2)

with open(predOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(predCNN_invStandard.tolist(), f, indent=2)

with open(predOutPath_val, 'w') as f: # Dump data to json file at specified path
    json.dump(predCNN_val_invStandard.tolist(), f, indent=2)

with open(gtOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(ground_truth_invStandard.tolist(), f, indent=2)

with open(gtOutPath_val, 'w') as f: # Dump data to json file at specified path
    json.dump(ground_truth_val_invStandard.tolist(), f, indent=2)

with open(paramOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(params.to_json(), f, indent=2)

with open(inputOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(inputDat.tolist(), f, indent=2)

with open(RMSEOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(RMSE.result().numpy().tolist(), f, indent=2)

with open(RMSEOutPath_val, 'w') as f: # Dump data to json file at specified path
    json.dump(RMSE_val.result().numpy().tolist(), f, indent=2)

# Save the model
modelCNN.save(modelOutPath)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:6
#       3 for i in range(0,samples2D.shape[-1]): # Un-normalise all input features
#       4     inputDat[:,:,:,i] = samples2D[:,:,:,i]
# ----> 6 with open(histOutPath, 'w') as f: # Dump data to json file at specified path
#       7     json.dump(trainingHist, f, indent=2)
#       9 with open(predOutPath, 'w') as f: # Dump data to json file at specified path
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataoutTESTJOB\\trainHist_TESTJOB_1.json'

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
inputDat = np.zeros(samples2D.shape)
for i in range(0,samples2D.shape[-1]): # Un-normalise all input features
    inputDat[:,:,:,i] = samples2D[:,:,:,i]

with open(histOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(trainingHist, f, indent=2)

with open(predOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(predCNN_invStandard.tolist(), f, indent=2)

with open(predOutPath_val, 'w') as f: # Dump data to json file at specified path
    json.dump(predCNN_val_invStandard.tolist(), f, indent=2)

with open(gtOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(ground_truth_invStandard.tolist(), f, indent=2)

with open(gtOutPath_val, 'w') as f: # Dump data to json file at specified path
    json.dump(ground_truth_val_invStandard.tolist(), f, indent=2)

with open(paramOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(params.to_json(), f, indent=2)

with open(inputOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(inputDat.tolist(), f, indent=2)

with open(RMSEOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(RMSE.result().numpy().tolist(), f, indent=2)

with open(RMSEOutPath_val, 'w') as f: # Dump data to json file at specified path
    json.dump(RMSE_val.result().numpy().tolist(), f, indent=2)

# Save the model
modelCNN.save(modelOutPath)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:6
#       3 for i in range(0,samples2D.shape[-1]): # Un-normalise all input features
#       4     inputDat[:,:,:,i] = samples2D[:,:,:,i]
# ----> 6 with open(histOutPath, 'w') as f: # Dump data to json file at specified path
#       7     json.dump(trainingHist, f, indent=2)
#       9 with open(predOutPath, 'w') as f: # Dump data to json file at specified path
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataoutTESTJOB\\trainHist_TESTJOB_1.json'

# %%
histOutPath
# Out:
# 'dataoutTESTJOB\\trainHist_TESTJOB_1.json'

# %%
inputDat = np.zeros(samples2D.shape)
for i in range(0,samples2D.shape[-1]): # Un-normalise all input features
    inputDat[:,:,:,i] = samples2D[:,:,:,i]

with open(histOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(trainingHist, f, indent=2)

with open(predOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(predCNN_invStandard.tolist(), f, indent=2)

with open(predOutPath_val, 'w') as f: # Dump data to json file at specified path
    json.dump(predCNN_val_invStandard.tolist(), f, indent=2)

with open(gtOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(ground_truth_invStandard.tolist(), f, indent=2)

with open(gtOutPath_val, 'w') as f: # Dump data to json file at specified path
    json.dump(ground_truth_val_invStandard.tolist(), f, indent=2)

with open(paramOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(params.to_json(), f, indent=2)

with open(inputOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(inputDat.tolist(), f, indent=2)

with open(RMSEOutPath, 'w') as f: # Dump data to json file at specified path
    json.dump(RMSE.result().numpy().tolist(), f, indent=2)

with open(RMSEOutPath_val, 'w') as f: # Dump data to json file at specified path
    json.dump(RMSE_val.result().numpy().tolist(), f, indent=2)

# Save the model
modelCNN.save(modelOutPath)

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features



# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path)) # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)




def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    sample = pd.read_csv(path)
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
            samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples))

    samples_array = np.array(samples_list)
    return headers_list, samples_array

# headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



for i,file in enumerate(os.listdir(trainDat_path)):
    print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
    filepath = os.path.join(trainDat_path,file)
    if i==0:
        headers, samples = loadSample(filepath)
        samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
    else:
        addSamp = loadSample(filepath)[1]
        samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 0 out of 9
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:298
#     296 filepath = os.path.join(trainDat_path,file)
#     297 if i==0:
# --> 298     headers, samples = loadSample(filepath)
#     299     samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     300 else:
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:135
#     129 '''
#     130 Imports data in csv and formats into a tensor
#     131 Data from Abaqus comes in a slightly bothersome format, this
#     132 function manually reformats it
#     133 '''
#     134 # Read sample csv data
# --> 135 sample = pd.read_csv(path)
#     136 headers = sample.columns.values.tolist()
#     137 values = np.array(sample)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: '\\\\rds.imperial.ac.uk\\rds\\user\\kfh23\\home\\IndividualProject\\CNNTraining\\datain\\Gaudron2018'

# %%
# # Exx
# ExxPlot = pd.DataFrame(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)[:,0])
# ExxPlot.columns = ['Exx']
# ExxPlot['Specimens']='All data'

# temp = pd.DataFrame(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1)[:,0])
# temp.columns = ['Exx']
# temp['Specimens']='Validation data'

# ExxPlot = pd.concat([ExxPlot, temp])

# # Eyy
# EyyPlot = pd.DataFrame(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)[:,1])
# EyyPlot.columns = ['Eyy']
# EyyPlot['Specimens']='All data'

# temp = pd.DataFrame(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1)[:,1])
# temp.columns = ['Eyy']
# temp['Specimens']='Validation data'

# EyyPlot = pd.concat([EyyPlot, temp])

# # Gxy
# GxyPlot = pd.DataFrame(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)[:,2])
# GxyPlot.columns = ['Gxy']
# GxyPlot['Specimens']='All data'

# temp = pd.DataFrame(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1)[:,2])
# temp.columns = ['Gxy']
# temp['Specimens']='Validation data'

# GxyPlot = pd.concat([GxyPlot, temp])

# # FI
# FIPlot = pd.DataFrame(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
# FIPlot.columns = ['FI']
# FIPlot['Specimens']='All data'

# temp = pd.DataFrame(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
# temp.columns = ['FI']
# temp['Specimens']='Validation data'

# FIPlot = pd.concat([FIPlot, temp])


# px = 1/plt.rcParams['figure.dpi']  # pixel in inches
# fig = plt.figure(figsize=(1000*px, 600*px), layout="constrained")
# plt.style.use("seaborn-v0_8-colorblind") # For consitency use this colour scheme and viridis
# # E11
# ax = plt.subplot(2,2,1)
# sns.histplot(ExxPlot, x='Exx',hue = 'Specimens')
# plt.grid()
# plt.xlabel('Exx [MPa]')
# plt.ylabel('Count')
# plt.title('Horizontal stiffness')

# # E22
# ax = plt.subplot(2,2,2)
# sns.histplot(EyyPlot, x='Eyy',hue = 'Specimens')
# plt.grid()
# plt.xlabel('Eyy [MPa]')
# plt.ylabel('Count')
# plt.title('Vertical stiffness')

# #G12
# ax = plt.subplot(2,2,3)
# sns.histplot(GxyPlot, x='Gxy',hue = 'Specimens')
# plt.grid()
# plt.xlabel('Gxy [Mpa]')
# plt.ylabel('Count')
# plt.title('Shear stiffness')
# #FI
# ax = plt.subplot(2,2,4)
# sns.histplot(FIPlot, x='FI',hue = 'Specimens')
# plt.grid()
# plt.xlabel('FI')
# plt.ylabel('Count')
# plt.title('Failure index')

# plt.show()

# %%
# # Test that import and reshape is correct
# fig, axs = plt.subplots(2, int(len(headers)/2), sharex=True, sharey=True,figsize=[12,7.5]) # Create subplots to fit all variables
# sampleNum = 0
# # Plot  map
# for i in range(len(headers)):
#   ax = plt.subplot(2, int(len(headers)/2), i+1)
#   CS = ax.contourf(grid[0],grid[1],samples2D[sampleNum,:,:,i])
#   plt.xlabel('x')
#   plt.ylabel('y')
#   plt.title(headers[i])
#   fig.colorbar(CS)

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features



# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path)) # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)




def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    sample = pd.read_csv(path)
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
            samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples))

    samples_array = np.array(samples_list)
    return headers_list, samples_array

# headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



for i,file in enumerate(os.listdir(trainDat_path)):
    print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
    filepath = os.path.join(trainDat_path,file)
    if i==0:
        headers, samples = loadSample(filepath)
        samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
    else:
        addSamp = loadSample(filepath)[1]
        samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 0 out of 9
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:298
#     296 filepath = os.path.join(trainDat_path,file)
#     297 if i==0:
# --> 298     headers, samples = loadSample(filepath)
#     299     samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     300 else:
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:135
#     129 '''
#     130 Imports data in csv and formats into a tensor
#     131 Data from Abaqus comes in a slightly bothersome format, this
#     132 function manually reformats it
#     133 '''
#     134 # Read sample csv data
# --> 135 sample = pd.read_csv(path)
#     136 headers = sample.columns.values.tolist()
#     137 values = np.array(sample)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: '\\\\rds.imperial.ac.uk\\rds\\user\\kfh23\\home\\IndividualProject\\CNNTraining\\datain\\Gaudron2018'

# %%
trainDat_path
# Out:
# '\\\\rds.imperial.ac.uk\\rds\\user\\kfh23\\home\\IndividualProject\\CNNTraining\\datain'

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features



# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path)) # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)




def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    sample = pd.read_csv(path)
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
            samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples))

    samples_array = np.array(samples_list)
    return headers_list, samples_array

# headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



for i,file in enumerate(os.listdir(trainDat_path)):
    print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
    filepath = os.path.join(trainDat_path,file)
    if i==0:
        headers, samples = loadSample(filepath)
        samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
    else:
        addSamp = loadSample(filepath)[1]
        samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 0 out of 9
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:298
#     296 filepath = os.path.join(trainDat_path,file)
#     297 if i==0:
# --> 298     headers, samples = loadSample(filepath)
#     299     samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     300 else:
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:135
#     129 '''
#     130 Imports data in csv and formats into a tensor
#     131 Data from Abaqus comes in a slightly bothersome format, this
#     132 function manually reformats it
#     133 '''
#     134 # Read sample csv data
# --> 135 sample = pd.read_csv(path)
#     136 headers = sample.columns.values.tolist()
#     137 values = np.array(sample)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: '\\\\rds.imperial.ac.uk\\rds\\user\\kfh23\\home\\IndividualProject\\CNNTraining\\datain\\Gaudron2018'

# %%
trainDat_path = r'C:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Data\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif p arams['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features



# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path)) # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)




def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    sample = pd.read_csv(path)
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
            samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples))

    samples_array = np.array(samples_list)
    return headers_list, samples_array

# headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



for i,file in enumerate(os.listdir(trainDat_path)):
    print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
    filepath = os.path.join(trainDat_path,file)
    if i==0:
        headers, samples = loadSample(filepath)
        samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
    else:
        addSamp = loadSample(filepath)[1]
        samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
#   Cell In[41], line 19
#     elif p arams['MC24_Features'] == 'All':
#            ^
# SyntaxError: invalid syntax

# %%
trainDat_path = r'C:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Data\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features



# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path)) # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)




def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    sample = pd.read_csv(path)
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
            samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples))

    samples_array = np.array(samples_list)
    return headers_list, samples_array

# headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



for i,file in enumerate(os.listdir(trainDat_path)):
    print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
    filepath = os.path.join(trainDat_path,file)
    if i==0:
        headers, samples = loadSample(filepath)
        samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
    else:
        addSamp = loadSample(filepath)[1]
        samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 0 out of 9
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:298
#     296 filepath = os.path.join(trainDat_path,file)
#     297 if i==0:
# --> 298     headers, samples = loadSample(filepath)
#     299     samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     300 else:
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:135
#     129 '''
#     130 Imports data in csv and formats into a tensor
#     131 Data from Abaqus comes in a slightly bothersome format, this
#     132 function manually reformats it
#     133 '''
#     134 # Read sample csv data
# --> 135 sample = pd.read_csv(path)
#     136 headers = sample.columns.values.tolist()
#     137 values = np.array(sample)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\kfh23\\OneDrive - Imperial College London\\KFH23_GENERAL\\PROJECTS\\20241029_MSc_Paper\\Data\\datain\\Gaudron2018'

# %% [markdown]
# Connected to Python 3.12.7

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC
# Out:
# WARNING:tensorflow:From c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'C:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Data\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features



# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path)) # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)




def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    sample = pd.read_csv(path)
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
            samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples))

    samples_array = np.array(samples_list)
    return headers_list, samples_array

# headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



for i,file in enumerate(os.listdir(trainDat_path)):
    print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
    filepath = os.path.join(trainDat_path,file)
    if i==0:
        headers, samples = loadSample(filepath)
        samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
    else:
        addSamp = loadSample(filepath)[1]
        samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 0 out of 9
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:298
#     296 filepath = os.path.join(trainDat_path,file)
#     297 if i==0:
# --> 298     headers, samples = loadSample(filepath)
#     299     samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     300 else:
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:135
#     129 '''
#     130 Imports data in csv and formats into a tensor
#     131 Data from Abaqus comes in a slightly bothersome format, this
#     132 function manually reformats it
#     133 '''
#     134 # Read sample csv data
# --> 135 sample = pd.read_csv(path)
#     136 headers = sample.columns.values.tolist()
#     137 values = np.array(sample)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\kfh23\\OneDrive - Imperial College London\\KFH23_GENERAL\\PROJECTS\\20241029_MSc_Paper\\Data\\datain\\Gaudron2018'

# %% [markdown]
# Connected to Python 3.12.7

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC
# Out:
# WARNING:tensorflow:From c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\fullSweep1106_repeat1\dataout\model_fullSweep1106_repeat1_1.keras"
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Code\TBDCML_Clone\TBDCML\dataoutTESTJOB\model_TESTJOB_1.keras"
modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\MC24CrossValidation2808_1\dataout\model_MC24CrossValidation2808_1_1.keras"

loaded_model = keras.models.load_model(modelPath)
loaded_model.summary()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:6
#       1 #%% Test model loading
#       2 # modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\fullSweep1106_repeat1\dataout\model_fullSweep1106_repeat1_1.keras"
#       3 # modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Code\TBDCML_Clone\TBDCML\dataoutTESTJOB\model_TESTJOB_1.keras"
#       4 modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\MC24CrossValidation2808_1\dataout\model_MC24CrossValidation2808_1_1.keras"
# ----> 6 loaded_model = keras.models.load_model(modelPath)
#       7 loaded_model.summary()
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\saving\saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\saving\legacy\save.py:233, in load_model(filepath, custom_objects, compile, options)
#     231 if isinstance(filepath_str, str):
#     232     if not tf.io.gfile.exists(filepath_str):
# --> 233         raise IOError(
#     234             f"No file or directory found at {filepath_str}"
#     235         )
#     237     if tf.io.gfile.isdir(filepath_str):
#     238         return saved_model_load.load(
#     239             filepath_str, compile, options
#     240         )
#
# OSError: No file or directory found at C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\MC24CrossValidation2808_1\dataout\model_MC24CrossValidation2808_1_1.keras

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)
# Out:
# Cell was canceled due to an error in a previous cell.

# %%
trainDat_path = r'C:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Data\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features



# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path)) # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)




def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    sample = pd.read_csv(path)
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
            samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples))

    samples_array = np.array(samples_list)
    return headers_list, samples_array

# headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



for i,file in enumerate(os.listdir(trainDat_path)):
    print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
    filepath = os.path.join(trainDat_path,file)
    if i==0:
        headers, samples = loadSample(filepath)
        samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
    else:
        addSamp = loadSample(filepath)[1]
        samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Cell was canceled due to an error in a previous cell.

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'C:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Data\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features



# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path)) # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)




def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    sample = pd.read_csv(path)
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
            samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples))

    samples_array = np.array(samples_list)
    return headers_list, samples_array

# headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



for i,file in enumerate(os.listdir(trainDat_path)):
    print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
    filepath = os.path.join(trainDat_path,file)
    if i==0:
        headers, samples = loadSample(filepath)
        samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
    else:
        addSamp = loadSample(filepath)[1]
        samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 0 out of 9
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:298
#     296 filepath = os.path.join(trainDat_path,file)
#     297 if i==0:
# --> 298     headers, samples = loadSample(filepath)
#     299     samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     300 else:
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:135
#     129 '''
#     130 Imports data in csv and formats into a tensor
#     131 Data from Abaqus comes in a slightly bothersome format, this
#     132 function manually reformats it
#     133 '''
#     134 # Read sample csv data
# --> 135 sample = pd.read_csv(path)
#     136 headers = sample.columns.values.tolist()
#     137 values = np.array(sample)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\kfh23\\OneDrive - Imperial College London\\KFH23_GENERAL\\PROJECTS\\20241029_MSc_Paper\\Data\\datain\\Gaudron2018'

# %%
os.access(trainDat_path, os.R_OK)
# Out:
# True

# %%
with open(trainDat_path, 'r') as file:
        # process your file
        print(file.read())
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 with open(trainDat_path, 'r') as file:
#       2         # process your file
#       3         print(file.read())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\kfh23\\OneDrive - Imperial College London\\KFH23_GENERAL\\PROJECTS\\20241029_MSc_Paper\\Data\\datain'

# %%
filepath
# Out:
# 'C:\\Users\\kfh23\\OneDrive - Imperial College London\\KFH23_GENERAL\\PROJECTS\\20241029_MSc_Paper\\Data\\datain\\Gaudron2018'

# %%
os.listdir(trainDat_path)
# Out:
# ['Gaudron2018',
#  'MatLabModel2024',
#  'MatLabModel2024_1000',
#  'MatLabModel2024_100SamplesVfConstant',
#  'MatLabModel2024_100SamplesVfVariable',
#  'MatLabModel2024_200',
#  'MatLabModel2024_224_4kSamples',
#  'MatLabModel2024_500',
#  'MatLabModel2024_OLD_102Specimens']

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features



# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path)) # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)




def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    sample = pd.read_csv(path)
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
            samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples))

    samples_array = np.array(samples_list)
    return headers_list, samples_array

# headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



for i,file in enumerate(os.listdir(trainDat_path)):
    print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
    filepath = os.path.join(trainDat_path,file)
    if i==0:
        headers, samples = loadSample(filepath)
        samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
    else:
        addSamp = loadSample(filepath)[1]
        samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 0 out of 100
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:298
#     296 filepath = os.path.join(trainDat_path,file)
#     297 if i==0:
# --> 298     headers, samples = loadSample(filepath)
#     299     samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     300 else:
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:135
#     129 '''
#     130 Imports data in csv and formats into a tensor
#     131 Data from Abaqus comes in a slightly bothersome format, this
#     132 function manually reformats it
#     133 '''
#     134 # Read sample csv data
# --> 135 sample = pd.read_csv(path)
#     136 headers = sample.columns.values.tolist()
#     137 values = np.array(sample)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 7: invalid start byte

# %%
path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 path
#
# NameError: name 'path' is not defined

# %%
trainDat_path
# Out:
# '\\\\rds.imperial.ac.uk\\rds\\user\\kfh23\\home\\IndividualProject\\CNNTraining\\datain\\MatLabModel2024_224_4kSamples'

# %% [markdown]
# Connected to Python 3.12.7

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K
import tfio

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:18
#      16 from sklearn.preprocessing import StandardScaler
#      17 from tensorflow.keras import backend as K
# ---> 18 import tfio
#      20 import numpy as np
#      21 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'tfio'

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC
# Out:
# WARNING:tensorflow:From c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\fullSweep1106_repeat1\dataout\model_fullSweep1106_repeat1_1.keras"
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Code\TBDCML_Clone\TBDCML\dataoutTESTJOB\model_TESTJOB_1.keras"
modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\MC24CrossValidation2808_1\dataout\model_MC24CrossValidation2808_1_1.keras"

loaded_model = keras.models.load_model(modelPath)
loaded_model.summary()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:6
#       1 #%% Test model loading
#       2 # modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\fullSweep1106_repeat1\dataout\model_fullSweep1106_repeat1_1.keras"
#       3 # modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Code\TBDCML_Clone\TBDCML\dataoutTESTJOB\model_TESTJOB_1.keras"
#       4 modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\MC24CrossValidation2808_1\dataout\model_MC24CrossValidation2808_1_1.keras"
# ----> 6 loaded_model = keras.models.load_model(modelPath)
#       7 loaded_model.summary()
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\saving\saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\saving\legacy\save.py:233, in load_model(filepath, custom_objects, compile, options)
#     231 if isinstance(filepath_str, str):
#     232     if not tf.io.gfile.exists(filepath_str):
# --> 233         raise IOError(
#     234             f"No file or directory found at {filepath_str}"
#     235         )
#     237     if tf.io.gfile.isdir(filepath_str):
#     238         return saved_model_load.load(
#     239             filepath_str, compile, options
#     240         )
#
# OSError: No file or directory found at C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\MC24CrossValidation2808_1\dataout\model_MC24CrossValidation2808_1_1.keras

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = tf.data.experimental.from_list(result)
            else:
                tmp = tf.data.experimental.from_list(result)
            # samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:285
#     282     # samples_array = np.array(samples_list)
#     283     return headers_list, samples_array
# --> 285 headers, samples = load_all_samples(trainDat_path, numSamples)
#     286 # print(samples_array.shape)
#     287
#     288
#    (...)
#     302 # std = np.sqrt(scaler.var_)
#     303 # Reshape sample variable to have shape (samples, row, column, features)
#     304 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:275
#     273 if i == 0:
#     274     headers_list = headers  # Use headers from the first file
# --> 275     samples_list = tf.data.experimental.from_list(result)
#     276 else:
#     277     tmp = tf.data.experimental.from_list(result)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\experimental\ops\from_list.py:119, in from_list(elements, name)
#      75 @tf_export("data.experimental.from_list")
#      76 def from_list(elements, name=None):
#      77   """Creates a `Dataset` comprising the given list of elements.
#      78
#      79   The returned dataset will produce the items in the list one by one. The
#    (...)
#     117     Dataset: A `Dataset` of the `elements`.
#     118   """
# --> 119   return _ListDataset(elements, name)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\experimental\ops\from_list.py:30, in _ListDataset.__init__(self, elements, name)
#      29 def __init__(self, elements, name=None):
# ---> 30   if not elements:
#      31     raise ValueError("Invalid `elements`. `elements` should not be empty.")
#      32   if not isinstance(elements, list):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
headers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 headers
#
# NameError: name 'headers' is not defined

# %%
trainDat_path
# Out:
# '\\\\rds.imperial.ac.uk\\rds\\user\\kfh23\\home\\IndividualProject\\CNNTraining\\datain\\Gaudron2018'

# %%
numSamples
# Out:
# 100

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                print(result)
                samples_list = tf.data.experimental.from_list(result)
            else:
                tmp = tf.data.experimental.from_list(result)
            # samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# [[ 1.00000000e+00  2.37500000e+01  6.77454500e+01 ...  4.95896328e+04
#    4.45051758e+04  1.90969121e+04]
#  [ 2.00000000e+00  2.12500000e+01  6.77454500e+01 ...  4.81528828e+04
#    4.61821172e+04  1.86280918e+04]
#  [ 3.00000000e+00  1.87500000e+01  6.77454500e+01 ...  4.67161289e+04
#    4.78590625e+04  1.81592715e+04]
#  ...
#  [ 1.09800000e+03 -1.87500000e+01 -6.77454500e+01 ...  5.28978047e+04
#    4.07294492e+04  1.71254043e+04]
#  [ 1.09900000e+03 -2.12500000e+01 -6.77454500e+01 ...  5.06401172e+04
#    4.03376641e+04  1.71284688e+04]
#  [ 1.10000000e+03 -2.37500000e+01 -6.77454500e+01 ...  4.83824297e+04
#    3.99458789e+04  1.71315352e+04]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:286
#     283     # samples_array = np.array(samples_list)
#     284     return headers_list, samples_array
# --> 286 headers, samples = load_all_samples(trainDat_path, numSamples)
#     287 # print(samples_array.shape)
#     288
#     289
#    (...)
#     303 # std = np.sqrt(scaler.var_)
#     304 # Reshape sample variable to have shape (samples, row, column, features)
#     305 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:276
#     274     headers_list = headers  # Use headers from the first file
#     275     print(result)
# --> 276     samples_list = tf.data.experimental.from_list(result)
#     277 else:
#     278     tmp = tf.data.experimental.from_list(result)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\experimental\ops\from_list.py:119, in from_list(elements, name)
#      75 @tf_export("data.experimental.from_list")
#      76 def from_list(elements, name=None):
#      77   """Creates a `Dataset` comprising the given list of elements.
#      78
#      79   The returned dataset will produce the items in the list one by one. The
#    (...)
#     117     Dataset: A `Dataset` of the `elements`.
#     118   """
# --> 119   return _ListDataset(elements, name)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\experimental\ops\from_list.py:30, in _ListDataset.__init__(self, elements, name)
#      29 def __init__(self, elements, name=None):
# ---> 30   if not elements:
#      31     raise ValueError("Invalid `elements`. `elements` should not be empty.")
#      32   if not isinstance(elements, list):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                tmp = result
            # samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:287
#     284     # samples_array = np.array(samples_list)
#     285     return headers_list, samples_array
# --> 287 headers, samples = load_all_samples(trainDat_path, numSamples)
#     288 # print(samples_array.shape)
#     289
#     290
#    (...)
#     304 # std = np.sqrt(scaler.var_)
#     305 # Reshape sample variable to have shape (samples, row, column, features)
#     306 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:283
#     280         # samples_list.append(result)
#     281         print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))
# --> 283 samples_array = tf.data.experimental.from_list(samples_list)
#     284 # samples_array = np.array(samples_list)
#     285 return headers_list, samples_array
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\experimental\ops\from_list.py:119, in from_list(elements, name)
#      75 @tf_export("data.experimental.from_list")
#      76 def from_list(elements, name=None):
#      77   """Creates a `Dataset` comprising the given list of elements.
#      78
#      79   The returned dataset will produce the items in the list one by one. The
#    (...)
#     117     Dataset: A `Dataset` of the `elements`.
#     118   """
# --> 119   return _ListDataset(elements, name)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\experimental\ops\from_list.py:30, in _ListDataset.__init__(self, elements, name)
#      29 def __init__(self, elements, name=None):
# ---> 30   if not elements:
#      31     raise ValueError("Invalid `elements`. `elements` should not be empty.")
#      32   if not isinstance(elements, list):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC

# %%
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\fullSweep1106_repeat1\dataout\model_fullSweep1106_repeat1_1.keras"
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Code\TBDCML_Clone\TBDCML\dataoutTESTJOB\model_TESTJOB_1.keras"
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\MC24CrossValidation2808_1\dataout\model_MC24CrossValidation2808_1_1.keras"

# loaded_model = keras.models.load_model(modelPath)
# loaded_model.summary()

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                tmp = result
            # samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:287
#     284     # samples_array = np.array(samples_list)
#     285     return headers_list, samples_array
# --> 287 headers, samples = load_all_samples(trainDat_path, numSamples)
#     288 # print(samples_array.shape)
#     289
#     290
#    (...)
#     304 # std = np.sqrt(scaler.var_)
#     305 # Reshape sample variable to have shape (samples, row, column, features)
#     306 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:272
#     270 futures = {executor.submit(process_file, file): file for file in files}
#     271 for i, future in enumerate(as_completed(futures)):
# --> 272     headers, result = future.result()
#     273     if i == 0:
#     274         headers_list = headers  # Use headers from the first file
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:266
#     265 def process_file(filepath):
# --> 266     headers, values = loadSampleNew(filepath)
#     267     return headers, values
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:245
#     243     sample = pd.read_csv(path)
#     244    case '.parquet':
# --> 245     sample = pd.read_parquet(path, engine='auto')
#     246 headers = sample.columns.values.tolist()
#     247 values = np.array(sample)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parquet.py:651, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     498 @doc(storage_options=_shared_docs["storage_options"])
#     499 def read_parquet(
#     500     path: FilePath | ReadBuffer[bytes],
#    (...)
#     508     **kwargs,
#     509 ) -> DataFrame:
#     510     """
#     511     Load a parquet object from the file path, returning a DataFrame.
#     512
#    (...)
#     648     1    4    9
#     649     """
# --> 651     impl = get_engine(engine)
#     653     if use_nullable_dtypes is not lib.no_default:
#     654         msg = (
#     655             "The argument 'use_nullable_dtypes' is deprecated and will be removed "
#     656             "in a future version."
#     657         )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parquet.py:67, in get_engine(engine)
#      64         except ImportError as err:
#      65             error_msgs += "\n - " + str(err)
# ---> 67     raise ImportError(
#      68         "Unable to find a usable engine; "
#      69         "tried using: 'pyarrow', 'fastparquet'.\n"
#      70         "A suitable version of "
#      71         "pyarrow or fastparquet is required for parquet "
#      72         "support.\n"
#      73         "Trying to import the above resulted in these errors:"
#      74         f"{error_msgs}"
#      75     )
#      77 if engine == "pyarrow":
#      78     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.

# %% [markdown]
# Connected to Python 3.12.7

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC
# Out:
# WARNING:tensorflow:From c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\fullSweep1106_repeat1\dataout\model_fullSweep1106_repeat1_1.keras"
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Code\TBDCML_Clone\TBDCML\dataoutTESTJOB\model_TESTJOB_1.keras"
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\MC24CrossValidation2808_1\dataout\model_MC24CrossValidation2808_1_1.keras"

# loaded_model = keras.models.load_model(modelPath)
# loaded_model.summary()

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                tmp = result
            # samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:95
#      69 # elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#      70 #   trainDat_name = 'MatLabModel2024_10000'
#      71 #   sampleShape = [60,20]
#    (...)
#      88 #   elif params['MC24_Features'] == 'All':
#      89 #      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
#      94 yNames = ['FI'] # Names of ground truth features in input csv
# ---> 95 numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
#      96 batchSize = params['batchSize'] # Batch size for training
#      97 trainValRatio = params['trainValRatio'] # Training and validation data split ratio
#
# OSError: [WinError 64] The specified network name is no longer available: '\\\\rds.imperial.ac.uk\\rds\\user\\kfh23\\home\\IndividualProject\\CNNTraining\\datain\\MatLabModel2024_224_4kSamples'

# %%
trainDat_path
# Out:
# '\\\\rds.imperial.ac.uk\\rds\\user\\kfh23\\home\\IndividualProject\\CNNTraining\\datain\\MatLabModel2024_224_4kSamples'

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                tmp = result
            # samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:287
#     284     # samples_array = np.array(samples_list)
#     285     return headers_list, samples_array
# --> 287 headers, samples = load_all_samples(trainDat_path, numSamples)
#     288 # print(samples_array.shape)
#     289
#     290
#    (...)
#     304 # std = np.sqrt(scaler.var_)
#     305 # Reshape sample variable to have shape (samples, row, column, features)
#     306 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:272
#     270 futures = {executor.submit(process_file, file): file for file in files}
#     271 for i, future in enumerate(as_completed(futures)):
# --> 272     headers, result = future.result()
#     273     if i == 0:
#     274         headers_list = headers  # Use headers from the first file
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:266
#     265 def process_file(filepath):
# --> 266     headers, values = loadSampleNew(filepath)
#     267     return headers, values
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:245
#     243     sample = pd.read_csv(path)
#     244    case '.parquet':
# --> 245     sample = pd.read_parquet(path, engine='auto')
#     246 headers = sample.columns.values.tolist()
#     247 values = np.array(sample)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parquet.py:651, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     498 @doc(storage_options=_shared_docs["storage_options"])
#     499 def read_parquet(
#     500     path: FilePath | ReadBuffer[bytes],
#    (...)
#     508     **kwargs,
#     509 ) -> DataFrame:
#     510     """
#     511     Load a parquet object from the file path, returning a DataFrame.
#     512
#    (...)
#     648     1    4    9
#     649     """
# --> 651     impl = get_engine(engine)
#     653     if use_nullable_dtypes is not lib.no_default:
#     654         msg = (
#     655             "The argument 'use_nullable_dtypes' is deprecated and will be removed "
#     656             "in a future version."
#     657         )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parquet.py:67, in get_engine(engine)
#      64         except ImportError as err:
#      65             error_msgs += "\n - " + str(err)
# ---> 67     raise ImportError(
#      68         "Unable to find a usable engine; "
#      69         "tried using: 'pyarrow', 'fastparquet'.\n"
#      70         "A suitable version of "
#      71         "pyarrow or fastparquet is required for parquet "
#      72         "support.\n"
#      73         "Trying to import the above resulted in these errors:"
#      74         f"{error_msgs}"
#      75     )
#      77 if engine == "pyarrow":
#      78     return PyArrowImpl()
#
# ImportError: Unable to find a usable engine; tried using: 'pyarrow', 'fastparquet'.
# A suitable version of pyarrow or fastparquet is required for parquet support.
# Trying to import the above resulted in these errors:
#  - Missing optional dependency 'pyarrow'. pyarrow is required for parquet support. Use pip or conda to install pyarrow.
#  - Missing optional dependency 'fastparquet'. fastparquet is required for parquet support. Use pip or conda to install fastparquet.

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                tmp = result
            # samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:287
#     284     # samples_array = np.array(samples_list)
#     285     return headers_list, samples_array
# --> 287 headers, samples = load_all_samples(trainDat_path, numSamples)
#     288 # print(samples_array.shape)
#     289
#     290
#    (...)
#     304 # std = np.sqrt(scaler.var_)
#     305 # Reshape sample variable to have shape (samples, row, column, features)
#     306 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:283
#     280         # samples_list.append(result)
#     281         print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))
# --> 283 samples_array = tf.data.experimental.from_list(samples_list)
#     284 # samples_array = np.array(samples_list)
#     285 return headers_list, samples_array
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\experimental\ops\from_list.py:119, in from_list(elements, name)
#      75 @tf_export("data.experimental.from_list")
#      76 def from_list(elements, name=None):
#      77   """Creates a `Dataset` comprising the given list of elements.
#      78
#      79   The returned dataset will produce the items in the list one by one. The
#    (...)
#     117     Dataset: A `Dataset` of the `elements`.
#     118   """
# --> 119   return _ListDataset(elements, name)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\experimental\ops\from_list.py:30, in _ListDataset.__init__(self, elements, name)
#      29 def __init__(self, elements, name=None):
# ---> 30   if not elements:
#      31     raise ValueError("Invalid `elements`. `elements` should not be empty.")
#      32   if not isinstance(elements, list):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
samples_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 samples_list
#
# NameError: name 'samples_list' is not defined

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                tmp = result
            # samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:306
#     287 headers, samples = load_all_samples(trainDat_path, numSamples)
#     288 # print(samples_array.shape)
#     289
#     290
#    (...)
#     304 # std = np.sqrt(scaler.var_)
#     305 # Reshape sample variable to have shape (samples, row, column, features)
# --> 306 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#     308 # Find indeces of input features
#     309 featureIdx = []
#
# ValueError: cannot reshape array of size 14049280 into shape (4000,60,20,7)

# %%
headers
# Out:
# array(['specimen', 'FI', 'Ex', 'Ey', 'Gxy', 'Vf', 'c2'], dtype='<U8')

# %%
samples
# Out:
# array([[1.21000000e+02, 7.65745157e-01, 4.37188339e+04, ...,
#         1.82960703e+04, 4.84500000e-01, 4.51433393e-01],
#        [1.21000000e+02, 7.09950329e-01, 3.78125993e+04, ...,
#         1.80424310e+04, 4.56000000e-01, 4.78437408e-01],
#        [1.21000000e+02, 6.71184841e-01, 3.73005735e+04, ...,
#         1.69176642e+04, 4.27500000e-01, 4.57407060e-01],
#        ...,
#        [1.60000000e+02, 3.96496627e-01, 5.85450675e+04, ...,
#         1.51253527e+04, 5.13000000e-01, 4.10321892e-01],
#        [1.60000000e+02, 4.19769264e-01, 5.89361268e+04, ...,
#         1.59338005e+04, 5.13000000e-01, 3.84264014e-01],
#        [1.60000000e+02, 4.70156442e-01, 5.95152924e+04, ...,
#         1.59429592e+04, 5.13000000e-01, 3.83298126e-01]])

# %%
samples.shape
# Out:
# (2007040, 7)

# %%
numSamples
# Out:
# 4000

# %%
os.listdir(trainDat_path)
# Out:
# ['samples_1001to1040.parquet',
#  'samples_1041to1080.parquet',
#  'samples_1081to1120.parquet',
#  'samples_1121to1160.parquet',
#  'samples_1161to1200.parquet',
#  'samples_1201to1240.parquet',
#  'samples_121to160.parquet',
#  'samples_1241to1280.parquet',
#  'samples_1281to1320.parquet',
#  'samples_1321to1360.parquet',
#  'samples_1361to1400.parquet',
#  'samples_1401to1440.parquet',
#  'samples_1441to1480.parquet',
#  'samples_1481to1520.parquet',
#  'samples_1521to1560.parquet',
#  'samples_1561to1600.parquet',
#  'samples_1601to1640.parquet',
#  'samples_161to200.parquet',
#  'samples_1641to1680.parquet',
#  'samples_1681to1720.parquet',
#  'samples_1721to1760.parquet',
#  'samples_1761to1800.parquet',
#  'samples_1801to1840.parquet',
#  'samples_1841to1880.parquet',
#  'samples_1881to1920.parquet',
#  'samples_1921to1960.parquet',
#  'samples_1961to2000.parquet',
#  'samples_1to40.parquet',
#  'samples_2001to2040.parquet',
#  'samples_201to240.parquet',
#  'samples_2041to2080.parquet',
#  'samples_2081to2120.parquet',
#  'samples_2121to2160.parquet',
#  'samples_2161to2200.parquet',
#  'samples_2201to2240.parquet',
#  'samples_2241to2280.parquet',
#  'samples_2281to2320.parquet',
#  'samples_2321to2360.parquet',
#  'samples_2361to2400.parquet',
#  'samples_2401to2440.parquet',
#  'samples_241to280.parquet',
#  'samples_2441to2480.parquet',
#  'samples_2481to2520.parquet',
#  'samples_2521to2560.parquet',
#  'samples_2561to2600.parquet',
#  'samples_2601to2640.parquet',
#  'samples_2641to2680.parquet',
#  'samples_2681to2720.parquet',
#  'samples_2721to2760.parquet',
#  'samples_2761to2800.parquet',
#  'samples_2801to2840.parquet',
#  'samples_281to320.parquet',
#  'samples_2841to2880.parquet',
#  'samples_2881to2920.parquet',
#  'samples_2921to2960.parquet',
#  'samples_2961to3000.parquet',
#  'samples_3001to3040.parquet',
#  'samples_3041to3080.parquet',
#  'samples_3081to3120.parquet',
#  'samples_3121to3160.parquet',
#  'samples_3161to3200.parquet',
#  'samples_3201to3240.parquet',
#  'samples_321to360.parquet',
#  'samples_3241to3280.parquet',
#  'samples_3281to3320.parquet',
#  'samples_3321to3360.parquet',
#  'samples_3361to3400.parquet',
#  'samples_3401to3440.parquet',
#  'samples_3441to3480.parquet',
#  'samples_3481to3520.parquet',
#  'samples_3521to3560.parquet',
#  'samples_3561to3600.parquet',
#  'samples_3601to3640.parquet',
#  'samples_361to400.parquet',
#  'samples_3641to3680.parquet',
#  'samples_3681to3720.parquet',
#  'samples_3721to3760.parquet',
#  'samples_3761to3800.parquet',
#  'samples_3801to3840.parquet',
#  'samples_3841to3880.parquet',
#  'samples_3881to3920.parquet',
#  'samples_3921to3960.parquet',
#  'samples_3961to4000.parquet',
#  'samples_401to440.parquet',
#  'samples_41to80.parquet',
#  'samples_441to480.parquet',
#  'samples_481to520.parquet',
#  'samples_521to560.parquet',
#  'samples_561to600.parquet',
#  'samples_601to640.parquet',
#  'samples_641to680.parquet',
#  'samples_681to720.parquet',
#  'samples_721to760.parquet',
#  'samples_761to800.parquet',
#  'samples_801to840.parquet',
#  'samples_81to120.parquet',
#  'samples_841to880.parquet',
#  'samples_881to920.parquet',
#  'samples_921to960.parquet',
#  'samples_961to1000.parquet']

# %%
len(os.listdir(trainDat_path))
# Out:
# 100

# %%
224**2
# Out:
# 50176

# %%
trainDat_path
# Out:
# '\\\\rds.imperial.ac.uk\\rds\\user\\kfh23\\home\\IndividualProject\\CNNTraining\\datain\\MatLabModel2024_224_4kSamples'

# %%
50176*40
# Out:
# 2007040

# %%
samples
# Out:
# array([[1.21000000e+02, 7.65745157e-01, 4.37188339e+04, ...,
#         1.82960703e+04, 4.84500000e-01, 4.51433393e-01],
#        [1.21000000e+02, 7.09950329e-01, 3.78125993e+04, ...,
#         1.80424310e+04, 4.56000000e-01, 4.78437408e-01],
#        [1.21000000e+02, 6.71184841e-01, 3.73005735e+04, ...,
#         1.69176642e+04, 4.27500000e-01, 4.57407060e-01],
#        ...,
#        [1.60000000e+02, 3.96496627e-01, 5.85450675e+04, ...,
#         1.51253527e+04, 5.13000000e-01, 4.10321892e-01],
#        [1.60000000e+02, 4.19769264e-01, 5.89361268e+04, ...,
#         1.59338005e+04, 5.13000000e-01, 3.84264014e-01],
#        [1.60000000e+02, 4.70156442e-01, 5.95152924e+04, ...,
#         1.59429592e+04, 5.13000000e-01, 3.83298126e-01]])

# %%
samples_array = tf.data.experimental.from_list(samples)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 samples_array = tf.data.experimental.from_list(samples)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\experimental\ops\from_list.py:119, in from_list(elements, name)
#      75 @tf_export("data.experimental.from_list")
#      76 def from_list(elements, name=None):
#      77   """Creates a `Dataset` comprising the given list of elements.
#      78
#      79   The returned dataset will produce the items in the list one by one. The
#    (...)
#     117     Dataset: A `Dataset` of the `elements`.
#     118   """
# --> 119   return _ListDataset(elements, name)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\data\experimental\ops\from_list.py:30, in _ListDataset.__init__(self, elements, name)
#      29 def __init__(self, elements, name=None):
# ---> 30   if not elements:
#      31     raise ValueError("Invalid `elements`. `elements` should not be empty.")
#      32   if not isinstance(elements, list):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
samples_array = tf.data.experimental.from_list(list(samples))

# %% [markdown]
# Restarted Python 3.12.7

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC
# Out:
# WARNING:tensorflow:From c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\fullSweep1106_repeat1\dataout\model_fullSweep1106_repeat1_1.keras"
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Code\TBDCML_Clone\TBDCML\dataoutTESTJOB\model_TESTJOB_1.keras"
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\MC24CrossValidation2808_1\dataout\model_MC24CrossValidation2808_1_1.keras"

# loaded_model = keras.models.load_model(modelPath)
# loaded_model.summary()

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                tmp = result
            # samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 306
#     287 headers, samples = load_all_samples(trainDat_path, numSamples)
#     288 # print(samples_array.shape)
#     289
#     290
#    (...)
#     304 # std = np.sqrt(scaler.var_)
#     305 # Reshape sample variable to have shape (samples, row, column, features)
# --> 306 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#     308 # Find indeces of input features
#     309 featureIdx = []
#
# ValueError: cannot reshape array of size 7200 into shape (100,60,20,6)

# %%
7200/20
# Out:
# 360.0

# %%
7200/60
# Out:
# 120.0

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 1 out of 100.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 287
#     284     samples_array = np.array(samples_list)
#     285     return headers_list, samples_array
# --> 287 headers, samples = load_all_samples(trainDat_path, numSamples)
#     288 # print(samples_array.shape)
#     289
#     290
#    (...)
#     304 # std = np.sqrt(scaler.var_)
#     305 # Reshape sample variable to have shape (samples, row, column, features)
#     306 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# Cell In[7], line 280, in load_all_samples(trainDat_path, numSamples)
#     275             samples_list = result
#     276             # samples_list = tf.data.experimental.from_list(result)
#     277         else:
#     278             # tmp = tf.data.experimental.from_list(result)
#     279             # tmp = result
# --> 280           samples_list.append(result)
#     281         print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))
#     283 # samples_array = tf.data.experimental.from_list(samples_list)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
samples_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 samples_list
#
# NameError: name 'samples_list' is not defined

# %%
samples_list = []

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list.append(result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 1 out of 100.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 287
#     284     samples_array = np.array(samples_list)
#     285     return headers_list, samples_array
# --> 287 headers, samples = load_all_samples(trainDat_path, numSamples)
#     288 # print(samples_array.shape)
#     289
#     290
#    (...)
#     304 # std = np.sqrt(scaler.var_)
#     305 # Reshape sample variable to have shape (samples, row, column, features)
#     306 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# Cell In[10], line 280, in load_all_samples(trainDat_path, numSamples)
#     275             samples_list = result
#     276             # samples_list = tf.data.experimental.from_list(result)
#     277         else:
#     278             # tmp = tf.data.experimental.from_list(result)
#     279             # tmp = result
# --> 280           samples_list.append(result)
#     281         print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))
#     283 # samples_array = tf.data.experimental.from_list(samples_list)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 306
#     287 headers, samples = load_all_samples(trainDat_path, numSamples)
#     288 # print(samples_array.shape)
#     289
#     290
#    (...)
#     304 # std = np.sqrt(scaler.var_)
#     305 # Reshape sample variable to have shape (samples, row, column, features)
# --> 306 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#     308 # Find indeces of input features
#     309 featureIdx = []
#
# ValueError: cannot reshape array of size 720000 into shape (100,60,20,720000)

# %%
samples.shape
# Out:
# (720000,)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# (1200, 6)
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 307
#     288 headers, samples = load_all_samples(trainDat_path, numSamples)
#     289 # print(samples_array.shape)
#     290
#     291
#    (...)
#     305 # std = np.sqrt(scaler.var_)
#     306 # Reshape sample variable to have shape (samples, row, column, features)
# --> 307 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#     309 # Find indeces of input features
#     310 featureIdx = []
#
# ValueError: cannot reshape array of size 720000 into shape (100,60,20,720000)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
trainValRatio = params['trainValRatio'] # Training and validation data split ratio
train_length = round(numSamples * trainValRatio) # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# (1200, 6)
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
samples
# Out:
# array([[5.15970569e-01, 5.97109818e+04, 3.67917908e+04, 2.39762055e+04,
#         6.27000000e-01, 4.03811571e-01],
#        [5.70876687e-01, 7.00357812e+04, 5.47597205e+04, 2.63173923e+04,
#         7.41000000e-01, 4.44174329e-01],
#        [6.02809704e-01, 7.15189226e+04, 5.34776590e+04, 2.58424207e+04,
#         7.41000000e-01, 4.29542329e-01],
#        ...,
#        [4.17044434e-01, 3.47607073e+04, 6.89183640e+04, 1.68343120e+04,
#         5.70000000e-01, 6.44236915e-01],
#        [4.13296349e-01, 4.07279652e+04, 4.57177647e+04, 1.60463680e+04,
#         4.84500000e-01, 5.18579513e-01],
#        [4.07646731e-01, 4.72670145e+04, 5.74277324e+04, 1.72395876e+04,
#         5.70000000e-01, 5.42058507e-01]])

# %%
samples.shape
# Out:
# (120000, 6)

# %%
# # Exx
# ExxPlot = pd.DataFrame(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)[:,0])
# ExxPlot.columns = ['Exx']
# ExxPlot['Specimens']='All data'

# temp = pd.DataFrame(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1)[:,0])
# temp.columns = ['Exx']
# temp['Specimens']='Validation data'

# ExxPlot = pd.concat([ExxPlot, temp])

# # Eyy
# EyyPlot = pd.DataFrame(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)[:,1])
# EyyPlot.columns = ['Eyy']
# EyyPlot['Specimens']='All data'

# temp = pd.DataFrame(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1)[:,1])
# temp.columns = ['Eyy']
# temp['Specimens']='Validation data'

# EyyPlot = pd.concat([EyyPlot, temp])

# # Gxy
# GxyPlot = pd.DataFrame(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)[:,2])
# GxyPlot.columns = ['Gxy']
# GxyPlot['Specimens']='All data'

# temp = pd.DataFrame(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1)[:,2])
# temp.columns = ['Gxy']
# temp['Specimens']='Validation data'

# GxyPlot = pd.concat([GxyPlot, temp])

# # FI
# FIPlot = pd.DataFrame(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
# FIPlot.columns = ['FI']
# FIPlot['Specimens']='All data'

# temp = pd.DataFrame(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
# temp.columns = ['FI']
# temp['Specimens']='Validation data'

# FIPlot = pd.concat([FIPlot, temp])


# px = 1/plt.rcParams['figure.dpi']  # pixel in inches
# fig = plt.figure(figsize=(1000*px, 600*px), layout="constrained")
# plt.style.use("seaborn-v0_8-colorblind") # For consitency use this colour scheme and viridis
# # E11
# ax = plt.subplot(2,2,1)
# sns.histplot(ExxPlot, x='Exx',hue = 'Specimens')
# plt.grid()
# plt.xlabel('Exx [MPa]')
# plt.ylabel('Count')
# plt.title('Horizontal stiffness')

# # E22
# ax = plt.subplot(2,2,2)
# sns.histplot(EyyPlot, x='Eyy',hue = 'Specimens')
# plt.grid()
# plt.xlabel('Eyy [MPa]')
# plt.ylabel('Count')
# plt.title('Vertical stiffness')

# #G12
# ax = plt.subplot(2,2,3)
# sns.histplot(GxyPlot, x='Gxy',hue = 'Specimens')
# plt.grid()
# plt.xlabel('Gxy [Mpa]')
# plt.ylabel('Count')
# plt.title('Shear stiffness')
# #FI
# ax = plt.subplot(2,2,4)
# sns.histplot(FIPlot, x='FI',hue = 'Specimens')
# plt.grid()
# plt.xlabel('FI')
# plt.ylabel('Count')
# plt.title('Failure index')

# plt.show()

# %%
# # Test that import and reshape is correct
# fig, axs = plt.subplots(2, int(len(headers)/2), sharex=True, sharey=True,figsize=[12,7.5]) # Create subplots to fit all variables
# sampleNum = 0
# # Plot  map
# for i in range(len(headers)):
#   ax = plt.subplot(2, int(len(headers)/2), i+1)
#   CS = ax.contourf(grid[0],grid[1],samples2D[sampleNum,:,:,i])
#   plt.xlabel('x')
#   plt.ylabel('y')
#   plt.title(headers[i])
#   fig.colorbar(CS)

# %%
#####################################################################
# CNN Model definition
#####################################################################

def TBDCNet_modelCNN(inputShape, outputShape, params):
  '''
  This function returns a model based on the hyperparameters in the
  sweep definition

  Args
  ----------
  inputShape: the 55x20x3 input image shape
  outputShape: the prediction image shape (currently unused)
  params: The hyperparameters for the given sweep index

  Returns
  ----------
  model: tensorflow model

  '''
  # Kernel regularizer (both linear and quadratic)
  if params['L1kernel_regularizer'] > 0 and params['L2kernel_regularizer'] > 0: 
     regularizer = tf.keras.regularizers.L1L2(l1=params['L1kernel_regularizer'], l2=params['L2kernel_regularizer'])
  elif params['L1kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L1(params['L1kernel_regularizer'])
  elif params['L2kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L2(params['L2kernel_regularizer'])
  else:
    regularizer = None

  # Define the model architecture. Each convolutional layer has settings related to the kernel size, 
  # activation function, and regularizer. After each convolutional layer there may be a batch-
  # normalization layer, a max pooling layer, and a dropout layer. The number of convolutional layers
  # is given in the sweep definition


  input = tf.keras.layers.Input(shape=inputShape) # Shape (Long, short, inputs)
  x = input


  x = tf.keras.layers.Conv2D(filters = 32, kernel_size=(int(params['layer1Kernel']), int(params['layer1Kernel'])),activation=params['conv1Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
  if params['batchNorm'] == 1:
    x = tf.keras.layers.BatchNormalization()(x)
  if params['pooling'] == 1:
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
  if params['dropout'] > 0:
    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
  encoder1 = x # Use this if skip connections need to be used


  if params['layer2'] == 1:
    x = tf.keras.layers.Conv2D(filters = 64, kernel_size=(int(params['layer2Kernel']), int(params['layer2Kernel'])),activation=params['conv2Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
    if params['batchNorm'] == 1:
      x = tf.keras.layers.BatchNormalization()(x)
    if params['pooling'] == 1:
       x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
    if params['dropout'] > 0:
       x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
    encoder2 = x
        

    if params['layer3'] == 1:
        x = tf.keras.layers.Conv2D(filters = 128, kernel_size=(int(params['layer3Kernel']), int(params['layer3Kernel'])),activation=params['conv3Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
        if params['batchNorm'] == 1:
           x = tf.keras.layers.BatchNormalization()(x)
        if params['pooling'] == 1:
           x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
        if params['dropout'] > 0:
           x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
        encoder3 = x


        if params['layer4'] == 1:
            x = tf.keras.layers.Conv2D(filters = 256, kernel_size=(int(params['layer4Kernel']), int(params['layer4Kernel'])),activation=params['conv4Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
            if params['batchNorm'] == 1:
                x = tf.keras.layers.BatchNormalization()(x)
            if params['pooling'] == 1:
                x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
            if params['dropout'] > 0:
                x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
            encoder4 = x


            if params['layer5'] == 1:
                x = tf.keras.layers.Conv2D(filters = 512, kernel_size=(int(params['layer5Kernel']), int(params['layer5Kernel'])),activation=params['conv5Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                if params['batchNorm'] == 1:
                    x = tf.keras.layers.BatchNormalization()(x)
                if params['pooling'] == 1:
                    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                if params['dropout'] > 0:
                    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                encoder5 = x


                if params['layer6'] == 1:
                    x = tf.keras.layers.Conv2D(filters = 1024, kernel_size=(int(params['layer6Kernel']), int(params['layer6Kernel'])),activation=params['conv6Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                    if params['batchNorm'] == 1:
                        x = tf.keras.layers.BatchNormalization()(x)
                    if params['pooling'] == 1:
                        x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                    if params['dropout'] > 0:
                        x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                    encoder6 = x

                    if params['ActivationUp'] == 0:
                       temp_activation = 'linear'
                    else:
                       temp_activation = params['conv6Activation']

                    x = tf.keras.layers.Conv2DTranspose(filters = 512, kernel_size = (int(params['layer6Kernel']),int(params['layer6Kernel'])),  padding='same',activation=temp_activation)(x)
                    if params['skipConnections'] == 1:
                      x = tf.keras.layers.Concatenate()([x, encoder5])


                if params['ActivationUp'] == 0:
                    temp_activation = 'linear'
                else:
                    temp_activation = params['conv5Activation']

                x = tf.keras.layers.Conv2DTranspose(filters = 256, kernel_size = (int(params['layer5Kernel']),int(params['layer5Kernel'])),  padding='same',activation=temp_activation)(x)
                if params['skipConnections'] == 1:
                  x = tf.keras.layers.Concatenate()([x, encoder4])
            
            
            if params['type'] == 'dense':
              y = tf.keras.layers.Flatten()(x)
              y = tf.keras.layers.Dense(64, activation='relu')(y)
              y = tf.keras.layers.Dense(outputShape[0]*outputShape[1])(y)
              y = tf.keras.layers.Reshape(outputShape)(y)

            if params['ActivationUp'] == 0:
                temp_activation = 'linear'
            else:
                temp_activation = params['conv4Activation']
            
            x = tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (int(params['layer4Kernel']),int(params['layer4Kernel'])),  padding='same',activation=temp_activation)(x)
            if params['skipConnections'] == 1:
              x = tf.keras.layers.Concatenate()([x, encoder3])

        if params['ActivationUp'] == 0:
            temp_activation = 'linear'
        else:
            temp_activation = params['conv3Activation']
        
        x = tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (int(params['layer3Kernel']),int(params['layer3Kernel'])),  padding='same',activation=temp_activation)(x)
        if params['skipConnections'] == 1:
          x = tf.keras.layers.Concatenate()([x, encoder2])

    if params['ActivationUp'] == 0:
        temp_activation = 'linear'
    else:
        temp_activation = params['conv2Activation']
    
    x = tf.keras.layers.Conv2DTranspose(filters = 32, kernel_size = (int(params['layer2Kernel']),int(params['layer2Kernel'])),  padding='same',activation=temp_activation)(x)
    if params['skipConnections'] == 1:
      x = tf.keras.layers.Concatenate()([x, encoder1])

   # Custom activation function is linear between 0 and 1 and otherwise constant
  def custom_activation(x):
      return tf.math.minimum(K.relu(x), 1)

  x = tf.keras.layers.Conv2DTranspose(filters = 1, kernel_size = (int(params['layer1Kernel']),int(params['layer1Kernel'])),  padding='same',activation='linear')(x)

  if params['type'] == 'dense': # For the dense model we jsut pull the output y
     output = y
  else:
    output = x

  model = tf.keras.Model(inputs=input, outputs=output) # Create model

  # Default initial learning rate is 0.001. If the the decay rate is 1 this will be held constant.
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=params['initial_lr'],
    decay_steps=steps_per_epoch*epochs,
    decay_rate=params['lr_decay_rate'])

  def custom_loss(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.nn.relu(y_true))))
    loss = tf.reduce_mean(loss)
    return loss
  
  def custom_loss5(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.math.multiply(tf.nn.relu(y_true),5))))
    loss = tf.reduce_mean(loss)
    return loss

  def peak_loss(y_true,y_pred):
    peakVal = tf.reduce_max(y_true, keepdims=True)
    cond = tf.equal(y_true, peakVal)
    # peakLoc = tf.where(cond)
    # peakLoc_1d = tf.squeeze(peakLoc)
    errorGrid = tf.math.subtract(y_true,y_pred)
    zeroGrid = tf.math.subtract(y_true,y_true) # Grid of zeros so we only get loss in peak location
    # peakPred = y_pred[peakLoc_1d.numpy()[0]]
    # peakPred = tf.slice(y_pred, peakLoc, [1,1])
    loss = tf.where(cond, errorGrid, zeroGrid)
    loss = tf.reduce_mean(loss)

    # loss = peakPred-peakVal
    return loss


#   Loss functions can be swept
  if params['loss'] == 'MSE':
    lossfunc = tf.keras.losses.MeanSquaredError()
  elif params['loss'] == 'MAE':
    lossfunc = tf.keras.losses.MeanAbsoluteError()
  elif params['loss'] == 'Custom':
    lossfunc = custom_loss
  elif params['loss'] == 'Peak':
    lossfunc = peak_loss
  elif params['loss'] == 'Custom5':
    lossfunc = custom_loss5
    



  # Compile model with the optimizer in the sweep definition
  if params['optimizer'] == 'Adadelta':
     model.compile(optimizer=tf.keras.optimizers.Adadelta(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  elif params['optimizer'] == 'Nadam':
     model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  else:
     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])

  return model

# %%
#####################################################################
# Training callbacks
#####################################################################

# Checkpoints to allow saving best model at various points
# checkpoint_path = 'training_checkpoints_{jn}_{num}/cp.ckpt'.format(jn='TESTJOB', num = 1)
checkpoint_path = 'training_checkpoints_{jn}_{num}/model.weights.h5'.format(jn='TESTJOB', num = 1)
checkpoint_dir = os.path.dirname(checkpoint_path)

try:
  os.mkdir(checkpoint_dir) # Make checkpoint directory
except:
  pass

# Save best weights to checkpoint
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_best_only = True,
                                                 monitor = 'val_loss',
                                                 verbose=1)

# Early stopping callback which monitors improvements and stops training if
# it stagnates.
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', # Monitor validation loss
    min_delta=0, # Minimum improvement to consider an improvement
    patience=60, # Number of epochs with no improvement before stopping training
    verbose=1, # Records message when earlystopping
    mode='auto',
    baseline=None, 
    restore_best_weights=False # Do not restore best weights after early stopping, we do this manually to allow recording of the full training history
)

# %%
#####################################################################
# Model instantiation
#####################################################################

tf.keras.backend.clear_session() # Clear the state and frees up memory

# CNN Model creation
modelCNN = TBDCNet_modelCNN(inputShape = train_in_shape[1:], outputShape = train_out_shape[1:], params = params)
modelCNNname = 'CNNModel1'
# Out:
# WARNING:tensorflow:From c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
#####################################################################
# Model training
#####################################################################

# Known issue: sometimes throws error related to the shape of the labels...
# Fit model to Failure index
modelCNN_history = modelCNN.fit(train_ds,
                                epochs=epochs,
                                steps_per_epoch=steps_per_epoch,
                                validation_data=val_ds,
                                validation_steps = validation_steps,
                                callbacks=[early_stopping_monitor, cp_callback]
                                )
# Out:
# Epoch 1/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.4395 - mean_absolute_error: 0.5301 - mean_squared_error: 0.4395
# Epoch 1: val_loss did not improve from 0.54165
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.4423 - mean_absolute_error: 0.5310 - mean_squared_error: 0.4423 - val_loss: 0.5630 - val_mean_absolute_error: 0.5893 - val_mean_squared_error: 0.5630
# Epoch 2/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4270 - mean_absolute_error: 0.5149 - mean_squared_error: 0.4270
# Epoch 2: val_loss did not improve from 0.54165
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.4275 - mean_absolute_error: 0.5155 - mean_squared_error: 0.4275 - val_loss: 0.5842 - val_mean_absolute_error: 0.6000 - val_mean_squared_error: 0.5842
# Epoch 3/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.5945 - mean_absolute_error: 0.6142 - mean_squared_error: 0.5945
# Epoch 3: val_loss did not improve from 0.54165
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.5876 - mean_absolute_error: 0.6102 - mean_squared_error: 0.5876 - val_loss: 0.5586 - val_mean_absolute_error: 0.5882 - val_mean_squared_error: 0.5586
# Epoch 4/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3976 - mean_absolute_error: 0.5028 - mean_squared_error: 0.3976
# Epoch 4: val_loss did not improve from 0.54165
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.3993 - mean_absolute_error: 0.5039 - mean_squared_error: 0.3993 - val_loss: 0.5618 - val_mean_absolute_error: 0.5895 - val_mean_squared_error: 0.5618
# Epoch 5/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5249 - mean_absolute_error: 0.5692 - mean_squared_error: 0.5249
# Epoch 5: val_loss did not improve from 0.54165
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.5267 - mean_absolute_error: 0.5707 - mean_squared_error: 0.5267 - val_loss: 0.5880 - val_mean_absolute_error: 0.6056 - val_mean_squared_error: 0.5880
# Epoch 6/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.3397 - mean_absolute_error: 0.4576 - mean_squared_error: 0.3397
# Epoch 6: val_loss did not improve from 0.54165
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.3432 - mean_absolute_error: 0.4598 - mean_squared_error: 0.3432 - val_loss: 0.5560 - val_mean_absolute_error: 0.5875 - val_mean_squared_error: 0.5560
# Epoch 7/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.4732 - mean_absolute_error: 0.5484 - mean_squared_error: 0.4732
# Epoch 7: val_loss did not improve from 0.54165
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.4717 - mean_absolute_error: 0.5476 - mean_squared_error: 0.4717 - val_loss: 0.5679 - val_mean_absolute_error: 0.5897 - val_mean_squared_error: 0.5679
# Epoch 8/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.5013 - mean_absolute_error: 0.5587 - mean_squared_error: 0.5013
# Epoch 8: val_loss did not improve from 0.54165
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.4990 - mean_absolute_error: 0.5572 - mean_squared_error: 0.4990 - val_loss: 0.5607 - val_mean_absolute_error: 0.5914 - val_mean_squared_error: 0.5607
# Epoch 9/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4380 - mean_absolute_error: 0.5280 - mean_squared_error: 0.4380
# Epoch 9: val_loss did not improve from 0.54165
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.4408 - mean_absolute_error: 0.5295 - mean_squared_error: 0.4408 - val_loss: 0.5689 - val_mean_absolute_error: 0.5929 - val_mean_squared_error: 0.5689
# Epoch 10/1000
#  8/11 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4221 - mean_absolute_error: 0.5100 - mean_squared_error: 0.4221
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 7
#       1 #####################################################################
#       2 # Model training
#       3 #####################################################################
#       4
#       5 # Known issue: sometimes throws error related to the shape of the labels...
#       6 # Fit model to Failure index
# ----> 7 modelCNN_history = modelCNN.fit(train_ds,
#       8                                 epochs=epochs,
#       9                                 steps_per_epoch=steps_per_epoch,
#      10                                 validation_data=val_ds,
#      11                                 validation_steps = validation_steps,
#      12                                 callbacks=[early_stopping_monitor, cp_callback]
#      13                                 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:368, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     366 for step, iterator in epoch_iterator:
#     367     callbacks.on_train_batch_begin(step)
# --> 368     logs = self.train_function(iterator)
#     369     callbacks.on_train_batch_end(step, logs)
#     370     if self.stop_training:
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:216, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     212 def function(iterator):
#     213     if isinstance(
#     214         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     215     ):
# --> 216         opt_outputs = multi_step_on_iterator(iterator)
#     217         if not opt_outputs.has_value():
#     218             raise StopIteration
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#####################################################################
# Data export
#####################################################################

trainingHist = modelCNN_history.history # save training history
modelCNN.load_weights(checkpoint_path) # load best model weights

predCNN = modelCNN.predict(X_train) # Make prediction
predCNN_val = modelCNN.predict(X_val) # Prediction of only validation data
predCNNShape = predCNN.shape
predCNN_valShape = predCNN_val.shape

# Inverse standardisation
if params['standardisation'] == 0:
   predCNN_invStandard = predCNN
   predCNN_val_invStandard = predCNN_val
   ground_truth_invStandard = y_train
   ground_truth_val_invStandard = y_val
else:
   predCNN_invStandard = Yscaler.inverse_transform(predCNN.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
   predCNN_invStandard = predCNN_invStandard.reshape(predCNNShape)
   predCNN_val_invStandard = Yscaler.inverse_transform(predCNN_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
   predCNN_val_invStandard = predCNN_val_invStandard.reshape(predCNN_valShape)
   
   ground_truth_invStandard =  Yscaler.inverse_transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
   ground_truth_invStandard = ground_truth_invStandard.reshape(y_trainShape)
   ground_truth_val_invStandard = Yscaler.inverse_transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
   ground_truth_val_invStandard = ground_truth_val_invStandard.reshape(y_valShape)


# RMSE
RMSE = tf.keras.metrics.RootMeanSquaredError()
RMSE.update_state(ground_truth_invStandard,predCNN_invStandard)
print('RMSE for training set = ' + str(RMSE.result().numpy()))
if ground_truth_val_invStandard is not None:
    RMSE_val = tf.keras.metrics.RootMeanSquaredError()
    RMSE_val.update_state(ground_truth_val_invStandard,predCNN_val_invStandard)
    print('RMSE for validation set  = ' + str(RMSE_val.result().numpy()))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# RMSE for training set = 0.082080245
# RMSE for validation set  = 0.08964666

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'valSize'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 97
#      95 numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
#      96 batchSize = params['batchSize'] # Batch size for training
# ---> 97 valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
#      98 testSize = math.floor(params['testSize']*numSamples)
#      99 train_length = numSamples-valSize-testSize # Number of training samples
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'valSize'

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweepIdx = 1
yNames = ['FI'] # Names of ground truth features in input csv
normalizerLength = 20 # Number of random samples used for computation of mean and variance used in data normalisation 

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweepIdx = 1
yNames = ['FI'] # Names of ground truth features in input csv
normalizerLength = 20 # Number of random samples used for computation of mean and variance used in data normalisation 

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'valSize'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 97
#      95 numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
#      96 batchSize = params['batchSize'] # Batch size for training
# ---> 97 valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
#      98 testSize = math.floor(params['testSize']*numSamples)
#      99 train_length = numSamples-valSize-testSize # Number of training samples
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'valSize'

# %%
import sys

import os
import random
import time
import math
import datetime
import shutil
import json
import scipy
import tensorflow as tf
import sklearn
from sklearn import preprocessing
import sklearn.model_selection
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import backend as K

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from concurrent.futures import ThreadPoolExecutor, as_completed

import seaborn as sns
os.environ["TF_USE_LEGACY_KERAS"]="1" # Needed to import models saved before keras 3.0 release
import tf_keras as keras # Legacy keras version which is equal to the one on the HPC

# %%
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\fullSweep1106_repeat1\dataout\model_fullSweep1106_repeat1_1.keras"
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Code\TBDCML_Clone\TBDCML\dataoutTESTJOB\model_TESTJOB_1.keras"
# modelPath = r"C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\CNNTrainingSweepsResults\MC24CrossValidation2808_1\dataout\model_MC24CrossValidation2808_1_1.keras"

# loaded_model = keras.models.load_model(modelPath)
# loaded_model.summary()

# %%
sweep_params = pd.read_csv(os.path.join(os.getcwd(),'sweep_definition_test.csv'))
sweepIdx = 1
yNames = ['FI'] # Names of ground truth features in input csv
normalizerLength = 20 # Number of random samples used for computation of mean and variance used in data normalisation 

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

sweep_params = sweep_params.set_index('Index')
params = sweep_params.loc[1]
jobname = 'TESTJOB'
parallel = 1
timeStamp = datetime.datetime.now().strftime("%Y%m%d%H%M") # Not currently used
histOutName = 'trainHist_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Training history file
histOutPath = os.path.join('dataoutTESTJOB',histOutName)
predOutName = 'predictions_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath = os.path.join('dataoutTESTJOB',predOutName)
predOutName_val = 'predictions_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Predictions
predOutPath_val = os.path.join('dataoutTESTJOB',predOutName_val)
gtOutName = 'groundTruth_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath = os.path.join('dataoutTESTJOB',gtOutName)
gtOutName_val = 'groundTruth_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Ground truths
gtOutPath_val = os.path.join('dataoutTESTJOB',gtOutName_val)
paramOutName = 'parameters_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Hyperparameters
paramOutPath = os.path.join('dataoutTESTJOB',paramOutName)
inputOutName = 'input_{jn}_{num}.json'.format(jn=jobname, num = parallel) # Model inputs
inputOutPath = os.path.join('dataoutTESTJOB',inputOutName)
modelOutPath = 'model_{jn}_{num}.keras'.format(jn=jobname, num = parallel) # Model architecture and weights
modelOutPath = os.path.join('dataoutTESTJOB',modelOutPath)
RMSEOutPath = 'RMSE_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath = os.path.join('dataoutTESTJOB',RMSEOutPath)
RMSEOutPath_val = 'RMSE_val_{jn}_{num}.json'.format(jn=jobname, num = parallel) # RMSE of model to quickly compare models when many are trained in a sweep
RMSEOutPath_val = os.path.join('dataoutTESTJOB',RMSEOutPath_val)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
    headers = sample.columns.values.tolist()
    values = np.array(sample)

    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# (1200, 6)
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
sampleShape
# Out:
# [60, 20]

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = sample.columns.values.tolist()

    samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 292
#     289     samples_array = np.array(samples_list)
#     290     return headers_list, samples_array
# --> 292 headers, samples = load_all_samples(trainDat_path, numSamples)
#     293 # print(samples_array.shape)
#     294
#     295
#    (...)
#     309 # std = np.sqrt(scaler.var_)
#     310 # Reshape sample variable to have shape (samples, row, column, features)
#     311 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# Cell In[35], line 276, in load_all_samples(trainDat_path, numSamples)
#     274 futures = {executor.submit(process_file, file): file for file in files}
#     275 for i, future in enumerate(as_completed(futures)):
# --> 276     headers, result = future.result()
#     277     if i == 0:
#     278         headers_list = headers  # Use headers from the first file
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[35], line 270, in load_all_samples.<locals>.process_file(filepath)
#     269 def process_file(filepath):
# --> 270     headers, values = loadSampleNew(filepath)
#     271     return headers, values
#
# Cell In[35], line 252, in loadSampleNew(path)
#     249     samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
#     250 headers = sample.columns.values.tolist()
# --> 252 samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
#     253 if "coordinates" in headers:
#     254   coordIdx = headers.index("coordinates")
#
# ValueError: cannot reshape array of size 7200 into shape (1200,60,20,newaxis)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        print(sample)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = sample.columns.values.tolist()

    samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, values


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
#             FI            Ex            Ey           Gxy      Vf        c2
# 0     0
#
# [1200 rows x 6 columns]
# (1200, 6)
#             FI            Ex            Ey           Gxy      Vf        c2
# 0     0.553656  34139.675516  44044.523410  11435.706833  0.3990  0.574814
# 1     0.543003  33298.667674  41754.555265  11370.220484  0.3990  0.582239
# 2     0.534680  49509.432257  40841.131700  15107.332480  0.4845  0.460292
# 3     0.522593  63208.838539  58682.783327  17485.062540  0.6270  0.482023
# 4     0.514705  64315.977794  60852.267140  18731.351256  0.6555  0.484325
# ...        ...           ...           ...           ...     ...       ...
# 1195  0.714413  41156.638239  37065.486941  18039.003187  0.4845  0.463258
# 1196  0.763574  41616.538831  39547.389618  15310.631565  0.4560  0.480399
# 1197  0.878654  32403.125127  31638.726120  11396.993819  0.3420  0.483842
# 1198  0.942004  41649.203010  38283.013310  11618.857594  0.3990  0.479355
# 1199  1.000000  39765.193869  36873.482555  12541.824446  0.3990  0.483713
#
# [1200 rows x 6 columns]
# (1200, 6)
#             FI            Ex            Ey           Gxy      Vf        c2
# 0     0.467486  69537.884309  43048.661986  20300.623544  0.6270  0.391320
# 1     0.501101  76287.687651  50617.833117  23204.158769  0.7125  0.406280
# 2     0.526511  64860.557819  43699.645512  18745.607398  0.5985  0.417229
# 3     0.562320  73354.691080  57162.389599  19573.044987  0.6840  0.437606
# 4     0.576724  74325.759923  69828.157489  20787.239991  0.7410  0.484882
# ...        ...           ...           ...           ...     ...       ...
# 1195  0.633390  67275.895432  52914.809273  22736.232545  0.6840  0.443069
# 1196  0.655658  64764.525537  44753.499755  18836.351789  0.5985  0.415576
# 1197  0.663443  54614.523376  35560.823208  14716.315925  0.4845  0.395952
# 1198  0.666133  51981.926526  32915.943756  18419.082828  0.5130  0.391017
# 1199  0.665696  50872.551845  57434.817996  19136.881970  0.5985  0.526999
#
# [1200 rows x 6 columns]
#             FI            Ex            Ey           Gxy      Vf        c2
# 0     0.529263  47798.304899  63696.910573  20650.608814  0.6270  0.566536
# 1     0.672407  59788.718646  54702.733115  19751.625490  0.6270  0.477195
# 2     0.738500  62218.881455  38168.865703  18814.238163  0.5700  0.395044
# 3     0.775925  49282.994215  31483.821316  13557.354388  0.4275  0.394951
# 4     0.783880  64539.902062  46328.821500  18156.523779  0.5985  0.428905
# ...        ...           ...           ...           ...     ...       ...
# 1195  0.431908  49020.445489  42275.712367  21541.319500  0.5700  0.466605
# 1196  0.428678  47550.962184  58291.438062  23657.071940  0.6555  0.550798
# 1197  0.397208  47500.963699  56623.637422  23561.830051  0.6555  0.550901
# 1198  0.374121  53442.718215  72277.144334  23034.488896  0.7125  0.571578
# 1199  0.342514  72993.926921  91374.698185  26762.054299  0.8835  0.562103
#
# [1200 rows x 6 columns]
# (1200, 6)
# (1200, 6)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:294
#     291     samples_array = np.array(samples_list)
#     292     return headers_list, samples_array
# --> 294 headers, samples = load_all_samples(trainDat_path, numSamples)
#     295 # print(samples_array.shape)
#     296
#     297
#    (...)
#     311 # std = np.sqrt(scaler.var_)
#     312 # Reshape sample variable to have shape (samples, row, column, features)
#     313 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:278
#     276 futures = {executor.submit(process_file, file): file for file in files}
#     277 for i, future in enumerate(as_completed(futures)):
# --> 278     headers, result = future.result()
#     279     if i == 0:
#     280         headers_list = headers  # Use headers from the first file
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:272
#     271 def process_file(filepath):
# --> 272     headers, values = loadSampleNew(filepath)
#     273     return headers, values
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:254
#     251     samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
#     252 headers = sample.columns.values.tolist()
# --> 254 samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
#     255 if "coordinates" in headers:
#     256   coordIdx = headers.index("coordinates")
#
# ValueError: cannot reshape array of size 7200 into shape (1200,60,20,newaxis)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
ers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
#     263 headers = np.array(headers)
# --> 264 return headers, values
#
# UnboundLocalError: cannot access local variable 'values' where it is not associated with a value

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = sample.columns.values.tolist()

    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    samples = samples.reshape(sampleShape[0],sampleShape[1],-1)
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, samples


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# (60, 20, 6)
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
samples.shape
# Out:
# (6000, 20, 6)

# %%
samples2D.shape
# Out:
# (100, 60, 20, 6)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = sample.columns.values.tolist()

    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, samples


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# (1, 60, 20, 6)
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
samples.shape
# Out:
# (100, 60, 20, 6)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = sample.columns.values.tolist()
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-45-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 312
#     309     samples_array = np.array(samples_list)
#     310     return headers_list, samples_array
# --> 312 headers, samples = load_all_samples(trainDat_path, numSamples)
#     313 # print(samples_array.shape)
#     314
#     315
#    (...)
#     329 # std = np.sqrt(scaler.var_)
#     330 # Reshape sample variable to have shape (samples, row, column, features)
#     331 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# Cell In[45], line 296, in load_all_samples(trainDat_path, numSamples)
#     294 futures = {executor.submit(process_file, file): file for file in files}
#     295 for i, future in enumerate(as_completed(futures)):
# --> 296     headers, result = future.result()
#     297     if i == 0:
#     298         headers_list = headers  # Use headers from the first file
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[45], line 290, in load_all_samples.<locals>.process_file(filepath)
#     289 def process_file(filepath):
# --> 290     headers, values = loadSampleNew(filepath)
#     291     return headers, values
#
# Cell In[45], line 257, in loadSampleNew(path)
#     255 featureIdx = []
#     256 for name in xNames:
# --> 257   featureIdx += [np.where(headers == name)[0][0]]
#     259 # Find indeces of ground truth features
#     260 gtIdx = []
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = sample.columns.values.tolist()
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    headers = np.array(headers)
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# <ipython-input-46-ed8d133fbac4>:257: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   featureIdx += [np.where(headers == name)[0][0]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[46], line 312
#     309     samples_array = np.array(samples_list)
#     310     return headers_list, samples_array
# --> 312 headers, samples = load_all_samples(trainDat_path, numSamples)
#     313 # print(samples_array.shape)
#     314
#     315
#    (...)
#     329 # std = np.sqrt(scaler.var_)
#     330 # Reshape sample variable to have shape (samples, row, column, features)
#     331 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# Cell In[46], line 296, in load_all_samples(trainDat_path, numSamples)
#     294 futures = {executor.submit(process_file, file): file for file in files}
#     295 for i, future in enumerate(as_completed(futures)):
# --> 296     headers, result = future.result()
#     297     if i == 0:
#     298         headers_list = headers  # Use headers from the first file
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[46], line 290, in load_all_samples.<locals>.process_file(filepath)
#     289 def process_file(filepath):
# --> 290     headers, values = loadSampleNew(filepath)
#     291     return headers, values
#
# Cell In[46], line 257, in loadSampleNew(path)
#     255 featureIdx = []
#     256 for name in xNames:
# --> 257   featureIdx += [np.where(headers == name)[0][0]]
#     259 # Find indeces of ground truth features
#     260 gtIdx = []
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
headers
# Out:
# array(['FI', 'Ex', 'Ey', 'Gxy', 'Vf', 'c2'], dtype='<U3')

# %%
name
# Out:
# 'FI'

# %%
np.where(headers == name)
# Out:
# (array([0]),)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = np.array(sample.columns.values.tolist())
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]
    headers_list = []
    samples_list = []

    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            headers, result = future.result()
            if i == 0:
                headers_list = headers  # Use headers from the first file
                samples_list = result
                print(result.shape)
                # samples_list = tf.data.experimental.from_list(result)
            else:
                # tmp = tf.data.experimental.from_list(result)
                # tmp = result
              samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    samples_array = np.array(samples_list)
    return headers_list, samples_array

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)



# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# Find indeces of input features 
featureIdx = []
for name in xNames:
   featureIdx += [np.where(headers == name)[0][0]]

# Find indeces of ground truth features 
gtIdx = []
for name in yNames:
   gtIdx += [np.where(headers == name)[0][0]]

X = samples2D[:,:,:,featureIdx]  # Input features

Y = samples2D[:,:,:,gtIdx] # Labels

# The below are just used for validation and shape (TODO: replace validation method with tf tensors)
X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
X_trainShape = X_train.shape
X_valShape = X_val.shape
y_trainShape = y_train.shape
y_valShape = y_val.shape


# Standardisation/normalisation
if params['standardisation'] == 'MinMax':
    Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
    Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
elif params['standardisation'] == 'Standard':
    Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
    Yscaler = preprocessing.StandardScaler()
elif params['standardisation'] == 0:
   print('Warning: no standardisation of data applied')
if params['standardisation'] != 0:
    Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
    X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
    X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
    X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
    X_val = X_val.reshape(X_valShape)

    Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
    y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
    y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
    y_val = y_val.reshape(y_valShape)

# Create tensor datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
   train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
train_in_shape = X_train.shape
val_in_shape = X_val.shape
train_out_shape = y_train.shape
val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:311
#     308     samples_array = np.array(samples_list)
#     309     return headers_list, samples_array
# --> 311 headers, samples = load_all_samples(trainDat_path, numSamples)
#     312 # print(samples_array.shape)
#     313
#     314
#    (...)
#     328 # std = np.sqrt(scaler.var_)
#     329 # Reshape sample variable to have shape (samples, row, column, features)
#     330 samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])
#
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:299
#     297     headers_list = headers  # Use headers from the first file
#     298     samples_list = result
# --> 299     print(result.shape)
#     300     # samples_list = tf.data.experimental.from_list(result)
#     301 else:
#     302     # tmp = tf.data.experimental.from_list(result)
#     303     # tmp = result
#     304   samples_list = np.append(samples_list,result,axis = 0)
#
# AttributeError: '_TensorSliceDataset' object has no attribute 'shape'

# %%
samples
# Out:
# array([[[[8.53653565e-01, 3.36518766e+04, 2.71349542e+04,
#           1.02875727e+04, 3.13500000e-01, 4.41859534e-01],
#          [7.42622896e-01, 4.03928918e+04, 3.29878830e+04,
#           1.05492835e+04, 3.70500000e-01, 4.37479207e-01],
#          [6.89831015e-01, 4.51226883e+04, 3.17763060e+04,
#           1.14517867e+04, 3.99000000e-01, 4.24603479e-01],
#          ...,
#          [6.39901040e-01, 3.36121303e+04, 2.94284978e+04,
#           1.14566785e+04, 3.42000000e-01, 4.76972429e-01],
#          [6.09758328e-01, 3.20451304e+04, 3.41775140e+04,
#           8.77102563e+03, 3.13500000e-01, 5.14136915e-01],
#          [5.57191868e-01, 4.62517356e+04, 4.30194032e+04,
#           1.33799429e+04, 4.56000000e-01, 4.82442276e-01]],
#
#         [[8.53653565e-01, 4.42358305e+04, 2.79356205e+04,
#           1.15671139e+04, 3.70500000e-01, 3.89530721e-01],
#          [7.42622896e-01, 4.58525852e+04, 3.28488928e+04,
#           9.27087363e+03, 3.70500000e-01, 4.10232996e-01],
#          [6.89831015e-01, 4.13592819e+04, 3.31773252e+04,
#           9.83381525e+03, 3.70500000e-01, 4.50106890e-01],
#          ...,
#          [6.39901040e-01, 4.26779928e+04, 4.20568540e+04,
#           1.57388621e+04, 4.84500000e-01, 4.95478088e-01],
#          [6.09758328e-01, 3.27035081e+04, 4.21525788e+04,
#           1.49398815e+04, 4.27500000e-01, 5.50568662e-01],
#          [5.57191868e-01, 3.16068623e+04, 4.66639158e+04,

# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = np.array(sample.columns.values.tolist())
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]


    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            if i == 0:
               headers, samples = future.result()
            else:
               addSamp = future.result()[1]
               samples = samples.concatenate(addSamp)
            
            
            # if i == 0:
            #     headers_list = headers  # Use headers from the first file
            #     samples_list = result
            #     # samples_list = tf.data.experimental.from_list(result)
            # else:
            #     # tmp = tf.data.experimental.from_list(result)
            #     # tmp = result
            #   samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers, samples

headers, samples = load_all_samples(trainDat_path, numSamples)
# print(samples_array.shape)
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
samples
# Out:
# <_ConcatenateDataset element_spec=(TensorSpec(shape=(60, 20, 5), dtype=tf.float64, name=None), TensorSpec(shape=(60, 20, 1), dtype=tf.float64, name=None))>

# %%
samples.cardinality().numpy()
# Out:
# np.int64(100)

# %%
headers
# Out:
# array(['FI', 'Ex', 'Ey', 'Gxy', 'Vf', 'c2'], dtype='<U3')

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = np.array(sample.columns.values.tolist())
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]


    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            if i == 0:
               headers, samples = future.result()
            else:
               addSamp = future.result()[1]
               samples = samples.concatenate(addSamp)
            
            
            # if i == 0:
            #     headers_list = headers  # Use headers from the first file
            #     samples_list = result
            #     # samples_list = tf.data.experimental.from_list(result)
            # else:
            #     # tmp = tf.data.experimental.from_list(result)
            #     # tmp = result
            #   samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers, samples

headers, samples = load_all_samples(trainDat_path, numSamples)


samples = samples.shuffle(buffer_size=len(samples)) # Shuffle set
train_ds = samples.take(train_length)
remaining = samples.skip(train_length)
val_ds = remaining.take(valSize)
test_ds = remaining.skip(valSize)

X_trainShape = (train_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(xNames))
X_valShape = (val_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(xNames))
X_testShape = (test_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(xNames))
y_trainShape = (train_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(yNames))
y_valShape = (val_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(yNames))
y_testShape = (test_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(yNames))
    

# print(samples_array.shape)
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
X_trainShape
# Out:
# (np.int64(70), 60, 20, 5)

# %%
# Define mean and variance for normalization based only on training set
feature_ds = train_ds.take(normalizerLength).map(lambda x, y: x) 
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(feature_ds)
# print(samples_array.shape)

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = np.array(sample.columns.values.tolist())
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]


    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            if i == 0:
               headers, samples = future.result()
            else:
               addSamp = future.result()[1]
               samples = samples.concatenate(addSamp)
            
            
            # if i == 0:
            #     headers_list = headers  # Use headers from the first file
            #     samples_list = result
            #     # samples_list = tf.data.experimental.from_list(result)
            # else:
            #     # tmp = tf.data.experimental.from_list(result)
            #     # tmp = result
            #   samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers, samples

headers, samples = load_all_samples(trainDat_path, numSamples)


samples = samples.shuffle(buffer_size=len(samples)) # Shuffle set
train_ds = samples.take(train_length)
remaining = samples.skip(train_length)
val_ds = remaining.take(valSize)
test_ds = remaining.skip(valSize)

X_trainShape = (train_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(xNames))
X_valShape = (val_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(xNames))
X_testShape = (test_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(xNames))
y_trainShape = (train_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(yNames))
y_valShape = (val_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(yNames))
y_testShape = (test_ds.cardinality().numpy(),sampleShape[0],sampleShape[1],len(yNames))
    


# Define mean and variance for normalization based only on training set
feature_ds = train_ds.take(normalizerLength).map(lambda x, y: x) 
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(feature_ds)
# print(samples_array.shape)

# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
# if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
#    train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Test preprocessing
test_ds = test_ds.cache() # cache dataset for it to be used over iterations
test_ds = test_ds.shuffle(buffer_size = len(test_ds)).batch(batchSize)
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
# for i,file in enumerate(os.listdir(trainDat_path)):
#     print('Now loading file number {num} out of {total}'.format(num = i, total = numSamples))
#     filepath = os.path.join(trainDat_path,file)
#     if i==0:
#         headers, samples = loadSample(filepath)
#         samples = samples.reshape(1, np.shape(samples)[0],np.shape(samples)[1])
#     else:
#         addSamp = loadSample(filepath)[1]
#         samples = np.concatenate((samples,addSamp.reshape(1, np.shape(addSamp)[0],np.shape(addSamp)[1])))
# samples_NonStandard = samples
# samples, scaler = normalise(samples.reshape(samples.shape[0]*samples.shape[1],-1),params) # retain the scaler parameters such that inverse scaling can be done
# means = scaler.mean_ # Will have 1 value for each feature in the data
# std = np.sqrt(scaler.var_)
# Reshape sample variable to have shape (samples, row, column, features)
# samples2D = samples.reshape(numSamples,sampleShape[0],sampleShape[1],samples.shape[-1])

# # Find indeces of input features 
# featureIdx = []
# for name in xNames:
#    featureIdx += [np.where(headers == name)[0][0]]

# # Find indeces of ground truth features 
# gtIdx = []
# for name in yNames:
#    gtIdx += [np.where(headers == name)[0][0]]

# X = samples2D[:,:,:,featureIdx]  # Input features

# Y = samples2D[:,:,:,gtIdx] # Labels

# # The below are just used for validation and shape (TODO: replace validation method with tf tensors)
# X_train, X_val, y_train, y_val = sklearn.model_selection.train_test_split(X, Y, train_size=trainValRatio, shuffle = True)
# X_trainShape = X_train.shape
# X_valShape = X_val.shape
# y_trainShape = y_train.shape
# y_valShape = y_val.shape


# # Standardisation/normalisation
# if params['standardisation'] == 'MinMax':
#     Xscaler = preprocessing.MinMaxScaler() # Do a scaler for the in and outputs separately (to be able to inversely standardise predictions)
#     Yscaler = preprocessing.MinMaxScaler() # Note: these shoud be fit to the training data and applied without fitting to the validation data to avoid data leakage
# elif params['standardisation'] == 'Standard':
#     Xscaler = preprocessing.StandardScaler() # Default is scale by mean and divide by std
#     Yscaler = preprocessing.StandardScaler()
# elif params['standardisation'] == 0:
#    print('Warning: no standardisation of data applied')
# if params['standardisation'] != 0:
#     Xscaler.fit(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1)) # Scaler only takes input of shape (data,features)
#     X_train = Xscaler.transform(X_train.reshape(X_train.shape[0]*X_train.shape[1]*X_train.shape[2],-1))
#     X_train = X_train.reshape(X_trainShape) # reshape to 2D samples
#     X_val = Xscaler.transform(X_val.reshape(X_val.shape[0]*X_val.shape[1]*X_val.shape[2],-1))
#     X_val = X_val.reshape(X_valShape)

#     Yscaler.fit(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
#     y_train = Yscaler.transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
#     y_train = y_train.reshape(y_trainShape) # reshape to 2D samples
#     y_val = Yscaler.transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
#     y_val = y_val.reshape(y_valShape)

# # Create tensor datasets
# train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)) 
# val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)) 



# # Training preprocessing
# train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
# train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
# train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
# if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
#    train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
# train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# # Validation preprocessing
# val_ds = val_ds.cache() # cache dataset for it to be used over iterations
# val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
# val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared


# Get shapes for later use
# train_in_shape = X_train.shape
# val_in_shape = X_val.shape
# train_out_shape = y_train.shape
# val_out_shape = y_val.shape

# Currently there's a bug where we need to define the shape manually...
# def set_shapes(image, label):
#     image.set_shape((batchSize,train_in_shape[1],train_in_shape[2],train_in_shape[3]))
#     label.set_shape((batchSize,train_out_shape[1],train_out_shape[2],train_out_shape[3]))
#     return image, label


# train_ds = train_ds.map(set_shapes)
# val_ds = val_ds.map(set_shapes)

# %%
#####################################################################
# CNN Model definition
#####################################################################

def TBDCNet_modelCNN(inputShape, outputShape, params):
  '''
  This function returns a model based on the hyperparameters in the
  sweep definition

  Args
  ----------
  inputShape: the 55x20x3 input image shape
  outputShape: the prediction image shape (currently unused)
  params: The hyperparameters for the given sweep index

  Returns
  ----------
  model: tensorflow model

  '''
  # Kernel regularizer (both linear and quadratic)
  if params['L1kernel_regularizer'] > 0 and params['L2kernel_regularizer'] > 0: 
     regularizer = tf.keras.regularizers.L1L2(l1=params['L1kernel_regularizer'], l2=params['L2kernel_regularizer'])
  elif params['L1kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L1(params['L1kernel_regularizer'])
  elif params['L2kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L2(params['L2kernel_regularizer'])
  else:
    regularizer = None

  # Define the model architecture. Each convolutional layer has settings related to the kernel size, 
  # activation function, and regularizer. After each convolutional layer there may be a batch-
  # normalization layer, a max pooling layer, and a dropout layer. The number of convolutional layers
  # is given in the sweep definition


  input = tf.keras.layers.Input(shape=inputShape) # Shape (Long, short, inputs)
  x = input


  x = tf.keras.layers.Conv2D(filters = 32, kernel_size=(int(params['layer1Kernel']), int(params['layer1Kernel'])),activation=params['conv1Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
  if params['batchNorm'] == 1:
    x = tf.keras.layers.BatchNormalization()(x)
  if params['pooling'] == 1:
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
  if params['dropout'] > 0:
    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
  encoder1 = x # Use this if skip connections need to be used


  if params['layer2'] == 1:
    x = tf.keras.layers.Conv2D(filters = 64, kernel_size=(int(params['layer2Kernel']), int(params['layer2Kernel'])),activation=params['conv2Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
    if params['batchNorm'] == 1:
      x = tf.keras.layers.BatchNormalization()(x)
    if params['pooling'] == 1:
       x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
    if params['dropout'] > 0:
       x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
    encoder2 = x
        

    if params['layer3'] == 1:
        x = tf.keras.layers.Conv2D(filters = 128, kernel_size=(int(params['layer3Kernel']), int(params['layer3Kernel'])),activation=params['conv3Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
        if params['batchNorm'] == 1:
           x = tf.keras.layers.BatchNormalization()(x)
        if params['pooling'] == 1:
           x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
        if params['dropout'] > 0:
           x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
        encoder3 = x


        if params['layer4'] == 1:
            x = tf.keras.layers.Conv2D(filters = 256, kernel_size=(int(params['layer4Kernel']), int(params['layer4Kernel'])),activation=params['conv4Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
            if params['batchNorm'] == 1:
                x = tf.keras.layers.BatchNormalization()(x)
            if params['pooling'] == 1:
                x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
            if params['dropout'] > 0:
                x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
            encoder4 = x


            if params['layer5'] == 1:
                x = tf.keras.layers.Conv2D(filters = 512, kernel_size=(int(params['layer5Kernel']), int(params['layer5Kernel'])),activation=params['conv5Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                if params['batchNorm'] == 1:
                    x = tf.keras.layers.BatchNormalization()(x)
                if params['pooling'] == 1:
                    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                if params['dropout'] > 0:
                    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                encoder5 = x


                if params['layer6'] == 1:
                    x = tf.keras.layers.Conv2D(filters = 1024, kernel_size=(int(params['layer6Kernel']), int(params['layer6Kernel'])),activation=params['conv6Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                    if params['batchNorm'] == 1:
                        x = tf.keras.layers.BatchNormalization()(x)
                    if params['pooling'] == 1:
                        x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                    if params['dropout'] > 0:
                        x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                    encoder6 = x

                    if params['ActivationUp'] == 0:
                       temp_activation = 'linear'
                    else:
                       temp_activation = params['conv6Activation']

                    x = tf.keras.layers.Conv2DTranspose(filters = 512, kernel_size = (int(params['layer6Kernel']),int(params['layer6Kernel'])),  padding='same',activation=temp_activation)(x)
                    if params['skipConnections'] == 1:
                      x = tf.keras.layers.Concatenate()([x, encoder5])


                if params['ActivationUp'] == 0:
                    temp_activation = 'linear'
                else:
                    temp_activation = params['conv5Activation']

                x = tf.keras.layers.Conv2DTranspose(filters = 256, kernel_size = (int(params['layer5Kernel']),int(params['layer5Kernel'])),  padding='same',activation=temp_activation)(x)
                if params['skipConnections'] == 1:
                  x = tf.keras.layers.Concatenate()([x, encoder4])
            
            
            if params['type'] == 'dense':
              y = tf.keras.layers.Flatten()(x)
              y = tf.keras.layers.Dense(64, activation='relu')(y)
              y = tf.keras.layers.Dense(outputShape[0]*outputShape[1])(y)
              y = tf.keras.layers.Reshape(outputShape)(y)

            if params['ActivationUp'] == 0:
                temp_activation = 'linear'
            else:
                temp_activation = params['conv4Activation']
            
            x = tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (int(params['layer4Kernel']),int(params['layer4Kernel'])),  padding='same',activation=temp_activation)(x)
            if params['skipConnections'] == 1:
              x = tf.keras.layers.Concatenate()([x, encoder3])

        if params['ActivationUp'] == 0:
            temp_activation = 'linear'
        else:
            temp_activation = params['conv3Activation']
        
        x = tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (int(params['layer3Kernel']),int(params['layer3Kernel'])),  padding='same',activation=temp_activation)(x)
        if params['skipConnections'] == 1:
          x = tf.keras.layers.Concatenate()([x, encoder2])

    if params['ActivationUp'] == 0:
        temp_activation = 'linear'
    else:
        temp_activation = params['conv2Activation']
    
    x = tf.keras.layers.Conv2DTranspose(filters = 32, kernel_size = (int(params['layer2Kernel']),int(params['layer2Kernel'])),  padding='same',activation=temp_activation)(x)
    if params['skipConnections'] == 1:
      x = tf.keras.layers.Concatenate()([x, encoder1])

   # Custom activation function is linear between 0 and 1 and otherwise constant
  def custom_activation(x):
      return tf.math.minimum(K.relu(x), 1)

  x = tf.keras.layers.Conv2DTranspose(filters = 1, kernel_size = (int(params['layer1Kernel']),int(params['layer1Kernel'])),  padding='same',activation='linear')(x)

  if params['type'] == 'dense': # For the dense model we jsut pull the output y
     output = y
  else:
    output = x

  model = tf.keras.Model(inputs=input, outputs=output) # Create model

  # Default initial learning rate is 0.001. If the the decay rate is 1 this will be held constant.
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=params['initial_lr'],
    decay_steps=steps_per_epoch*epochs,
    decay_rate=params['lr_decay_rate'])

  def custom_loss(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.nn.relu(y_true))))
    loss = tf.reduce_mean(loss)
    return loss
  
  def custom_loss5(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.math.multiply(tf.nn.relu(y_true),5))))
    loss = tf.reduce_mean(loss)
    return loss

  def peak_loss(y_true,y_pred):
    peakVal = tf.reduce_max(y_true, keepdims=True)
    cond = tf.equal(y_true, peakVal)
    # peakLoc = tf.where(cond)
    # peakLoc_1d = tf.squeeze(peakLoc)
    errorGrid = tf.math.subtract(y_true,y_pred)
    zeroGrid = tf.math.subtract(y_true,y_true) # Grid of zeros so we only get loss in peak location
    # peakPred = y_pred[peakLoc_1d.numpy()[0]]
    # peakPred = tf.slice(y_pred, peakLoc, [1,1])
    loss = tf.where(cond, errorGrid, zeroGrid)
    loss = tf.reduce_mean(loss)

    # loss = peakPred-peakVal
    return loss


#   Loss functions can be swept
  if params['loss'] == 'MSE':
    lossfunc = tf.keras.losses.MeanSquaredError()
  elif params['loss'] == 'MAE':
    lossfunc = tf.keras.losses.MeanAbsoluteError()
  elif params['loss'] == 'Custom':
    lossfunc = custom_loss
  elif params['loss'] == 'Peak':
    lossfunc = peak_loss
  elif params['loss'] == 'Custom5':
    lossfunc = custom_loss5
    



  # Compile model with the optimizer in the sweep definition
  if params['optimizer'] == 'Adadelta':
     model.compile(optimizer=tf.keras.optimizers.Adadelta(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  elif params['optimizer'] == 'Nadam':
     model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  else:
     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])

  return model

# %%
#####################################################################
# Training callbacks
#####################################################################

# Checkpoints to allow saving best model at various points
# checkpoint_path = 'training_checkpoints_{jn}_{num}/cp.ckpt'.format(jn='TESTJOB', num = 1)
checkpoint_path = 'training_checkpoints_{jn}_{num}/model.weights.h5'.format(jn='TESTJOB', num = 1)
checkpoint_dir = os.path.dirname(checkpoint_path)

try:
  os.mkdir(checkpoint_dir) # Make checkpoint directory
except:
  pass

# Save best weights to checkpoint
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_best_only = True,
                                                 monitor = 'val_loss',
                                                 verbose=1)

# Early stopping callback which monitors improvements and stops training if
# it stagnates.
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', # Monitor validation loss
    min_delta=0, # Minimum improvement to consider an improvement
    patience=60, # Number of epochs with no improvement before stopping training
    verbose=1, # Records message when earlystopping
    mode='auto',
    baseline=None, 
    restore_best_weights=False # Do not restore best weights after early stopping, we do this manually to allow recording of the full training history
)

# %%
#####################################################################
# Training callbacks
#####################################################################

# Checkpoints to allow saving best model at various points
# checkpoint_path = 'training_checkpoints_{jn}_{num}/cp.ckpt'.format(jn='TESTJOB', num = 1)
checkpoint_path = 'training_checkpoints_{jn}_{num}/model.weights.h5'.format(jn='TESTJOB', num = 1)
checkpoint_dir = os.path.dirname(checkpoint_path)

try:
  os.mkdir(checkpoint_dir) # Make checkpoint directory
except:
  pass

# Save best weights to checkpoint
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_best_only = True,
                                                 monitor = 'val_loss',
                                                 verbose=1)

# Early stopping callback which monitors improvements and stops training if
# it stagnates.
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', # Monitor validation loss
    min_delta=0, # Minimum improvement to consider an improvement
    patience=60, # Number of epochs with no improvement before stopping training
    verbose=1, # Records message when earlystopping
    mode='auto',
    baseline=None, 
    restore_best_weights=False # Do not restore best weights after early stopping, we do this manually to allow recording of the full training history
)

# %%
#####################################################################
# Model instantiation
#####################################################################

tf.keras.backend.clear_session() # Clear the state and frees up memory

# CNN Model creation
modelCNN = TBDCNet_modelCNN(inputShape = train_in_shape[1:], outputShape = train_out_shape[1:], params = params)
modelCNNname = 'CNNModel1'

# %%
#####################################################################
# Model training
#####################################################################

# Known issue: sometimes throws error related to the shape of the labels...
# Fit model to Failure index
modelCNN_history = modelCNN.fit(train_ds,
                                epochs=epochs,
                                steps_per_epoch=steps_per_epoch,
                                validation_data=val_ds,
                                validation_steps = validation_steps,
                                callbacks=[early_stopping_monitor, cp_callback]
                                )
# Out:
# Epoch 1/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 340884608.0000 - mean_absolute_error: 13504.5820 - mean_squared_error: 340884608.0000
# Epoch 1: val_loss improved from inf to 38822384.00000, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - loss: 326363648.0000 - mean_absolute_error: 13084.8809 - mean_squared_error: 326363648.0000 - val_loss: 38822384.0000 - val_mean_absolute_error: 5456.7544 - val_mean_squared_error: 38822376.0000
# Epoch 2/1000
# 2/8 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 86193128.0000 - mean_absolute_error: 7360.5205 - mean_squared_error: 86193120.0000
# c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 59821564.0000 - mean_absolute_error: 6040.0889 - mean_squared_error: 59821560.0000
# Epoch 2: val_loss improved from 38822384.00000 to 8081792.00000, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 58062688.0000 - mean_absolute_error: 5948.5928 - mean_squared_error: 58062684.0000 - val_loss: 8081792.0000 - val_mean_absolute_error: 2314.6790 - val_mean_squared_error: 8081792.0000
# Epoch 3/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 16732687.0000 - mean_absolute_error: 3223.6750 - mean_squared_error: 16732687.0000
# Epoch 3: val_loss improved from 8081792.00000 to 3482918.50000, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 16823068.0000 - mean_absolute_error: 3228.8960 - mean_squared_error: 16823068.0000 - val_loss: 3482918.5000 - val_mean_absolute_error: 1465.7140 - val_mean_squared_error: 3482918.5000
# Epoch 4/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 13823788.0000 - mean_absolute_error: 2889.2217 - mean_squared_error: 13823788.0000
# Epoch 4: val_loss improved from 3482918.50000 to 2103152.00000, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 13658021.0000 - mean_absolute_error: 2868.7854 - mean_squared_error: 13658021.0000 - val_loss: 2103152.0000 - val_mean_absolute_error: 1138.0129 - val_mean_squared_error: 2103152.2500
# Epoch 5/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 8743946.0000 - mean_absolute_error: 2291.9636 - mean_squared_error: 8743946.0000
# Epoch 5: val_loss did not improve from 2103152.00000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 8786162.0000 - mean_absolute_error: 2300.6089 - mean_squared_error: 8786162.0000 - val_loss: 2237474.5000 - val_mean_absolute_error: 1197.9557 - val_mean_squared_error: 2237474.2500
# Epoch 6/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 6705049.0000 - mean_absolute_error: 1996.0638 - mean_squared_error: 6705049.5000
# Epoch 6: val_loss improved from 2103152.00000 to 1538541.12500, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 6684548.0000 - mean_absolute_error: 1994.7659 - mean_squared_error: 6684548.0000 - val_loss: 1538541.1250 - val_mean_absolute_error: 978.7872 - val_mean_squared_error: 1538541.1250
# Epoch 7/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 5282133.5000 - mean_absolute_error: 1803.7825 - mean_squared_error: 5282133.5000
# Epoch 7: val_loss improved from 1538541.12500 to 1322535.25000, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 5309651.5000 - mean_absolute_error: 1809.1399 - mean_squared_error: 5309651.5000 - val_loss: 1322535.2500 - val_mean_absolute_error: 904.6365 - val_mean_squared_error: 1322535.2500
# Epoch 8/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 5598960.5000 - mean_absolute_error: 1860.6008 - mean_squared_error: 5598960.0000
# Epoch 8: val_loss did not improve from 1322535.25000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 5520603.0000 - mean_absolute_error: 1846.8717 - mean_squared_error: 5520602.5000 - val_loss: 1355478.6250 - val_mean_absolute_error: 913.2585 - val_mean_squared_error: 1355478.6250
# Epoch 9/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 5669467.0000 - mean_absolute_error: 1864.4341 - mean_squared_error: 5669467.5000
# Epoch 9: val_loss did not improve from 1322535.25000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 5626220.0000 - mean_absolute_error: 1856.7637 - mean_squared_error: 5626220.5000 - val_loss: 1345630.8750 - val_mean_absolute_error: 901.8212 - val_mean_squared_error: 1345630.8750
# Epoch 10/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 3914190.2500 - mean_absolute_error: 1529.8920 - mean_squared_error: 3914190.2500
# Epoch 10: val_loss improved from 1322535.25000 to 1149012.25000, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 3932391.0000 - mean_absolute_error: 1534.0734 - mean_squared_error: 3932391.0000 - val_loss: 1149012.2500 - val_mean_absolute_error: 840.1473 - val_mean_squared_error: 1149012.1250
# Epoch 11/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 5972828.0000 - mean_absolute_error: 1846.3627 - mean_squared_error: 5972828.0000
# Epoch 11: val_loss improved from 1149012.25000 to 1110308.62500, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[66], line 8
#       1 #%%
#       2 #####################################################################
#       3 # Model training
#    (...)
#       6 # Known issue: sometimes throws error related to the shape of the labels...
#       7 # Fit model to Failure index
# ----> 8 modelCNN_history = modelCNN.fit(train_ds,
#       9                                 epochs=epochs,
#      10                                 steps_per_epoch=steps_per_epoch,
#      11                                 validation_data=val_ds,
#      12                                 validation_steps = validation_steps,
#      13                                 callbacks=[early_stopping_monitor, cp_callback]
#      14                                 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\h5py\_hl\files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\h5py\_hl\files.py:241, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     239     fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     240 elif mode == 'w':
# --> 241     fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     242 elif mode == 'a':
#     243     # Open in append mode (read/write).
#     244     # If that fails, create a new file only if it won't clobber an
#     245     # existing one (ACC_EXCL)
#     246     try:
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:122, in h5py.h5f.create()
#
# PermissionError: [Errno 13] Unable to synchronously create file (unable to open file: name = 'training_checkpoints_TESTJOB_1/model.weights.h5', errno = 13, error message = 'Permission denied', flags = 13, o_flags = 302)

# %%
#####################################################################
# Model training
#####################################################################

# Known issue: sometimes throws error related to the shape of the labels...
# Fit model to Failure index
modelCNN_history = modelCNN.fit(train_ds,
                                epochs=epochs,
                                steps_per_epoch=steps_per_epoch,
                                validation_data=val_ds,
                                validation_steps = validation_steps,
                                callbacks=[early_stopping_monitor, cp_callback]
                                )
# Out:
# Epoch 1/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 4260719.5000 - mean_absolute_error: 1593.6301 - mean_squared_error: 4260719.5000
# Epoch 1: val_loss improved from 1110308.62500 to 1044715.31250, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 4201183.5000 - mean_absolute_error: 1583.4513 - mean_squared_error: 4201183.5000 - val_loss: 1044715.3125 - val_mean_absolute_error: 802.3716 - val_mean_squared_error: 1044715.4375
# Epoch 2/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 3208759.2500 - mean_absolute_error: 1399.3485 - mean_squared_error: 3208759.5000
# Epoch 2: val_loss did not improve from 1044715.31250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 3195450.7500 - mean_absolute_error: 1395.9207 - mean_squared_error: 3195451.0000 - val_loss: 1356828.6250 - val_mean_absolute_error: 921.4048 - val_mean_squared_error: 1356828.6250
# Epoch 3/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 2868123.2500 - mean_absolute_error: 1299.7269 - mean_squared_error: 2868123.2500
# Epoch 3: val_loss did not improve from 1044715.31250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2848464.0000 - mean_absolute_error: 1295.9989 - mean_squared_error: 2848463.7500 - val_loss: 1330386.3750 - val_mean_absolute_error: 912.5291 - val_mean_squared_error: 1330386.3750
# Epoch 4/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 2728287.7500 - mean_absolute_error: 1313.5205 - mean_squared_error: 2728287.5000
# Epoch 4: val_loss improved from 1044715.31250 to 954178.68750, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 2733450.2500 - mean_absolute_error: 1314.0961 - mean_squared_error: 2733450.0000 - val_loss: 954178.6875 - val_mean_absolute_error: 771.8109 - val_mean_squared_error: 954178.6875
# Epoch 5/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 2790986.0000 - mean_absolute_error: 1310.9075 - mean_squared_error: 2790985.7500
# Epoch 5: val_loss improved from 954178.68750 to 949048.00000, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 2807364.2500 - mean_absolute_error: 1315.8785 - mean_squared_error: 2807364.2500 - val_loss: 949048.0000 - val_mean_absolute_error: 772.5677 - val_mean_squared_error: 949048.0000
# Epoch 6/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 2373147.2500 - mean_absolute_error: 1205.6525 - mean_squared_error: 2373147.7500
# Epoch 6: val_loss improved from 949048.00000 to 918851.31250, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 2369215.2500 - mean_absolute_error: 1204.0286 - mean_squared_error: 2369215.5000 - val_loss: 918851.3125 - val_mean_absolute_error: 756.0901 - val_mean_squared_error: 918851.3125
# Epoch 7/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 2764467.7500 - mean_absolute_error: 1283.0204 - mean_squared_error: 2764467.5000
# Epoch 7: val_loss did not improve from 918851.31250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2747992.5000 - mean_absolute_error: 1279.1199 - mean_squared_error: 2747992.5000 - val_loss: 938966.6250 - val_mean_absolute_error: 764.3575 - val_mean_squared_error: 938966.5625
# Epoch 8/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 2661618.0000 - mean_absolute_error: 1252.6085 - mean_squared_error: 2661617.7500
# Epoch 8: val_loss improved from 918851.31250 to 885429.62500, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 2685226.5000 - mean_absolute_error: 1259.8164 - mean_squared_error: 2685226.5000 - val_loss: 885429.6250 - val_mean_absolute_error: 746.4686 - val_mean_squared_error: 885429.6250
# Epoch 9/1000
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 2448203.5000 - mean_absolute_error: 1237.4667 - mean_squared_error: 2448203.5000
# Epoch 9: val_loss did not improve from 885429.62500
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss:
saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 378227.0625 - mean_absolute_error: 480.4986 - mean_squared_error: 378227.0625 - val_loss: 168864.8438 - val_mean_absolute_error: 325.4733 - val_mean_squared_error: 168864.8594
# Epoch 113/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 348439.5312 - mean_absolute_error: 458.7630 - mean_squared_error: 348439.5312
# Epoch 113: val_loss did not improve from 168864.84375
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 351460.8750 - mean_absolute_error: 460.1163 - mean_squared_error: 351460.8750 - val_loss: 172241.5625 - val_mean_absolute_error: 329.1580 - val_mean_squared_error: 172241.5312
# Epoch 114/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 341467.2812 - mean_absolute_error: 456.1013 - mean_squared_error: 341467.2500
# Epoch 114: val_loss did not improve from 168864.84375
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 340454.6875 - mean_absolute_error: 455.3221 - mean_squared_error: 340454.6875 - val_loss: 171631.6562 - val_mean_absolute_error: 329.0296 - val_mean_squared_error: 171631.6406
# Epoch 115/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 306866.1250 - mean_absolute_error: 434.4333 - mean_squared_error: 306866.1250
# Epoch 115: val_loss did not improve from 168864.84375
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 307812.5625 - mean_absolute_error: 435.0406 - mean_squared_error: 307812.5312 - val_loss: 196230.0312 - val_mean_absolute_error: 354.5120 - val_mean_squared_error: 196230.0312
# Epoch 116/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 330456.1562 - mean_absolute_error: 448.8269 - mean_squared_error: 330456.1562
# Epoch 116: val_loss did not improve from 168864.84375
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 329742.1875 - mean_absolute_error: 448.3562 - mean_squared_error: 329742.2188 - val_loss: 171379.0625 - val_mean_absolute_error: 326.3069 - val_mean_squared_error: 171379.0625
# Epoch 117/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 356671.5000 - mean_absolute_error: 468.4483 - mean_squared_error: 356671.5000
# Epoch 117: val_loss improved from 168864.84375 to 166472.00000, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 353680.5938 - mean_absolute_error: 466.4036 - mean_squared_error: 353680.5938 - val_loss: 166472.0000 - val_mean_absolute_error: 322.1042 - val_mean_squared_error: 166471.9688
# Epoch 118/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 338189.0938 - mean_absolute_error: 450.7544 - mean_squared_error: 338189.0938
# Epoch 118: val_loss improved from 166472.00000 to 162162.29688, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 336544.3750 - mean_absolute_error: 449.7297 - mean_squared_error: 336544.3750 - val_loss: 162162.2969 - val_mean_absolute_error: 318.3130 - val_mean_squared_error: 162162.2812
# Epoch 119/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 335150.7188 - mean_absolute_error: 445.1289 - mean_squared_error: 335150.7500
# Epoch 119: val_loss did not improve from 162162.29688
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 335976.3750 - mean_absolute_error: 445.6972 - mean_squared_error: 335976.4062 - val_loss: 164567.7969 - val_mean_absolute_error: 320.0785 - val_mean_squared_error: 164567.8125
# Epoch 120/1000
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 299647.0625 - mean_absolute_error: 426.9401 - mean_squared_error: 299647.0312
# Epoch 120: val_loss improved from 162162.29688 to 156652.23438, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 301224.5312 - mean_absolute_error: 427.9796 - mean_squared_error: 301224.5312 - val_loss: 156652.2344 - val_mean_absolute_error: 313.7552 - val_mean_squared_error: 156652.2344
# Epoch 121/1000
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 384525.0000 - mean_absolute_error: 477.7759 - mean_squared_error: 384525.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 8
#       1 #%%
#       2 #####################################################################
#       3 # Model training
#    (...)
#       6 # Known issue: sometimes throws error related to the shape of the labels...
#       7 # Fit model to Failure index
# ----> 8 modelCNN_history = modelCNN.fit(train_ds,
#       9                                 epochs=epochs,
#      10                                 steps_per_epoch=steps_per_epoch,
#      11                                 validation_data=val_ds,
#      12                                 validation_steps = validation_steps,
#      13                                 callbacks=[early_stopping_monitor, cp_callback]
#      14                                 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:368, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     366 for step, iterator in epoch_iterator:
#     367     callbacks.on_train_batch_begin(step)
# --> 368     logs = self.train_function(iterator)
#     369     callbacks.on_train_batch_end(step, logs)
#     370     if self.stop_training:
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:216, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     212 def function(iterator):
#     213     if isinstance(
#     214         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     215     ):
# --> 216         opt_outputs = multi_step_on_iterator(iterator)
#     217         if not opt_outputs.has_value():
#     218             raise StopIteration
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#####################################################################
# CNN Model definition
#####################################################################

def TBDCNet_modelCNN(inputShape, outputShape, params):
  '''
  This function returns a model based on the hyperparameters in the
  sweep definition

  Args
  ----------
  inputShape: the 55x20x3 input image shape
  outputShape: the prediction image shape (currently unused)
  params: The hyperparameters for the given sweep index

  Returns
  ----------
  model: tensorflow model

  '''
  # Kernel regularizer (both linear and quadratic)
  if params['L1kernel_regularizer'] > 0 and params['L2kernel_regularizer'] > 0: 
     regularizer = tf.keras.regularizers.L1L2(l1=params['L1kernel_regularizer'], l2=params['L2kernel_regularizer'])
  elif params['L1kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L1(params['L1kernel_regularizer'])
  elif params['L2kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L2(params['L2kernel_regularizer'])
  else:
    regularizer = None

  # Define the model architecture. Each convolutional layer has settings related to the kernel size, 
  # activation function, and regularizer. After each convolutional layer there may be a batch-
  # normalization layer, a max pooling layer, and a dropout layer. The number of convolutional layers
  # is given in the sweep definition


  input = tf.keras.layers.Input(shape=inputShape) # Shape (Long, short, inputs)
  x = normalizer(input)
  if params['dsAugmentation'] == 1:
    x = tf.keras.layers.RandomFlip(mode="horizontal_and_vertical", seed=seed)(x)


  x = tf.keras.layers.Conv2D(filters = 32, kernel_size=(int(params['layer1Kernel']), int(params['layer1Kernel'])),activation=params['conv1Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
  if params['batchNorm'] == 1:
    x = tf.keras.layers.BatchNormalization()(x)
  if params['pooling'] == 1:
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
  if params['dropout'] > 0:
    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
  encoder1 = x # Use this if skip connections need to be used


  if params['layer2'] == 1:
    x = tf.keras.layers.Conv2D(filters = 64, kernel_size=(int(params['layer2Kernel']), int(params['layer2Kernel'])),activation=params['conv2Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
    if params['batchNorm'] == 1:
      x = tf.keras.layers.BatchNormalization()(x)
    if params['pooling'] == 1:
       x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
    if params['dropout'] > 0:
       x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
    encoder2 = x
        

    if params['layer3'] == 1:
        x = tf.keras.layers.Conv2D(filters = 128, kernel_size=(int(params['layer3Kernel']), int(params['layer3Kernel'])),activation=params['conv3Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
        if params['batchNorm'] == 1:
           x = tf.keras.layers.BatchNormalization()(x)
        if params['pooling'] == 1:
           x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
        if params['dropout'] > 0:
           x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
        encoder3 = x


        if params['layer4'] == 1:
            x = tf.keras.layers.Conv2D(filters = 256, kernel_size=(int(params['layer4Kernel']), int(params['layer4Kernel'])),activation=params['conv4Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
            if params['batchNorm'] == 1:
                x = tf.keras.layers.BatchNormalization()(x)
            if params['pooling'] == 1:
                x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
            if params['dropout'] > 0:
                x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
            encoder4 = x


            if params['layer5'] == 1:
                x = tf.keras.layers.Conv2D(filters = 512, kernel_size=(int(params['layer5Kernel']), int(params['layer5Kernel'])),activation=params['conv5Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                if params['batchNorm'] == 1:
                    x = tf.keras.layers.BatchNormalization()(x)
                if params['pooling'] == 1:
                    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                if params['dropout'] > 0:
                    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                encoder5 = x


                if params['layer6'] == 1:
                    x = tf.keras.layers.Conv2D(filters = 1024, kernel_size=(int(params['layer6Kernel']), int(params['layer6Kernel'])),activation=params['conv6Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                    if params['batchNorm'] == 1:
                        x = tf.keras.layers.BatchNormalization()(x)
                    if params['pooling'] == 1:
                        x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                    if params['dropout'] > 0:
                        x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                    encoder6 = x

                    if params['ActivationUp'] == 0:
                       temp_activation = 'linear'
                    else:
                       temp_activation = params['conv6Activation']

                    x = tf.keras.layers.Conv2DTranspose(filters = 512, kernel_size = (int(params['layer6Kernel']),int(params['layer6Kernel'])),  padding='same',activation=temp_activation)(x)
                    if params['skipConnections'] == 1:
                      x = tf.keras.layers.Concatenate()([x, encoder5])


                if params['ActivationUp'] == 0:
                    temp_activation = 'linear'
                else:
                    temp_activation = params['conv5Activation']

                x = tf.keras.layers.Conv2DTranspose(filters = 256, kernel_size = (int(params['layer5Kernel']),int(params['layer5Kernel'])),  padding='same',activation=temp_activation)(x)
                if params['skipConnections'] == 1:
                  x = tf.keras.layers.Concatenate()([x, encoder4])
            
            
            if params['type'] == 'dense':
              y = tf.keras.layers.Flatten()(x)
              y = tf.keras.layers.Dense(64, activation='relu')(y)
              y = tf.keras.layers.Dense(outputShape[0]*outputShape[1])(y)
              y = tf.keras.layers.Reshape(outputShape)(y)

            if params['ActivationUp'] == 0:
                temp_activation = 'linear'
            else:
                temp_activation = params['conv4Activation']
            
            x = tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (int(params['layer4Kernel']),int(params['layer4Kernel'])),  padding='same',activation=temp_activation)(x)
            if params['skipConnections'] == 1:
              x = tf.keras.layers.Concatenate()([x, encoder3])

        if params['ActivationUp'] == 0:
            temp_activation = 'linear'
        else:
            temp_activation = params['conv3Activation']
        
        x = tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (int(params['layer3Kernel']),int(params['layer3Kernel'])),  padding='same',activation=temp_activation)(x)
        if params['skipConnections'] == 1:
          x = tf.keras.layers.Concatenate()([x, encoder2])

    if params['ActivationUp'] == 0:
        temp_activation = 'linear'
    else:
        temp_activation = params['conv2Activation']
    
    x = tf.keras.layers.Conv2DTranspose(filters = 32, kernel_size = (int(params['layer2Kernel']),int(params['layer2Kernel'])),  padding='same',activation=temp_activation)(x)
    if params['skipConnections'] == 1:
      x = tf.keras.layers.Concatenate()([x, encoder1])

   # Custom activation function is linear between 0 and 1 and otherwise constant
  def custom_activation(x):
      return tf.math.minimum(K.relu(x), 1)

  x = tf.keras.layers.Conv2DTranspose(filters = 1, kernel_size = (int(params['layer1Kernel']),int(params['layer1Kernel'])),  padding='same',activation='linear')(x)

  if params['type'] == 'dense': # For the dense model we jsut pull the output y
     output = y
  else:
    output = x

  model = tf.keras.Model(inputs=input, outputs=output) # Create model

  # Default initial learning rate is 0.001. If the the decay rate is 1 this will be held constant.
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=params['initial_lr'],
    decay_steps=steps_per_epoch*epochs,
    decay_rate=params['lr_decay_rate'])

  def custom_loss(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.nn.relu(y_true))))
    loss = tf.reduce_mean(loss)
    return loss
  
  def custom_loss5(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.math.multiply(tf.nn.relu(y_true),5))))
    loss = tf.reduce_mean(loss)
    return loss

  def peak_loss(y_true,y_pred):
    peakVal = tf.reduce_max(y_true, keepdims=True)
    cond = tf.equal(y_true, peakVal)
    # peakLoc = tf.where(cond)
    # peakLoc_1d = tf.squeeze(peakLoc)
    errorGrid = tf.math.subtract(y_true,y_pred)
    zeroGrid = tf.math.subtract(y_true,y_true) # Grid of zeros so we only get loss in peak location
    # peakPred = y_pred[peakLoc_1d.numpy()[0]]
    # peakPred = tf.slice(y_pred, peakLoc, [1,1])
    loss = tf.where(cond, errorGrid, zeroGrid)
    loss = tf.reduce_mean(loss)

    # loss = peakPred-peakVal
    return loss


#   Loss functions can be swept
  if params['loss'] == 'MSE':
    lossfunc = tf.keras.losses.MeanSquaredError()
  elif params['loss'] == 'MAE':
    lossfunc = tf.keras.losses.MeanAbsoluteError()
  elif params['loss'] == 'Custom':
    lossfunc = custom_loss
  elif params['loss'] == 'Peak':
    lossfunc = peak_loss
  elif params['loss'] == 'Custom5':
    lossfunc = custom_loss5
    



  # Compile model with the optimizer in the sweep definition
  if params['optimizer'] == 'Adadelta':
     model.compile(optimizer=tf.keras.optimizers.Adadelta(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  elif params['optimizer'] == 'Nadam':
     model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  else:
     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])

  return model

# %%
#####################################################################
# Training callbacks
#####################################################################

# Checkpoints to allow saving best model at various points
# checkpoint_path = 'training_checkpoints_{jn}_{num}/cp.ckpt'.format(jn='TESTJOB', num = 1)
checkpoint_path = 'training_checkpoints_{jn}_{num}/model.weights.h5'.format(jn='TESTJOB', num = 1)
checkpoint_dir = os.path.dirname(checkpoint_path)

try:
  os.mkdir(checkpoint_dir) # Make checkpoint directory
except:
  pass

# Save best weights to checkpoint
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_best_only = True,
                                                 monitor = 'val_loss',
                                                 verbose=1)

# Early stopping callback which monitors improvements and stops training if
# it stagnates.
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', # Monitor validation loss
    min_delta=0, # Minimum improvement to consider an improvement
    patience=60, # Number of epochs with no improvement before stopping training
    verbose=1, # Records message when earlystopping
    mode='auto',
    baseline=None, 
    restore_best_weights=False # Do not restore best weights after early stopping, we do this manually to allow recording of the full training history
)

# %%
#####################################################################
# Model instantiation
#####################################################################

tf.keras.backend.clear_session() # Clear the state and frees up memory

# CNN Model creation
modelCNN = TBDCNet_modelCNN(inputShape = train_in_shape[1:], outputShape = train_out_shape[1:], params = params)
modelCNNname = 'CNNModel1'

# %%
train_in_shape
# Out:
# (90, 60, 20, 5)

# %%
train_out_shape
# Out:
# (90, 60, 20, 1)

# %%
#####################################################################
# Model training
#####################################################################

# Known issue: sometimes throws error related to the shape of the labels...
# Fit model to Failure index
epochs = 80
modelCNN_history = modelCNN.fit(train_ds,
                                epochs=epochs,
                                steps_per_epoch=steps_per_epoch,
                                validation_data=val_ds,
                                validation_steps = validation_steps,
                                callbacks=[early_stopping_monitor, cp_callback]
                                )
# Out:
# Epoch 1/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.2744 - mean_absolute_error: 0.4116 - mean_squared_error: 0.2744
# Epoch 1: val_loss improved from inf to 0.05545, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - loss: 0.2630 - mean_absolute_error: 0.4012 - mean_squared_error: 0.2630 - val_loss: 0.0555 - val_mean_absolute_error: 0.1853 - val_mean_squared_error: 0.0555
# Epoch 2/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0800 - mean_absolute_error: 0.2226 - mean_squared_error: 0.0800
# Epoch 2: val_loss improved from 0.05545 to 0.04188, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0792 - mean_absolute_error: 0.2213 - mean_squared_error: 0.0792 - val_loss: 0.0419 - val_mean_absolute_error: 0.1595 - val_mean_squared_error: 0.0419
# Epoch 3/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0590 - mean_absolute_error: 0.1925 - mean_squared_error: 0.0590
# Epoch 3: val_loss improved from 0.04188 to 0.03465, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0586 - mean_absolute_error: 0.1918 - mean_squared_error: 0.0586 - val_loss: 0.0347 - val_mean_absolute_error: 0.1452 - val_mean_squared_error: 0.0347
# Epoch 4/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0474 - mean_absolute_error: 0.1716 - mean_squared_error: 0.0474
# Epoch 4: val_loss improved from 0.03465 to 0.03363, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0473 - mean_absolute_error: 0.1714 - mean_squared_error: 0.0473 - val_loss: 0.0336 - val_mean_absolute_error: 0.1429 - val_mean_squared_error: 0.0336
# Epoch 5/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0450 - mean_absolute_error: 0.1677 - mean_squared_error: 0.0450
# Epoch 5: val_loss improved from 0.03363 to 0.02590, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0449 - mean_absolute_error: 0.1675 - mean_squared_error: 0.0449 - val_loss: 0.0259 - val_mean_absolute_error: 0.1262 - val_mean_squared_error: 0.0259
# Epoch 6/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.
80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0171 - mean_absolute_error: 0.1046 - mean_squared_error: 0.0171
# Epoch 71: val_loss did not improve from 0.01252
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0170 - mean_absolute_error: 0.1043 - mean_squared_error: 0.0170 - val_loss: 0.0132 - val_mean_absolute_error: 0.0922 - val_mean_squared_error: 0.0132
# Epoch 72/80
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0160 - mean_absolute_error: 0.1011 - mean_squared_error: 0.0160
# Epoch 72: val_loss did not improve from 0.01252
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0159 - mean_absolute_error: 0.1007 - mean_squared_error: 0.0159 - val_loss: 0.0134 - val_mean_absolute_error: 0.0926 - val_mean_squared_error: 0.0134
# Epoch 73/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0152 - mean_absolute_error: 0.0973 - mean_squared_error: 0.0152
# Epoch 73: val_loss did not improve from 0.01252
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0152 - mean_absolute_error: 0.0972 - mean_squared_error: 0.0152 - val_loss: 0.0135 - val_mean_absolute_error: 0.0936 - val_mean_squared_error: 0.0135
# Epoch 74/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0158 - mean_absolute_error: 0.0987 - mean_squared_error: 0.0158
# Epoch 74: val_loss did not improve from 0.01252
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 0.0157 - mean_absolute_error: 0.0986 - mean_squared_error: 0.0157 - val_loss: 0.0128 - val_mean_absolute_error: 0.0906 - val_mean_squared_error: 0.0128
# Epoch 75/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0141 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0141
# Epoch 75: val_loss did not improve from 0.01252
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0141 - mean_absolute_error: 0.0936 - mean_squared_error: 0.0141 - val_loss: 0.0128 - val_mean_absolute_error: 0.0908 - val_mean_squared_error: 0.0128
# Epoch 76/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0156 - mean_absolute_error: 0.0992 - mean_squared_error: 0.0156
# Epoch 76: val_loss did not improve from 0.01252
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0157 - mean_absolute_error: 0.0992 - mean_squared_error: 0.0157 - val_loss: 0.0126 - val_mean_absolute_error: 0.0902 - val_mean_squared_error: 0.0126
# Epoch 77/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0137 - mean_absolute_error: 0.0918 - mean_squared_error: 0.0137
# Epoch 77: val_loss did not improve from 0.01252
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0137 - mean_absolute_error: 0.0919 - mean_squared_error: 0.0137 - val_loss: 0.0126 - val_mean_absolute_error: 0.0901 - val_mean_squared_error: 0.0126
# Epoch 78/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0136 - mean_absolute_error: 0.0932 - mean_squared_error: 0.0136
# Epoch 78: val_loss did not improve from 0.01252
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0137 - mean_absolute_error: 0.0934 - mean_squared_error: 0.0137 - val_loss: 0.0134 - val_mean_absolute_error: 0.0935 - val_mean_squared_error: 0.0134
# Epoch 79/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0177 - mean_absolute_error: 0.1059 - mean_squared_error: 0.0177
# Epoch 79: val_loss did not improve from 0.01252
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0176 - mean_absolute_error: 0.1055 - mean_squared_error: 0.0176 - val_loss: 0.0126 - val_mean_absolute_error: 0.0904 - val_mean_squared_error: 0.0126
# Epoch 80/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0158 - mean_absolute_error: 0.0997 - mean_squared_error: 0.0158
# Epoch 80: val_loss did not improve from 0.01252
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0157 - mean_absolute_error: 0.0991 - mean_squared_error: 0.0157 - val_loss: 0.0147 - val_mean_absolute_error: 0.0982 - val_mean_squared_error: 0.0147

# %%
#####################################################################
# Data export
#####################################################################

trainingHist = modelCNN_history.history # save training history
modelCNN.load_weights(checkpoint_path) # load best model weights

predCNN = modelCNN.predict(X_train) # Make prediction
predCNN_val = modelCNN.predict(X_val) # Prediction of only validation data
predCNNShape = predCNN.shape
predCNN_valShape = predCNN_val.shape

# Inverse standardisation
if params['standardisation'] == 0:
   predCNN_invStandard = predCNN
   predCNN_val_invStandard = predCNN_val
   ground_truth_invStandard = y_train
   ground_truth_val_invStandard = y_val
else:
   predCNN_invStandard = Yscaler.inverse_transform(predCNN.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
   predCNN_invStandard = predCNN_invStandard.reshape(predCNNShape)
   predCNN_val_invStandard = Yscaler.inverse_transform(predCNN_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
   predCNN_val_invStandard = predCNN_val_invStandard.reshape(predCNN_valShape)
   
   ground_truth_invStandard =  Yscaler.inverse_transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
   ground_truth_invStandard = ground_truth_invStandard.reshape(y_trainShape)
   ground_truth_val_invStandard = Yscaler.inverse_transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
   ground_truth_val_invStandard = ground_truth_val_invStandard.reshape(y_valShape)


# RMSE
RMSE = tf.keras.metrics.RootMeanSquaredError()
RMSE.update_state(ground_truth_invStandard,predCNN_invStandard)
print('RMSE for training set = ' + str(RMSE.result().numpy()))
if ground_truth_val_invStandard is not None:
    RMSE_val = tf.keras.metrics.RootMeanSquaredError()
    RMSE_val.update_state(ground_truth_val_invStandard,predCNN_val_invStandard)
    print('RMSE for validation set  = ' + str(RMSE_val.result().numpy()))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 27
#      24 predCNN_val_invStandard = predCNN_val_invStandard.reshape(predCNN_valShape)
#      26 ground_truth_invStandard =  Yscaler.inverse_transform(y_train.reshape(y_train.shape[0]*y_train.shape[1]*y_train.shape[2],-1))
# ---> 27 ground_truth_invStandard = ground_truth_invStandard.reshape(y_trainShape)
#      28 ground_truth_val_invStandard = Yscaler.inverse_transform(y_val.reshape(y_val.shape[0]*y_val.shape[1]*y_val.shape[2],-1))
#      29 ground_truth_val_invStandard = ground_truth_val_invStandard.reshape(y_valShape)
#
# ValueError: cannot reshape array of size 108000 into shape (70,60,20,1)

# %%
X_train
# Out:
# array([[[[-0.83151275,  0.21205913, -0.4318276 , -0.51553869,
#            0.93157901],
#          [-0.93414935, -0.27508131, -0.88684113, -0.9882008 ,
#            0.64666669],
#          [-1.21926482, -0.97858349, -0.0882782 , -0.9882008 ,
#            0.25487987],
#          ...,
#          [ 0.75719071, -1.03335594, -0.14145818, -0.04287658,
#           -1.71563653],
#          [ 1.26446489, -1.09215125,  0.11965353,  0.19345447,
#           -1.94776126],
#          [ 0.07657712, -0.42458795, -0.68149839, -0.51553869,
#           -0.47555984]],
#
#         [[-0.99143953, -0.7548413 , -0.92048695, -1.22453186,
#            0.26193225],
#          [-0.63662948, -0.5841619 ,  0.07809031, -0.51553869,
#            0.06337196],
#          [-0.89742001, -0.3235044 ,  0.45726407, -0.27920764,
#            0.49310323],
#          ...,
#          [ 0.27879436, -1.01213676, -0.81686373, -0.51553869,
#           -1.39555953],
#          [ 1.48609082, -1.47050185,  0.10179512,  0.19345447,
#           -2.50279211],
#          [ 2.07448477, -0.52497725,  0.09849905,  0.66611659,
#           -1.78372042]],
#
#         [[-1.08100735, -0.74536984, -0.40964612, -0.9882008 ,
#            0.31034095],
#          [-1.03630467, -0.86183282,  0.10465976, -0.75186975,
#            0.18911912],
#          [-1.20283351, -0.25209157,  0.60448694, -0.27920764,
#
#         [[-0.65751059, -0.56645513, -0.931032  , -0.9882008 ,
#            0.12939322],
#          [-0.52665824, -0.28460479, -0.78589632, -0.75186975,
#            0.1619444 ],
#          [-0.1598512 , -1.330114  , -0.2111495 , -0.75186975,
#           -1.18815679],
#          ...,
#          [-0.17684975,  0.9262544 ,  0.81145585,  0.66611659,
#            0.74001768],
#          [ 0.34791437,  1.75681042,  1.19557039,  1.37510975,
#            0.79367414],
#          [-0.35401145,  1.23562143,  0.07533245,  0.42978553,
#            1.0268711 ]],
#
#         [[-0.80841174, -0.58874674, -0.79418586, -0.9882008 ,
#            0.27890003],
#          [-0.08255192, -0.57928384, -0.44593511, -0.51553869,
#           -0.40967293],
#          [-0.11898804, -0.71111297, -0.30174387, -0.51553869,
#           -0.49549636],
#          ...,
#          [-0.16672835,  0.47094647,  0.23626676,  0.19345447,
#            0.45582745],
#          [ 0.62007786,  0.28859289,  1.08557206,  0.90244764,
#           -0.37621503],
#          [ 0.07432338,  1.00628152,  0.86147045,  0.90244764,
#            0.40819709]],
#
#         ...,
#
#         [[ 0.89140394,  0.69342761,  0.1093741 ,  0.66611659,
#           -0.16554567],
#          [ 1.15008338,  1.30378893,  0.66495752,  1.37510975,
#           -0.0157856 ],
#          [ 0.31134971,  0.83671936, -0.084751  ,  0.42978553,
#            0.26117661],
#          ...,
#          [-0.76162387, -1.08749817,  0.32760537, -0.51553869,
#           -0.17042366],
#          [-1.03630868, -0.36777905,  0.16709058, -0.51553869,
#            0.69261217],
#          [-1.24180135,  0.00765519, -0.44018977, -0.75186975,
#            1.24099412]],
#
#         [[ 0.01706362,  0.75143757, -0.17649565,  0.19345447,
#            0.4936267 ],
#          [ 1.24418803,  0.60724685,  0.92753137,  1.1387787 ,
#           -0.41521444],
#          [ 1.44275074,  1.95459546,  1.78821815,  2.08410292,
#            0.28474924],
#          ...,
#          [-0.44858439, -0.64747474,  0.74503024, -0.04287658,
#           -0.02773296],
#          [-0.38699444, -0.00663682,  1.23384007,  0.42978553,
#            0.33384445],
#          [-1.01958849,  0.29668496,  0.59007893, -0.04287658,
#            1.12310995]],
#
#         [[ 1.1001431 ,  0.62163448,  0.05588451,  0.66611659,
#           -0.3112472 ],
#          [ 1.72365773,  0.88810785,  0.29787029,  1.1387787 ,
#           -0.49921955],
#          [ 1.78944843,  2.14447665,  1.87142063,  2.32043397,
#            0.1798453 ],
#          ...,
#          [-0.48442623,  0.06844568,  0.86201902,  0.19345447,
#            0.44340515],
#          [-0.48446421,  1.35298163,  1.71285532,  1.1387787 ,
#            1.25687309],
#          [-1.81969202, -0.32767979,  0.63536525, -0.51553869,
#            1.54681419]]]])

# %%
X_trainShape
# Out:
# (np.int64(70), 60, 20, 5)

# %%
type(X_trainShape)
# Out:
# tuple

# %%
X_trainShape[0]
# Out:
# np.int64(70)

# %%
X_trainShape[-1]
# Out:
# 5

# %%
test_ds.cardinality().numpy()
# Out:
# np.int64(2)

# %%
test_ds.cardinality().numpy()[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:1
# ----> 1 test_ds.cardinality().numpy()[0]
#
# IndexError: invalid index to scalar variable.

# %%
np.int64(2)
# Out:
# np.int64(2)

# %%
test_ds.cardinality().numpy().item
# Out:
# <function int64.item>

# %%
test_ds.cardinality().numpy().item()
# Out:
# 2

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = np.array(sample.columns.values.tolist())
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]


    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            if i == 0:
               headers, samples = future.result()
            else:
               addSamp = future.result()[1]
               samples = samples.concatenate(addSamp)
            
            
            # if i == 0:
            #     headers_list = headers  # Use headers from the first file
            #     samples_list = result
            #     # samples_list = tf.data.experimental.from_list(result)
            # else:
            #     # tmp = tf.data.experimental.from_list(result)
            #     # tmp = result
            #   samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers, samples

headers, samples = load_all_samples(trainDat_path, numSamples)


samples = samples.shuffle(buffer_size=len(samples)) # Shuffle set
train_ds = samples.take(train_length)
remaining = samples.skip(train_length)
val_ds = remaining.take(valSize)
test_ds = remaining.skip(valSize)

X_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
y_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
    


# Define mean and variance for normalization based only on training set
feature_ds = train_ds.take(normalizerLength).map(lambda x, y: x) 
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(feature_ds)
# print(samples_array.shape)

# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
# if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
#    train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Test preprocessing
test_ds = test_ds.cache() # cache dataset for it to be used over iterations
test_ds = test_ds.shuffle(buffer_size = len(test_ds)).batch(batchSize)
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
X_trainShape
# Out:
# (70, 60, 20, 5)

# %%
X_trainShape[1:]
# Out:
# (60, 20, 5)

# %%
y_trainShape
# Out:
# (70, 60, 20, 1)

# %%
predCNN = modelCNN.predict(train_ds)
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001549AFC2E80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#    1816/Unknown 43s 23ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:1
# ----> 1 predCNN = modelCNN.predict(train_ds)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:559, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     557 callbacks.on_predict_batch_begin(step)
#     558 data = get_data(iterator)
# --> 559 batch_outputs = self.predict_function(data)
#     560 outputs = append_to_outputs(batch_outputs, outputs)
#     561 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
predCNN_val = modelCNN.predict(val_ds)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
predCNN_val
# Out:
# array([[[[0.40445456],
#          [0.48468256],
#          [0.47207442],
#          ...,
#          [0.63678235],
#          [0.6313215 ],
#          [0.5265768 ]],
#
#         [[0.5074164 ],
#          [0.49416244],
#          [0.526384  ],
#          ...,
#          [0.6969388 ],
#          [0.6404737 ],
#          [0.60510296]],
#
#         [[0.47702625],
#          [0.41493618],
#          [0.5013455 ],
#          ...,
#          [0.6634494 ],
#          [0.66693956],
#          [0.6560907 ]],
#
#         ...,
#
#         [[0.48401415],
#          [0.57555866],
#          [0.5682292 ],
#          ...,
#          [0.54902184],
#          [0.5001404 ],
#          [0.50476927]],
#
#         [[0.4555591 ],
#          [0.5687993 ],
#          [0.5620416 ],
#          ...,
#          [0.54485214],
#          [0.5556819 ],
#          [0.44702607]],
#
#         [[0.37241086],
#          [0.5041265 ],
#          [0.5912343 ],
#          ...,
#          [0.5522561 ],
#          [0.4550719 ],
#          [0.38334063]]],
#
#
#        [[[0.39104238],
#          [0.44733334],
#          [0.49622583],
#          ...,
#          [0.5957806 ],
#          [0.612449  ],
#          [0.47651502]],
#
#         [[0.48805118],
#          [0.4918144 ],
#          [0.614878  ],
#          ...,
#          [0.63774467],
#          [0.6810124 ],
#          [0.6604602 ]],
#
#         [[0.56813014],
#          [0.5954259 ],
#          [0.6343163 ],
#          ...,
#          [0.6028114 ],
#          [0.63274056],
#          [0.6561528 ]],
#
#         ...,
#
#         [[0.5796724 ],
#          [0.60681295],
#          [0.5999257 ],
#          ...,
#          [0.53098613],
#          [0.5477504 ],
#          [0.5413234 ]],
#
#         [[0.4962567 ],
#          [0.5714669 ],
#          [0.56811994],
#          ...,
#          [0.5365441 ],
#          [0.4832522 ],
#          [0.48788446]],
#
#         [[0.41174075],
#          [0.518     ],
#          [0.5195622 ],
#          ...,
#          [0.478707  ],
#          [0.3860617 ],
#          [0.36252472]]],
#
#
#        [[[0.34351757],
#          [0.48426718],
#          [0.53591037],
#          ...,
#          [0.49127775],
#          [0.5320577 ],
#          [0.47755182]],
#
#         [[0.518661  ],
#          [0.5747529 ],
#          [0.5975547 ],
#          ...,
#          [0.6482998 ],
#          [0.60046506],
#          [0.5590455 ]],
#
#         [[0.5839788 ],
#          [0.5858207 ],
#          [0.5405088 ],
#          ...,
#          [0.65125155],
#          [0.5592768 ],
#          [0.56577337]],
#
#         ...,
#
#         [[0.58065575],
#          [0.57899475],
#          [0.5744731 ],
#          ...,
#          [0.6027226 ],
#          [0.57380605],
#          [0.52183014]],
#
#         [[0.54463804],
#          [0.5356758 ],
#          [0.5700313 ],
#          ...,
#          [0.57588303],
#          [0.5757616 ],
#          [0.47352523]],
#
#         [[0.42377535],
#          [0.46968633],
#          [0.5233678 ],
#          ...,
#          [0.5053882 ],
#          [0.4781032 ],
#          [0.39694786]]],
#
#
#        ...,
#
#
#        [[[0.4692357 ],
#          [0.54005426],
#          [0.5972107 ],
#          ...,
#          [0.66155267],
#          [0.5910558 ],
#          [0.5281159 ]],
#
#         [[0.61249024],
#          [0.63031495],
#          [0.6369829 ],
#          ...,
#          [0.6446117 ],
#          [0.594555  ],
#          [0.55856556]],
#
#         [[0.64567786],
#          [0.6445158 ],
#          [0.6436425 ],
#          ...,
#          [0.62776625],
#          [0.5337863 ],
#          [0.5670883 ]],
#
#         ...,
#
#         [[0.46444795],
#          [0.5435903 ],
#          [0.5368203 ],
#          ...,
#          [0.55940175],
#          [0.5322148 ],
#          [0.54129785]],
#
#         [[0.44970703],
#          [0.5564534 ],
#          [0.57217455],
#          ...,
#          [0.6070329 ],
#          [0.57206035],
#          [0.49709016]],
#
#         [[0.3520887 ],
#          [0.49051148],
#          [0.5938316 ],
#          ...,
#          [0.56971407],
#          [0.5318962 ],
#          [0.4254801 ]]],
#
#
#        [[[0.47491318],
#          [0.6600353 ],
#          [0.68335813],
#          ...,
#          [0.54140735],
#          [0.46368515],
#          [0.4696013 ]],
#
#         [[0.5911712 ],
#          [0.660845  ],
#          [0.6762774 ],
#          ...,
#          [0.5983207 ],
#          [0.57946664],
#          [0.5459838 ]],
#
#         [[0.57596457],
#          [0.5831173 ],
#          [0.6158211 ],
#          ...,
#          [0.5226855 ],
#          [0.60136837],
#          [0.62398165]],
#
#         ...,
#
#         [[0.56247985],
#          [0.59259737],
#          [0.5051338 ],
#          ...,
#          [0.55215305],
#          [0.64229345],
#          [0.54727286]],
#
#         [[0.49824962],
#          [0.5156209 ],
#          [0.5277479 ],
#          ...,
#          [0.55292284],
#          [0.574028  ],
#          [0.5141928 ]],
#
#         [[0.39654785],
#          [0.4945996 ],
#          [0.5230335 ],
#          ...,
#          [0.513453  ],
#          [0.4908078 ],
#          [0.37084264]]],
#
#
#        [[[0.41972157],
#          [0.5026492 ],
#          [0.5350144 ],
#          ...,
#          [0.59332776],
#          [0.6196281 ],
#          [0.502134  ]],
#
#         [[0.53669494],
#          [0.5505843 ],
#          [0.5754294 ],
#          ...,
#          [0.6517036 ],
#          [0.6195653 ],
#          [0.6269775 ]],
#
#         [[0.5629345 ],
#          [0.59166294],
#          [0.59307945],
#          ...,
#          [0.677619  ],
#          [0.6500353 ],
#          [0.7137687 ]],
#
#         ...,
#
#         [[0.64569813],
#          [0.6092954 ],
#          [0.55943066],
#          ...,
#          [0.48564035],
#          [0.49697223],
#          [0.46681347]],
#
#         [[0.63337886],
#          [0.58694434],
#          [0.6209017 ],
#          ...,
#          [0.5106291 ],
#          [0.48231322],
#          [0.42825434]],
#
#         [[0.5423096 ],
#          [0.61337715],
#          [0.6651727 ],
#          ...,
#          [0.4532096 ],
#          [0.37181857],
#          [0.3259795 ]]]], dtype=float32)

# %%
predCNN_test = modelCNN.predict(test_ds)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = np.array(sample.columns.values.tolist())
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]


    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            if i == 0:
               headers, samples = future.result()
            else:
               addSamp = future.result()[1]
               samples = samples.concatenate(addSamp)
            
            
            # if i == 0:
            #     headers_list = headers  # Use headers from the first file
            #     samples_list = result
            #     # samples_list = tf.data.experimental.from_list(result)
            # else:
            #     # tmp = tf.data.experimental.from_list(result)
            #     # tmp = result
            #   samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers, samples

headers, samples = load_all_samples(trainDat_path, numSamples)


samples = samples.shuffle(buffer_size=len(samples)) # Shuffle set
train_ds = samples.take(train_length)
remaining = samples.skip(train_length)
val_ds = remaining.take(valSize)
test_ds = remaining.skip(valSize)

X_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
y_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
    


# Define mean and variance for normalization based only on training set
feature_ds = train_ds.take(normalizerLength).map(lambda x, y: x) 
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(feature_ds)
# print(samples_array.shape)

# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds_eval = train_ds.copy() # Take a copy of the training dataset for RMSE evaluation at the end before repeat is passed
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
# if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
#    train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Test preprocessing
test_ds = test_ds.cache() # cache dataset for it to be used over iterations
test_ds = test_ds.shuffle(buffer_size = len(test_ds)).batch(batchSize)
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\kfh23\OneDrive - Imperial College London\KFH23_GENERAL\PROJECTS\20241029_MSc_Paper\Code\TBDCML\test.py:342
#     340 train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
#     341 train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
# --> 342 train_ds_eval = train_ds.copy() # Take a copy of the training dataset for RMSE evaluation at the end before repeat is passed
#     343 train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
#     344 # if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
#     345 #    train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
#
# AttributeError: '_BatchDataset' object has no attribute 'copy'

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = np.array(sample.columns.values.tolist())
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]


    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            if i == 0:
               headers, samples = future.result()
            else:
               addSamp = future.result()[1]
               samples = samples.concatenate(addSamp)
            
            
            # if i == 0:
            #     headers_list = headers  # Use headers from the first file
            #     samples_list = result
            #     # samples_list = tf.data.experimental.from_list(result)
            # else:
            #     # tmp = tf.data.experimental.from_list(result)
            #     # tmp = result
            #   samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers, samples

headers, samples = load_all_samples(trainDat_path, numSamples)


samples = samples.shuffle(buffer_size=len(samples)) # Shuffle set
train_ds = samples.take(train_length)
remaining = samples.skip(train_length)
val_ds = remaining.take(valSize)
test_ds = remaining.skip(valSize)

X_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
y_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
    


# Define mean and variance for normalization based only on training set
feature_ds = train_ds.take(normalizerLength).map(lambda x, y: x) 
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(feature_ds)
# print(samples_array.shape)

# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order
train_ds_eval = train_ds # Take a copy of the training dataset for RMSE evaluation at the end before repeat is passed
train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
# if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
#    train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Test preprocessing
test_ds = test_ds.cache() # cache dataset for it to be used over iterations
test_ds = test_ds.shuffle(buffer_size = len(test_ds)).batch(batchSize)
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
predCNN = modelCNN.predict(train_ds_eval)
predCNN_val = modelCNN.predict(val_ds)
predCNN_test = modelCNN.predict(test_ds)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
predCNN
# Out:
# array([[[[0.4278829 ],
#          [0.5341634 ],
#          [0.5011185 ],
#          ...,
#          [0.46757787],
#          [0.45331123],
#          [0.4138396 ]],
#
#         [[0.49713796],
#          [0.55492705],
#          [0.5688295 ],
#          ...,
#          [0.5711675 ],
#          [0.56056213],
#          [0.4989297 ]],
#
#         [[0.53570706],
#          [0.55647546],
#          [0.6027465 ],
#          ...,
#          [0.5500487 ],
#          [0.521218  ],
#          [0.5038384 ]],
#
#         ...,
#
#         [[0.50293565],
#          [0.5367908 ],
#          [0.6046619 ],
#          ...,
#          [0.568021  ],
#          [0.52469313],
#          [0.4937673 ]],
#
#         [[0.4269961 ],
#          [0.54794663],
#          [0.65323406],
#          ...,
#          [0.54837865],
#          [0.5038024 ],
#          [0.4520395 ]],
#
#         [[0.35507357],
#          [0.48549744],
#          [0.5423775 ],
#          ...,
#          [0.49064943],
#          [0.4161349 ],
#          [0.36912724]]],
#
#
#        [[[0.6073653 ],
#          [0.6546206 ],
#          [0.7091698 ],
#          ...,
#          [0.51213723],
#          [0.44029105],
#          [0.41009364]],
#
#         [[0.7910002 ],
#          [0.6044443 ],
#          [0.63164556],
#          ...,
#          [0.58506346],
#          [0.5553625 ],
#          [0.524759  ]],
#
#         [[0.7671056 ],
#          [0.7273932 ],
#          [0.6416454 ],
#          ...,
#          [0.54742426],
#          [0.5889569 ],
#          [0.52042097]],
#
#         ...,
#
#         [[0.6783113 ],
#          [0.57413244],
#          [0.5896528 ],
#          ...,
#          [0.6352383 ],
#          [0.65186864],
#          [0.5743738 ]],
#
#         [[0.6363448 ],
#          [0.60950017],
#          [0.5816748 ],
#          ...,
#          [0.58373857],
#          [0.6019928 ],
#          [0.54134244]],
#
#         [[0.54611856],
#          [0.57921344],
#          [0.60356987],
#          ...,
#          [0.53518146],
#          [0.4981431 ],
#          [0.4170233 ]]],
#
#
#        [[[0.40046874],
#          [0.50295866],
#          [0.5388332 ],
#          ...,
#          [0.5112186 ],
#          [0.48617375],
#          [0.42278457]],
#
#         [[0.51493007],
#          [0.5199116 ],
#          [0.5559502 ],
#          ...,
#          [0.5752915 ],
#          [0.55541015],
#          [0.45326748]],
#
#         [[0.54590374],
#          [0.54901516],
#          [0.59276575],
#          ...,
#          [0.5290078 ],
#          [0.564592  ],
#          [0.5711866 ]],
#
#         ...,
#
#         [[0.54108477],
#          [0.6134005 ],
#          [0.64927703],
#          ...,
#          [0.60876215],
#          [0.6990375 ],
#          [0.62973   ]],
#
#         [[0.54409665],
#          [0.5928854 ],
#          [0.5810562 ],
#          ...,
#          [0.74837697],
#          [0.666422  ],
#          [0.5718422 ]],
#
#         [[0.42842716],
#          [0.55052364],
#          [0.541164  ],
#          ...,
#          [0.56578517],
#          [0.5320821 ],
#          [0.45125636]]],
#
#
#        ...,
#
#
#        [[[0.461775  ],
#          [0.53057504],
#          [0.55776155],
#          ...,
#          [0.51816857],
#          [0.49726126],
#          [0.4047963 ]],
#
#         [[0.5448325 ],
#          [0.59952325],
#          [0.6028708 ],
#          ...,
#          [0.61314154],
#          [0.59106004],
#          [0.5386224 ]],
#
#         [[0.5610915 ],
#          [0.6258034 ],
#          [0.63652015],
#          ...,
#          [0.5641201 ],
#          [0.59395444],
#          [0.590728  ]],
#
#         ...,
#
#         [[0.5583689 ],
#          [0.6011299 ],
#          [0.55810064],
#          ...,
#          [0.59263766],
#          [0.5645322 ],
#          [0.6405196 ]],
#
#         [[0.47668135],
#          [0.59173197],
#          [0.6070879 ],
#          ...,
#          [0.7045254 ],
#          [0.7025182 ],
#          [0.5990424 ]],
#
#         [[0.36150482],
#          [0.4913012 ],
#          [0.48851094],
#          ...,
#          [0.6440649 ],
#          [0.6256877 ],
#          [0.5205334 ]]],
#
#
#        [[[0.37087408],
#          [0.4621147 ],
#          [0.45556393],
#          ...,
#          [0.48514023],
#          [0.4395382 ],
#          [0.388055  ]],
#
#         [[0.4928272 ],
#          [0.50720245],
#          [0.5384168 ],
#          ...,
#          [0.51843214],
#          [0.4748006 ],
#          [0.44081575]],
#
#         [[0.52255607],
#          [0.5443579 ],
#          [0.5533424 ],
#          ...,
#          [0.5737589 ],
#          [0.46626234],
#          [0.5161916 ]],
#
#         ...,
#
#         [[0.5583586 ],
#          [0.6315018 ],
#          [0.5584849 ],
#          ...,
#          [0.58823687],
#          [0.6092277 ],
#          [0.5734015 ]],
#
#         [[0.4698848 ],
#          [0.54102105],
#          [0.56171656],
#          ...,
#          [0.5516578 ],
#          [0.52119076],
#          [0.5591775 ]],
#
#         [[0.30800563],
#          [0.49342316],
#          [0.49143174],
#          ...,
#          [0.5463477 ],
#          [0.49911347],
#          [0.4360171 ]]],
#
#
#        [[[0.5250838 ],
#          [0.5916734 ],
#          [0.6452069 ],
#          ...,
#          [0.5130622 ],
#          [0.47693136],
#          [0.45221838]],
#
#         [[0.62708694],
#          [0.6659439 ],
#          [0.65361613],
#          ...,
#          [0.5074768 ],
#          [0.5043725 ],
#          [0.49077824]],
#
#         [[0.6626132 ],
#          [0.6365216 ],
#          [0.6336616 ],
#          ...,
#          [0.53575736],
#          [0.5548805 ],
#          [0.5443697 ]],
#
#         ...,
#
#         [[0.6203407 ],
#          [0.6432956 ],
#          [0.6494528 ],
#          ...,
#          [0.5911087 ],
#          [0.5356239 ],
#          [0.50963616]],
#
#         [[0.5126368 ],
#          [0.6103669 ],
#          [0.58378434],
#          ...,
#          [0.57331413],
#          [0.59007466],
#          [0.4730902 ]],
#
#         [[0.4203211 ],
#          [0.45758966],
#          [0.5572564 ],
#          ...,
#          [0.6089322 ],
#          [0.5442136 ],
#          [0.39821756]]]], dtype=float32)

# %%
y_train
# Out:
# array([[[[-0.47228115],
#          [-0.16930889],
#          [ 0.01083783],
#          ...,
#          [ 1.51208778],
#          [ 1.82723724],
#          [ 2.41237194]],
#
#         [[-0.47228115],
#          [-0.16930889],
#          [ 0.01083783],
#          ...,
#          [ 1.51208778],
#          [ 1.82723724],
#          [ 2.41237194]],
#
#         [[ 0.44052076],
#          [ 0.11826778],
#          [ 0.03549847],
#          ...,
#          [ 3.24816164],
#          [ 3.3929644 ],
#          [ 3.16060976]],
#
#         ...,
#
#         [[ 1.28741303],
#          [ 1.38348375],
#          [ 1.42204706],
#          ...,
#          [-1.27578979],
#          [-1.59161299],
#          [-2.09444185]],
#
#         [[ 2.28027557],
#          [ 2.06219358],
#          [ 1.81160239],
#          ...,
#          [-1.50765568],
#          [-1.75457331],
#          [-2.11988503]],
#
#         [[ 2.28027557],
#          [ 2.06219358],
#          [ 1.81160239],
#          ...,
#          [-1.50765568],
#          [-1.75457331],
#          [-2.11988503]]],
#
#
#        [[[-0.69053316],
#          [-1.24202698],
#          [-1.40347804],
#          ...,
#          [-0.58216117],
#          [-0.84427594],
#          [-1.32220441]],
#
#         [[-0.69053316],
#          [-1.24202698],
#          [-1.40347804],
#          ...,
#          [-0.58216117],
#          [-0.84427594],
#          [-1.32220441]],
#
#         [[-1.54380141],
#          [-1.33268551],
#          [-1.31198577],
#          ...,
#          [-0.10379471],
#          [ 0.00826591],
#          [ 0.16062454]],
#
#         ...,
#
#         [[ 0.50047046],
#          [-0.00539383],
#          [-0.16794507],
#          ...,
#          [-2.05790575],
#          [-1.96185893],
#          [-1.56450074]],
#
#         [[-0.5976071 ],
#          [ 0.07489207],
#          [ 0.35075183],
#          ...,
#          [-0.99396467],
#          [-1.3419895 ],
#          [-2.12372579]],
#
#         [[-0.5976071 ],
#          [ 0.07489207],
#          [ 0.35075183],
#          ...,
#          [-0.99396467],
#          [-1.3419895 ],
#          [-2.12372579]]],
#
#
#        [[[ 0.90400104],
#          [ 0.3573123 ],
#          [ 0.04669048],
#          ...,
#          [-1.69416781],
#          [-1.67665795],
#          [-1.47833778]],
#
#         [[ 0.90400104],
#          [ 0.3573123 ],
#          [ 0.04669048],
#          ...,
#          [-1.69416781],
#          [-1.67665795],
#          [-1.47833778]],
#
#         [[-0.49755077],
#          [-0.69204659],
#          [-0.75123698],
#          ...,
#          [-1.56220074],
#          [-1.55997627],
#          [-1.54044922]],
#
#         ...,
#
#         [[ 0.03538799],
#          [-0.20099065],
#          [-0.47540306],
#          ...,
#          [-1.3643408 ],
#          [-1.301763  ],
#          [-1.3845324 ]],
#
#         [[ 0.33197678],
#          [-0.15356813],
#          [-0.3583654 ],
#          ...,
#          [-1.15617697],
#          [-1.18794545],
#          [-1.34309376]],
#
#         [[ 0.33197678],
#          [-0.15356813],
#          [-0.3583654 ],
#          ...,
#          [-1.15617697],
#          [-1.18794545],
#          [-1.34309376]]],
#
#
#        ...,
#
#
#        [[[ 2.24262155],
#          [ 2.2501945 ],
#          [ 2.23102259],
#          ...,
#          [-0.12934401],
#          [-0.03364711],
#          [ 0.3471602 ]],
#
#         [[ 2.24262155],
#          [ 2.2501945 ],
#          [ 2.23102259],
#          ...,
#          [-0.12934401],
#          [-0.03364711],
#          [ 0.3471602 ]],
#
#         [[ 2.90462399],
#          [ 2.59871828],
#          [ 2.56297003],
#          ...,
#          [ 0.63555942],
#          [ 0.78196991],
#          [ 1.00720169]],
#
#         ...,
#
#         [[ 0.83154251],
#          [ 0.74240997],
#          [ 0.79904286],
#          ...,
#          [ 1.69583503],
#          [ 1.82233432],
#          [ 2.02154096]],
#
#         [[ 1.64391162],
#          [ 1.48358413],
#          [ 1.41182004],
#          ...,
#          [ 1.98410626],
#          [ 2.00838433],
#          [ 2.2623252 ]],
#
#         [[ 1.64391162],
#          [ 1.48358413],
#          [ 1.41182004],
#          ...,
#          [ 1.98410626],
#          [ 2.00838433],
#          [ 2.2623252 ]]],
#
#
#        [[[-0.61649138],
#          [-0.69979522],
#          [-0.66274637],
#          ...,
#          [ 1.32575093],
#          [ 1.30040667],
#          [ 0.91073522]],
#
#         [[-0.61649138],
#          [-0.69979522],
#          [-0.66274637],
#          ...,
#          [ 1.32575093],
#          [ 1.30040667],
#          [ 0.91073522]],
#
#         [[-1.58599772],
#          [-1.50572818],
#          [-1.44162089],
#          ...,
#          [ 0.01303249],
#          [ 0.16758691],
#          [ 0.57962497]],
#
#         ...,
#
#         [[ 1.81321752],
#          [ 1.11574053],
#          [ 0.92239035],
#          ...,
#          [-1.00007872],
#          [-1.20652248],
#          [-1.54741809]],
#
#         [[ 0.23441973],
#          [ 0.13824051],
#          [ 0.104127  ],
#          ...,
#          [-0.75186503],
#          [-0.62038909],
#          [-0.25008899]],
#
#         [[ 0.23441973],
#          [ 0.13824051],
#          [ 0.104127  ],
#          ...,
#          [-0.75186503],
#          [-0.62038909],
#          [-0.25008899]]],
#
#
#        [[[ 1.26302067],
#          [ 1.50578039],
#          [ 1.47013653],
#          ...,
#          [-1.60312218],
#          [-1.87713212],
#          [-2.24486456]],
#
#         [[ 1.26302067],
#          [ 1.50578039],
#          [ 1.47013653],
#          ...,
#          [-1.60312218],
#          [-1.87713212],
#          [-2.24486456]],
#
#         [[ 1.81594944],
#          [ 1.04882092],
#          [ 0.69114668],
#          ...,
#          [-1.04155714],
#          [-1.15118867],
#          [-1.61836239]],
#
#         ...,
#
#         [[-0.79034927],
#          [-0.78590782],
#          [-0.74692627],
#          ...,
#          [ 0.59721425],
#          [ 0.35741642],
#          [-0.31441775]],
#
#         [[-0.82697334],
#          [-0.90664061],
#          [-0.97284028],
#          ...,
#          [ 0.03607061],
#          [-0.29256148],
#          [-0.79767753]],
#
#         [[-0.82697334],
#          [-0.90664061],
#          [-0.97284028],
#          ...,
#          [ 0.03607061],
#          [-0.29256148],
#          [-0.79767753]]]])

# %%
predCNN.shape
# Out:
# (70, 60, 20, 1)

# %%
predCNN_test.shape
# Out:
# (15, 60, 20, 1)

# %%
predCNN.shape
# Out:
# (70, 60, 20, 1)

# %%
train_ds
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 60, 20, 5), dtype=tf.float64, name=None), TensorSpec(shape=(None, 60, 20, 1), dtype=tf.float64, name=None))>

# %%
train_ds_eval
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 60, 20, 5), dtype=tf.float64, name=None), TensorSpec(shape=(None, 60, 20, 1), dtype=tf.float64, name=None))>

# %%
modelCNN.get_metrics_result()
# Out:
# {'loss': 0.014652717858552933,
#  'mean_absolute_error': 0.09819378703832626,
#  'mean_squared_error': 0.014652718789875507}

# %%
train_ds_eval[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 train_ds_eval[0]
#
# TypeError: '_BatchDataset' object is not subscriptable

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = np.array(sample.columns.values.tolist())
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]


    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            if i == 0:
               headers, samples = future.result()
            else:
               addSamp = future.result()[1]
               samples = samples.concatenate(addSamp)
            
            
            # if i == 0:
            #     headers_list = headers  # Use headers from the first file
            #     samples_list = result
            #     # samples_list = tf.data.experimental.from_list(result)
            # else:
            #     # tmp = tf.data.experimental.from_list(result)
            #     # tmp = result
            #   samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers, samples

headers, samples = load_all_samples(trainDat_path, numSamples)


samples = samples.shuffle(buffer_size=len(samples)) # Shuffle set
train_ds = samples.take(train_length)
remaining = samples.skip(train_length)
val_ds = remaining.take(valSize)
test_ds = remaining.skip(valSize)

# Take a copy of the datasets for RMSE evaluation at the end before repeat and shuffling is passed
train_ds_eval = train_ds 
val_ds_eval = val_ds 
test_ds_eval = test_ds 

X_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
y_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
    


# Define mean and variance for normalization based only on training set
feature_ds = train_ds.take(normalizerLength).map(lambda x, y: x) 
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(feature_ds)
# print(samples_array.shape)

# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order

train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
# if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
#    train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Test preprocessing
test_ds = test_ds.cache() # cache dataset for it to be used over iterations
test_ds = test_ds.shuffle(buffer_size = len(test_ds)).batch(batchSize)
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
predCNN = modelCNN.predict(train_ds_eval)
predCNN_val = modelCNN.predict(val_ds_eval)
predCNN_test = modelCNN.predict(test_ds_eval)
# Old method where the normalisation was not part o
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 predCNN = modelCNN.predict(train_ds_eval)
#       2 predCNN_val = modelCNN.predict(val_ds_eval)
#       3 predCNN_test = modelCNN.predict(test_ds_eval)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ValueError: as_list() is not defined on an unknown TensorShape.

# %%
val_ds_eval
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(60, 20, 5), dtype=tf.float64, name=None), TensorSpec(shape=(60, 20, 1), dtype=tf.float64, name=None))>

# %%
predCNN = modelCNN.predict(train_ds_eval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 predCNN = modelCNN.predict(train_ds_eval)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ValueError: as_list() is not defined on an unknown TensorShape.

# %%
predCNN = modelCNN.predict(train_ds)
# Out:
#     407/Unknown 9s 21ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 predCNN = modelCNN.predict(train_ds)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:559, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     557 callbacks.on_predict_batch_begin(step)
#     558 data = get_data(iterator)
# --> 559 batch_outputs = self.predict_function(data)
#     560 outputs = append_to_outputs(batch_outputs, outputs)
#     561 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)
#    1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
predCNN = modelCNN.predict(test_ds)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
predCNN = modelCNN.predict(test_ds_eval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 predCNN = modelCNN.predict(test_ds_eval)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ValueError: as_list() is not defined on an unknown TensorShape.

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = np.array(sample.columns.values.tolist())
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]


    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            if i == 0:
               headers, samples = future.result()
            else:
               addSamp = future.result()[1]
               samples = samples.concatenate(addSamp)
            
            
            # if i == 0:
            #     headers_list = headers  # Use headers from the first file
            #     samples_list = result
            #     # samples_list = tf.data.experimental.from_list(result)
            # else:
            #     # tmp = tf.data.experimental.from_list(result)
            #     # tmp = result
            #   samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers, samples

headers, samples = load_all_samples(trainDat_path, numSamples)


samples = samples.shuffle(buffer_size=len(samples)) # Shuffle set
train_ds = samples.take(train_length)
remaining = samples.skip(train_length)
val_ds = remaining.take(valSize)
test_ds = remaining.skip(valSize)

# Take a copy of the datasets for RMSE evaluation at the end before repeat and shuffling is passed
train_ds_eval = train_ds 
val_ds_eval = val_ds 
test_ds_eval = test_ds 

X_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
y_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
    


# Define mean and variance for normalization based only on training set
feature_ds = train_ds.take(normalizerLength).map(lambda x, y: x) 
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(feature_ds)
# print(samples_array.shape)

# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order

train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
# if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
#    train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Test preprocessing
test_ds = test_ds.cache() # cache dataset for it to be used over iterations
test_ds = test_ds.shuffle(buffer_size = len(test_ds)).batch(batchSize)
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
#####################################################################
# CNN Model definition
#####################################################################

def TBDCNet_modelCNN(inputShape, outputShape, params):
  '''
  This function returns a model based on the hyperparameters in the
  sweep definition

  Args
  ----------
  inputShape: the 55x20x3 input image shape
  outputShape: the prediction image shape (currently unused)
  params: The hyperparameters for the given sweep index

  Returns
  ----------
  model: tensorflow model

  '''
  # Kernel regularizer (both linear and quadratic)
  if params['L1kernel_regularizer'] > 0 and params['L2kernel_regularizer'] > 0: 
     regularizer = tf.keras.regularizers.L1L2(l1=params['L1kernel_regularizer'], l2=params['L2kernel_regularizer'])
  elif params['L1kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L1(params['L1kernel_regularizer'])
  elif params['L2kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L2(params['L2kernel_regularizer'])
  else:
    regularizer = None

  # Define the model architecture. Each convolutional layer has settings related to the kernel size, 
  # activation function, and regularizer. After each convolutional layer there may be a batch-
  # normalization layer, a max pooling layer, and a dropout layer. The number of convolutional layers
  # is given in the sweep definition


  input = tf.keras.layers.Input(shape=inputShape) # Shape (Long, short, inputs)
  x = normalizer(input)
  if params['dsAugmentation'] == 1:
    x = tf.keras.layers.RandomFlip(mode="horizontal_and_vertical", seed=seed)(x)


  x = tf.keras.layers.Conv2D(filters = 32, kernel_size=(int(params['layer1Kernel']), int(params['layer1Kernel'])),activation=params['conv1Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
  if params['batchNorm'] == 1:
    x = tf.keras.layers.BatchNormalization()(x)
  if params['pooling'] == 1:
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
  if params['dropout'] > 0:
    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
  encoder1 = x # Use this if skip connections need to be used


  if params['layer2'] == 1:
    x = tf.keras.layers.Conv2D(filters = 64, kernel_size=(int(params['layer2Kernel']), int(params['layer2Kernel'])),activation=params['conv2Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
    if params['batchNorm'] == 1:
      x = tf.keras.layers.BatchNormalization()(x)
    if params['pooling'] == 1:
       x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
    if params['dropout'] > 0:
       x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
    encoder2 = x
        

    if params['layer3'] == 1:
        x = tf.keras.layers.Conv2D(filters = 128, kernel_size=(int(params['layer3Kernel']), int(params['layer3Kernel'])),activation=params['conv3Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
        if params['batchNorm'] == 1:
           x = tf.keras.layers.BatchNormalization()(x)
        if params['pooling'] == 1:
           x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
        if params['dropout'] > 0:
           x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
        encoder3 = x


        if params['layer4'] == 1:
            x = tf.keras.layers.Conv2D(filters = 256, kernel_size=(int(params['layer4Kernel']), int(params['layer4Kernel'])),activation=params['conv4Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
            if params['batchNorm'] == 1:
                x = tf.keras.layers.BatchNormalization()(x)
            if params['pooling'] == 1:
                x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
            if params['dropout'] > 0:
                x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
            encoder4 = x


            if params['layer5'] == 1:
                x = tf.keras.layers.Conv2D(filters = 512, kernel_size=(int(params['layer5Kernel']), int(params['layer5Kernel'])),activation=params['conv5Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                if params['batchNorm'] == 1:
                    x = tf.keras.layers.BatchNormalization()(x)
                if params['pooling'] == 1:
                    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                if params['dropout'] > 0:
                    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                encoder5 = x


                if params['layer6'] == 1:
                    x = tf.keras.layers.Conv2D(filters = 1024, kernel_size=(int(params['layer6Kernel']), int(params['layer6Kernel'])),activation=params['conv6Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                    if params['batchNorm'] == 1:
                        x = tf.keras.layers.BatchNormalization()(x)
                    if params['pooling'] == 1:
                        x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                    if params['dropout'] > 0:
                        x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                    encoder6 = x

                    if params['ActivationUp'] == 0:
                       temp_activation = 'linear'
                    else:
                       temp_activation = params['conv6Activation']

                    x = tf.keras.layers.Conv2DTranspose(filters = 512, kernel_size = (int(params['layer6Kernel']),int(params['layer6Kernel'])),  padding='same',activation=temp_activation)(x)
                    if params['skipConnections'] == 1:
                      x = tf.keras.layers.Concatenate()([x, encoder5])


                if params['ActivationUp'] == 0:
                    temp_activation = 'linear'
                else:
                    temp_activation = params['conv5Activation']

                x = tf.keras.layers.Conv2DTranspose(filters = 256, kernel_size = (int(params['layer5Kernel']),int(params['layer5Kernel'])),  padding='same',activation=temp_activation)(x)
                if params['skipConnections'] == 1:
                  x = tf.keras.layers.Concatenate()([x, encoder4])
            
            
            if params['type'] == 'dense':
              y = tf.keras.layers.Flatten()(x)
              y = tf.keras.layers.Dense(64, activation='relu')(y)
              y = tf.keras.layers.Dense(outputShape[0]*outputShape[1])(y)
              y = tf.keras.layers.Reshape(outputShape)(y)

            if params['ActivationUp'] == 0:
                temp_activation = 'linear'
            else:
                temp_activation = params['conv4Activation']
            
            x = tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (int(params['layer4Kernel']),int(params['layer4Kernel'])),  padding='same',activation=temp_activation)(x)
            if params['skipConnections'] == 1:
              x = tf.keras.layers.Concatenate()([x, encoder3])

        if params['ActivationUp'] == 0:
            temp_activation = 'linear'
        else:
            temp_activation = params['conv3Activation']
        
        x = tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (int(params['layer3Kernel']),int(params['layer3Kernel'])),  padding='same',activation=temp_activation)(x)
        if params['skipConnections'] == 1:
          x = tf.keras.layers.Concatenate()([x, encoder2])

    if params['ActivationUp'] == 0:
        temp_activation = 'linear'
    else:
        temp_activation = params['conv2Activation']
    
    x = tf.keras.layers.Conv2DTranspose(filters = 32, kernel_size = (int(params['layer2Kernel']),int(params['layer2Kernel'])),  padding='same',activation=temp_activation)(x)
    if params['skipConnections'] == 1:
      x = tf.keras.layers.Concatenate()([x, encoder1])

   # Custom activation function is linear between 0 and 1 and otherwise constant
  def custom_activation(x):
      return tf.math.minimum(K.relu(x), 1)

  x = tf.keras.layers.Conv2DTranspose(filters = 1, kernel_size = (int(params['layer1Kernel']),int(params['layer1Kernel'])),  padding='same',activation='linear')(x)

  if params['type'] == 'dense': # For the dense model we jsut pull the output y
     output = y
  else:
    output = x

  model = tf.keras.Model(inputs=input, outputs=output) # Create model

  # Default initial learning rate is 0.001. If the the decay rate is 1 this will be held constant.
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=params['initial_lr'],
    decay_steps=steps_per_epoch*epochs,
    decay_rate=params['lr_decay_rate'])

  def custom_loss(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.nn.relu(y_true))))
    loss = tf.reduce_mean(loss)
    return loss
  
  def custom_loss5(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.math.multiply(tf.nn.relu(y_true),5))))
    loss = tf.reduce_mean(loss)
    return loss

  def peak_loss(y_true,y_pred):
    peakVal = tf.reduce_max(y_true, keepdims=True)
    cond = tf.equal(y_true, peakVal)
    # peakLoc = tf.where(cond)
    # peakLoc_1d = tf.squeeze(peakLoc)
    errorGrid = tf.math.subtract(y_true,y_pred)
    zeroGrid = tf.math.subtract(y_true,y_true) # Grid of zeros so we only get loss in peak location
    # peakPred = y_pred[peakLoc_1d.numpy()[0]]
    # peakPred = tf.slice(y_pred, peakLoc, [1,1])
    loss = tf.where(cond, errorGrid, zeroGrid)
    loss = tf.reduce_mean(loss)

    # loss = peakPred-peakVal
    return loss


#   Loss functions can be swept
  if params['loss'] == 'MSE':
    lossfunc = tf.keras.losses.MeanSquaredError()
  elif params['loss'] == 'MAE':
    lossfunc = tf.keras.losses.MeanAbsoluteError()
  elif params['loss'] == 'Custom':
    lossfunc = custom_loss
  elif params['loss'] == 'Peak':
    lossfunc = peak_loss
  elif params['loss'] == 'Custom5':
    lossfunc = custom_loss5
    



  # Compile model with the optimizer in the sweep definition
  if params['optimizer'] == 'Adadelta':
     model.compile(optimizer=tf.keras.optimizers.Adadelta(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  elif params['optimizer'] == 'Nadam':
     model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  else:
     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])

  return model

# %%
#####################################################################
# Training callbacks
#####################################################################

# Checkpoints to allow saving best model at various points
# checkpoint_path = 'training_checkpoints_{jn}_{num}/cp.ckpt'.format(jn='TESTJOB', num = 1)
checkpoint_path = 'training_checkpoints_{jn}_{num}/model.weights.h5'.format(jn='TESTJOB', num = 1)
checkpoint_dir = os.path.dirname(checkpoint_path)

try:
  os.mkdir(checkpoint_dir) # Make checkpoint directory
except:
  pass

# Save best weights to checkpoint
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_best_only = True,
                                                 monitor = 'val_loss',
                                                 verbose=1)

# Early stopping callback which monitors improvements and stops training if
# it stagnates.
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', # Monitor validation loss
    min_delta=0, # Minimum improvement to consider an improvement
    patience=60, # Number of epochs with no improvement before stopping training
    verbose=1, # Records message when earlystopping
    mode='auto',
    baseline=None, 
    restore_best_weights=False # Do not restore best weights after early stopping, we do this manually to allow recording of the full training history
)

# %%
#####################################################################
# Model instantiation
#####################################################################

tf.keras.backend.clear_session() # Clear the state and frees up memory

# CNN Model creation
# modelCNN = TBDCNet_modelCNN(inputShape = train_in_shape[1:], outputShape = train_out_shape[1:], params = params)
modelCNN = TBDCNet_modelCNN(inputShape = X_trainShape[1:], outputShape = y_trainShape[1:], params = params)

modelCNNname = 'CNNModel1'

# %%
predCNN = modelCNN.predict(test_ds_eval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 predCNN = modelCNN.predict(test_ds_eval)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 0 of layer "functional" is incompatible with the layer: expected shape=(None, 60, 20, 5), found shape=(60, 20, 5)

# %%
predCNN = modelCNN.predict(test_ds)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step

# %%
trainDat_path = r'\\rds.imperial.ac.uk\rds\user\kfh23\home\IndividualProject\CNNTraining\datain'


if params['Dataset'] == 'LFC18': # ABAQUS DATA FROM GAUDRON2018
  trainDat_name = 'Gaudron2018' 
  sampleShape = [55,20]
  xNames = ['E11','E22','E12'] # Names of input features in input csv
  trainDat_path = os.path.join(trainDat_path,'Gaudron2018') # Path for training data samples
  samplesPerFile = 1
elif params['Dataset'] == 'MC24': # MECOMPOSITES MODEL FROM 2024 (100 samples)
  trainDat_name = 'MatLabModel2024' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_200': # MECOMPOSITES MODEL FROM 2024 (200 samples)
  trainDat_name = 'MatLabModel2024_200' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_200')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_500': # MECOMPOSITES MODEL FROM 2024 (500 samples)
  trainDat_name = 'MatLabModel2024_500' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_500')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1
elif params['Dataset'] == 'MC24_1000': # MECOMPOSITES MODEL FROM 2024 (1000 samples)
  trainDat_name = 'MatLabModel2024_1000' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_1000')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 1

elif params['Dataset'] == 'MC24x': # MC24_extended dataset (4000 samples 224x224 resolution)
  trainDat_name = 'MatLabModel2024_224_4kSamples' 
  sampleShape = [60,20]
  trainDat_path = os.path.join(trainDat_path,'MatLabModel2024_224_4kSamples')
  if params['MC24_Features'] == 'Stiffness':
    xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
  elif params['MC24_Features'] == 'Vf_c2':
    xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
  elif params['MC24_Features'] == 'All':
     xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features
  samplesPerFile = 40


# elif params['Dataset'] == 'MC24_10000': # MECOMPOSITES MODEL FROM 2024 (10,000 samples)
#   trainDat_name = 'MatLabModel2024_10000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1239_10kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features

# elif params['Dataset'] == 'MC24_100000': # MECOMPOSITES MODEL FROM 2024 (100,000 samples)
#   trainDat_name = 'MatLabModel2024_100000' 
#   sampleShape = [60,20]
#   trainDat_path = r'C:\Users\kaspe\OneDrive\UNIVERSITY\YEAR 4\Individual Project\Data\MatLabModelFiles\20240725_1439_100kSamples'
#   if params['MC24_Features'] == 'Stiffness':
#     xNames = ['Ex','Ey','Gxy'] # Use stiffnesses (default)
#   elif params['MC24_Features'] == 'Vf_c2':
#     xNames = ['Vf','c2'] # Use fibre volume fraction and orientation distribution
#   elif params['MC24_Features'] == 'All':
#      xNames = ['Ex','Ey','Gxy','Vf','c2'] # Use all available features




yNames = ['FI'] # Names of ground truth features in input csv
numSamples = len(os.listdir(trainDat_path))*samplesPerFile # number of samples is number of files in datain
batchSize = params['batchSize'] # Batch size for training
valSize = math.floor(params['valSize']*numSamples) # Training and validation data split ratio
testSize = math.floor(params['testSize']*numSamples)
train_length = numSamples-valSize-testSize # Number of training samples 
epochs = params['Epochs'] # Max epochs for training
# epochs = 500 # Max epochs for training
steps_per_epoch = train_length // batchSize
validation_steps = math.ceil((numSamples-train_length) / batchSize)

# For reproducible results set a seed
seed = 0
tf.random.set_seed(seed)

def formatCoords(values,coordIdx):
    coords = [[x for x in values[:,coordIdx][y].split(' ') if x] for y in range(len(values[:,coordIdx]))] # Split coordinates by delimiter (space)
    coords = [np.char.strip(x, '[') for x in coords] # Coordinate output from abaqus has leading "["
    coords = [[x for x in coords[y] if x] for y in range(len(values[:,coordIdx]))] # remove empty array elements
    coords = np.array([[float(x) for x in coords[y][0:2]] for y in range(len(values[:,coordIdx]))]) # Take 2d coordinates and convert to float
    return coords

def loadSample(path = str):
  '''
  Imports data in csv and formats into a tensor
  Data from Abaqus comes in a slightly bothersome format, this 
  function manually reformats it
  '''
  # Read sample csv data
  sample = pd.read_csv(path)
  headers = sample.columns.values.tolist()
  values = np.array(sample)
  
  if "coordinates" in headers: 
    coordIdx = headers.index("coordinates")
    if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
      coords = formatCoords(values,coordIdx)
      values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

    headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
  headers = np.array(headers)
  return headers, values
    

randAug = tf.random.Generator.from_seed(seed) # Random number generator used for random augmentations
def augmentImage(inputMatrices,gtMatrix):
    '''
  Apply augmentations to increase the dataset size

  Args
  ----------
  inputMatrices: the Batchx55x20x3 input
  gtMatrix: the Batchx55x30 ground truth

  Returns
  ----------
  inputMatrices,gtMatrix with consistent augmentations applied

  '''
    height, width = sampleShape[0], sampleShape[1] # image dimensions

    if randAug.normal([]) > 0: # Randomly flip an image horizontally 50% of the time
      inputMatrices = tf.image.flip_left_right(inputMatrices)
      gtMatrix = tf.image.flip_left_right(gtMatrix)
      # gtMatrix = tf.image.flip_left_right(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    if  randAug.normal([]) > 0: # Randomly flip an image vertically 50% of the time
      inputMatrices = tf.image.flip_up_down(inputMatrices)
      gtMatrix = tf.image.flip_up_down(gtMatrix)
      # gtMatrix = tf.image.flip_up_down(tf.reshape(gtMatrix,[-1,height,width,1]))
      # gtMatrix = tf.reshape(gtMatrix,[-1,height,width])

    # We can crop and resize but this messes with the boundary conditions hence not done right now
    # if randAug.normal([]) > 0.67: # Scale to a random size within the bounding box and fit to a random location within this
    #   crop_width = randAug.uniform(shape=(), minval=math.floor(0.7 * width), maxval=math.floor(0.9 * width), dtype = tf.int32)
    #   crop_height = randAug.uniform(shape=(), minval=math.floor(0.7 * height), maxval=math.floor(0.9 * height), dtype = tf.int32)
    #   offset_x = randAug.uniform(shape=(), minval=0, maxval=(width - crop_width), dtype = tf.int32)
    #   offset_y = randAug.uniform(shape=(), minval=0, maxval=(height - crop_height), dtype = tf.int32)

    #   inputMatrices = tf.image.crop_to_bounding_box(inputMatrices, offset_y, offset_x, crop_height, crop_width) # Crop to bounding box
    #   gtMatrix = tf.image.crop_to_bounding_box(tf.reshape(gtMatrix,[-1,height,width,1]), offset_y, offset_x, crop_height, crop_width)
    #   newHeight = crop_height
    #   newWidth = crop_width
    #   gtMatrix = tf.reshape(gtMatrix,[-1,newHeight,newWidth]) # Reshape ground truth back to not have channels dimensions
    
    #   inputMatrices = tf.image.resize(inputMatrices, (height, width)) # Resize to original size (we want all images same size) - this distorts the image
    #   gtMatrix = tf.image.resize(tf.reshape(gtMatrix,[-1,newHeight,newWidth,1]), (height, width), method='nearest')
    #   gtMatrix = tf.reshape(gtMatrix,[-1,height,width])
    #   inputMatrices = tf.cast(inputMatrices, tf.float64)
    #   gtMatrix = tf.cast(gtMatrix, tf.float64)

      
    return (inputMatrices,gtMatrix)


def show_prediction(sample, predictions, names, ground_truth, grid):
  '''
  For a given dataset plots one image, its true mask, and predicted mask

  Args
  ----------
  sample: the input
  prediction: the predicted field
  ground_truth: the ground truth field

  Returns
  ----------
  Nothing, graph will be displayed

  '''
  # Plot  inputs
  fig, axs = plt.subplots(1, sample.shape[-1],figsize=[10,5]) # Create subplots to fit input fields
  for i in range(sample.shape[-1]):
    ax = plt.subplot(1, sample.shape[-1], i+1)
    CS = ax.contourf(grid[0],grid[1],sample[:,:,i], cmap = 'jet')
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS)
    plt.title('input'+str(i+1))

  # Plot outputs
  fig, axs = plt.subplots(1, len(names)+1,figsize=[5*len(names), 5]) # Create subplots to fit output fields

  ax = plt.subplot(1, len(names)+1, 1)
  CS = ax.contourf(grid[0],grid[1],ground_truth, cmap = 'jet')
  plt.xlabel('x')
  plt.ylabel('y')
  fig.colorbar(CS)
  plt.title('ground truth')

  for idx, pred in enumerate(predictions):
    ax = plt.subplot(1, len(names)+1, idx+2)
    CS2 = ax.contourf(grid[0],grid[1],predictions[idx], cmap = 'jet', levels = CS.levels)
    plt.xlabel('x')
    plt.ylabel('y')
    fig.colorbar(CS2)
    plt.title(names[idx])


# Format is csv files with columns 
# Try new method of loading samples
from concurrent.futures import ThreadPoolExecutor, as_completed

def loadSampleNew(path):
    # Assuming loadSample uses pandas to read the CSV file
    # Adjust the delimiter and header options as needed
    _, file_extension = os.path.splitext(path)
    match file_extension:
       case '.csv':
        sample = pd.read_csv(path)
        samples = np.array(sample)
       case '.parquet':
        sample = pd.read_parquet(path, engine='auto')
        samples = [y for x, y in sample.groupby('specimen')]
        samples = np.array(list(map(lambda x: x.to_numpy(), samples)))
    headers = np.array(sample.columns.values.tolist())
    samples = samples.reshape(samplesPerFile,sampleShape[0],sampleShape[1],-1)


    # Find indeces of input features 
    featureIdx = []
    for name in xNames:
      featureIdx += [np.where(headers == name)[0][0]]

    # Find indeces of ground truth features 
    gtIdx = []
    for name in yNames:
      gtIdx += [np.where(headers == name)[0][0]]



    X = samples[:,:,:,featureIdx] # Input features
    Y = samples[:,:,:,gtIdx] # Labels
    ds = tf.data.Dataset.from_tensor_slices((X, Y))


    # samples = samples.reshape(samples.shape[0],sampleShape[0],sampleShape[1],-1)
    
    if "coordinates" in headers: 
      coordIdx = headers.index("coordinates")
      if '[' in values[0,1]: # Some coordinates will be formatted with brackets from abaqus export
        coords = formatCoords(values,coordIdx)
        values = np.column_stack((values[:,0],coords,values[:,2:])).astype(float) # Create a new values vector which contains the coordinates

      headers = np.concatenate(([[headers[0],'x_coord','y_coord'],headers[2:]])) # rectify the headers to include x and y coordinates separately
    return headers, ds


def load_all_samples(trainDat_path, numSamples):
    files = [os.path.join(trainDat_path, file) for file in os.listdir(trainDat_path)]


    def process_file(filepath):
        headers, values = loadSampleNew(filepath)
        return headers, values

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_file, file): file for file in files}
        for i, future in enumerate(as_completed(futures)):
            if i == 0:
               headers, samples = future.result()
            else:
               addSamp = future.result()[1]
               samples = samples.concatenate(addSamp)
            
            
            # if i == 0:
            #     headers_list = headers  # Use headers from the first file
            #     samples_list = result
            #     # samples_list = tf.data.experimental.from_list(result)
            # else:
            #     # tmp = tf.data.experimental.from_list(result)
            #     # tmp = result
            #   samples_list = np.append(samples_list,result,axis = 0)
            print('Now loading file number {num} out of {total}'.format(num=i+1, total=numSamples/samplesPerFile))

    # samples_array = tf.data.experimental.from_list(samples_list)
    # samples_array = np.array(samples_list)
    return headers, samples

headers, samples = load_all_samples(trainDat_path, numSamples)


samples = samples.shuffle(buffer_size=len(samples)) # Shuffle set
train_ds = samples.take(train_length)
remaining = samples.skip(train_length)
val_ds = remaining.take(valSize)
test_ds = remaining.skip(valSize)

# Take a copy of the datasets for RMSE evaluation at the end before repeat and shuffling is passed
train_ds_eval = train_ds.batch(batchSize)
val_ds_eval = val_ds.batch(batchSize)
test_ds_eval = test_ds.batch(batchSize)

X_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
X_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(xNames))
y_trainShape = (train_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_valShape = (val_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
y_testShape = (test_ds.cardinality().numpy().item(),sampleShape[0],sampleShape[1],len(yNames))
    


# Define mean and variance for normalization based only on training set
feature_ds = train_ds.take(normalizerLength).map(lambda x, y: x) 
normalizer = tf.keras.layers.Normalization()
normalizer.adapt(feature_ds)
# print(samples_array.shape)

# Training preprocessing
train_ds = train_ds.cache() # cache dataset for it to be used over iterations. Any operation before this will not be reapplied each iteration
train_ds = train_ds.shuffle(buffer_size = len(train_ds)).batch(batchSize) # Shuffle for random order

train_ds = train_ds.repeat() # Repeats dataset indefinitely to avoid errors
# if params['dsAugmentation'] == 1: # We can apply dataset augmentation to effectively increase the dataset size
#    train_ds = train_ds.map(lambda x,y: augmentImage(x,y))
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Validation preprocessing
val_ds = val_ds.cache() # cache dataset for it to be used over iterations
val_ds = val_ds.shuffle(buffer_size = len(val_ds)).batch(batchSize)
val_ds = val_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared

# Test preprocessing
test_ds = test_ds.cache() # cache dataset for it to be used over iterations
test_ds = test_ds.shuffle(buffer_size = len(test_ds)).batch(batchSize)
test_ds = test_ds.prefetch(buffer_size=tf.data.AUTOTUNE) # Allows prefetching of elements while later elements are prepared
# Out:
# Now loading file number 1 out of 100.0
# Now loading file number 2 out of 100.0
# Now loading file number 3 out of 100.0
# Now loading file number 4 out of 100.0
# Now loading file number 5 out of 100.0
# Now loading file number 6 out of 100.0
# Now loading file number 7 out of 100.0
# Now loading file number 8 out of 100.0
# Now loading file number 9 out of 100.0
# Now loading file number 10 out of 100.0
# Now loading file number 11 out of 100.0
# Now loading file number 12 out of 100.0
# Now loading file number 13 out of 100.0
# Now loading file number 14 out of 100.0
# Now loading file number 15 out of 100.0
# Now loading file number 16 out of 100.0
# Now loading file number 17 out of 100.0
# Now loading file number 18 out of 100.0
# Now loading file number 19 out of 100.0
# Now loading file number 20 out of 100.0
# Now loading file number 21 out of 100.0
# Now loading file number 22 out of 100.0
# Now loading file number 23 out of 100.0
# Now loading file number 24 out of 100.0
# Now loading file number 25 out of 100.0
# Now loading file number 26 out of 100.0
# Now loading file number 27 out of 100.0
# Now loading file number 28 out of 100.0
# Now loading file number 29 out of 100.0
# Now loading file number 30 out of 100.0
# Now loading file number 31 out of 100.0
# Now loading file number 32 out of 100.0
# Now loading file number 33 out of 100.0
# Now loading file number 34 out of 100.0
# Now loading file number 35 out of 100.0
# Now loading file number 36 out of 100.0
# Now loading file number 37 out of 100.0
# Now loading file number 38 out of 100.0
# Now loading file number 39 out of 100.0
# Now loading file number 40 out of 100.0
# Now loading file number 41 out of 100.0
# Now loading file number 42 out of 100.0
# Now loading file number 43 out of 100.0
# Now loading file number 44 out of 100.0
# Now loading file number 45 out of 100.0
# Now loading file number 46 out of 100.0
# Now loading file number 47 out of 100.0
# Now loading file number 48 out of 100.0
# Now loading file number 49 out of 100.0
# Now loading file number 50 out of 100.0
# Now loading file number 51 out of 100.0
# Now loading file number 52 out of 100.0
# Now loading file number 53 out of 100.0
# Now loading file number 54 out of 100.0
# Now loading file number 55 out of 100.0
# Now loading file number 56 out of 100.0
# Now loading file number 57 out of 100.0
# Now loading file number 58 out of 100.0
# Now loading file number 59 out of 100.0
# Now loading file number 60 out of 100.0
# Now loading file number 61 out of 100.0
# Now loading file number 62 out of 100.0
# Now loading file number 63 out of 100.0
# Now loading file number 64 out of 100.0
# Now loading file number 65 out of 100.0
# Now loading file number 66 out of 100.0
# Now loading file number 67 out of 100.0
# Now loading file number 68 out of 100.0
# Now loading file number 69 out of 100.0
# Now loading file number 70 out of 100.0
# Now loading file number 71 out of 100.0
# Now loading file number 72 out of 100.0
# Now loading file number 73 out of 100.0
# Now loading file number 74 out of 100.0
# Now loading file number 75 out of 100.0
# Now loading file number 76 out of 100.0
# Now loading file number 77 out of 100.0
# Now loading file number 78 out of 100.0
# Now loading file number 79 out of 100.0
# Now loading file number 80 out of 100.0
# Now loading file number 81 out of 100.0
# Now loading file number 82 out of 100.0
# Now loading file number 83 out of 100.0
# Now loading file number 84 out of 100.0
# Now loading file number 85 out of 100.0
# Now loading file number 86 out of 100.0
# Now loading file number 87 out of 100.0
# Now loading file number 88 out of 100.0
# Now loading file number 89 out of 100.0
# Now loading file number 90 out of 100.0
# Now loading file number 91 out of 100.0
# Now loading file number 92 out of 100.0
# Now loading file number 93 out of 100.0
# Now loading file number 94 out of 100.0
# Now loading file number 95 out of 100.0
# Now loading file number 96 out of 100.0
# Now loading file number 97 out of 100.0
# Now loading file number 98 out of 100.0
# Now loading file number 99 out of 100.0
# Now loading file number 100 out of 100.0

# %%
predCNN = modelCNN.predict(test_ds_eval)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
predCNN = modelCNN.predict(train_ds_eval)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
train_ds_eval.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 train_ds_eval.shape
#
# AttributeError: '_BatchDataset' object has no attribute 'shape'

# %%
train_ds_eval
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 60, 20, 5), dtype=tf.float64, name=None), TensorSpec(shape=(None, 60, 20, 1), dtype=tf.float64, name=None))>

# %%
train_ds_eval
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 60, 20, 5), dtype=tf.float64, name=None), TensorSpec(shape=(None, 60, 20, 1), dtype=tf.float64, name=None))>

# %%
batchSize
# Out:
# np.int64(8)

# %%
RMSE = tf.keras.metrics.RootMeanSquaredError()

# %%
predCNN = modelCNN.predict(train_ds_eval)
predCNN_val = modelCNN.predict(val_ds_eval)
predCNN_test = modelCNN.predict(test_ds_eval)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %%
RMSE.update_state(train_ds_eval,predCNN)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 RMSE.update_state(train_ds_eval,predCNN)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\metrics\regression_metrics.py:244, in RootMeanSquaredError.update_state(self, y_true, y_pred, sample_weight)
#     230 def update_state(self, y_true, y_pred, sample_weight=None):
#     231     """Accumulates root mean squared error statistics.
#     232
#     233     Args:
#    (...)
#     242         Update op.
#     243     """
# --> 244     y_true = ops.convert_to_tensor(y_true, self._dtype)
#     245     y_pred = ops.convert_to_tensor(y_pred, self._dtype)
#     246     y_true, y_pred = squeeze_or_expand_to_same_rank(y_true, y_pred)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\ops\core.py:952, in convert_to_tensor(x, dtype, sparse)
#     950 if any_symbolic_tensors((x,)):
#     951     return ConvertToTensor(dtype=dtype, sparse=sparse)(x)
# --> 952 return backend.core.convert_to_tensor(x, dtype=dtype, sparse=sparse)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:143, in convert_to_tensor(x, dtype, sparse)
#     141         x = tf.convert_to_tensor(x)
#     142         return tf.cast(x, dtype)
# --> 143     return tf.convert_to_tensor(x, dtype=dtype)
#     144 elif dtype is not None and not x.dtype == dtype:
#     145     if isinstance(x, tf.SparseTensor):
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# ValueError: Attempt to convert a value (<_BatchDataset element_spec=(TensorSpec(shape=(None, 60, 20, 5), dtype=tf.float64, name=None), TensorSpec(shape=(None, 60, 20, 1), dtype=tf.float64, name=None))>) with an unsupported type (<class 'tensorflow.python.data.ops.batch_op._BatchDataset'>) to a Tensor.

# %%
predCNN
# Out:
# array([[[[-0.03017727],
#          [ 0.09601513],
#          [ 0.05404209],
#          ...,
#          [ 0.26261315],
#          [ 0.08000188],
#          [-0.06556879]],
#
#         [[ 0.02085762],
#          [-0.08329264],
#          [-0.03882654],
#          ...,
#          [ 0.07421422],
#          [-0.13402373],
#          [-0.1354771 ]],
#
#         [[-0.09337223],
#          [-0.06106073],
#          [ 0.00905002],
#          ...,
#          [-0.24816029],
#          [-0.3039007 ],
#          [-0.26785883]],
#
#         ...,
#
#         [[-0.0672708 ],
#          [-0.46925887],
#          [-0.3803274 ],
#          ...,
#          [-0.42883465],
#          [-0.34235355],
#          [-0.39295185]],
#
#         [[-0.03135575],
#          [-0.2433732 ],
#          [-0.19358349],
#          ...,
#          [-0.41723764],
#          [-0.34715426],
#          [-0.33176652]],
#
#         [[-0.02980205],
#          [-0.01393597],
#          [ 0.04358783],
#          ...,
#          [-0.20686491],
#          [-0.16790351],
#          [-0.10181649]]],
#
#
#        [[[-0.00330182],
#          [-0.06507489],
#          [-0.15897752],
#          ...,
#          [-0.14021142],
#          [-0.05628178],
#          [-0.06023674]],
#
#         [[ 0.004833  ],
#          [ 0.03693269],
#          [-0.09492058],
#          ...,
#          [ 0.00371996],
#          [ 0.09451207],
#          [-0.12750466]],
#
#         [[-0.04674507],
#          [-0.03313147],
#          [-0.11140443],
#          ...,
#          [ 0.3062851 ],
#          [ 0.2229616 ],
#          [-0.0017529 ]],
#
#         ...,
#
#         [[ 0.07146382],
#          [ 0.16476302],
#          [ 0.22601804],
#          ...,
#          [-1.0141956 ],
#          [-0.7053759 ],
#          [-0.6010376 ]],
#
#         [[ 0.14678052],
#          [ 0.17994094],
#          [ 0.144624  ],
#          ...,
#          [-0.86638415],
#          [-0.6270158 ],
#          [-0.44682947]],
#
#         [[ 0.06096438],
#          [ 0.09006763],
#          [ 0.11280753],
#          ...,
#          [-0.29199272],
#          [-0.2877465 ],
#          [-0.21052799]]],
#
#
#        [[[-0.07599613],
#          [-0.41054305],
#          [-0.32245585],
#          ...,
#          [-0.74626243],
#          [-0.6642335 ],
#          [-0.5451064 ]],
#
#         [[-0.16613574],
#          [-0.45881984],
#          [-0.42286474],
#          ...,
#          [-0.9010042 ],
#          [-0.87203556],
#          [-0.63553476]],
#
#         [[-0.19631355],
#          [-0.49388176],
#          [-0.29037285],
#          ...,
#          [-0.8890668 ],
#          [-0.9680604 ],
#          [-0.7536374 ]],
#
#         ...,
#
#         [[ 0.14680932],
#          [-0.06530241],
#          [-0.17416203],
#          ...,
#          [-0.24107386],
#          [-0.39120308],
#          [-0.5271069 ]],
#
#         [[ 0.00405406],
#          [-0.02057924],
#          [-0.02802042],
#          ...,
#          [-0.05675765],
#          [-0.11442621],
#          [-0.25755107]],
#
#         [[ 0.0070387 ],
#          [ 0.02462114],
#          [ 0.1380107 ],
#          ...,
#          [ 0.06183293],
#          [-0.00283942],
#          [-0.14057024]]],
#
#
#        ...,
#
#
#        [[[-0.12229151],
#          [-0.28349844],
#          [-0.254539  ],
#          ...,
#          [ 0.40845117],
#          [ 0.28061748],
#          [-0.04159713]],
#
#         [[-0.17226647],
#          [-0.33477268],
#          [-0.23873766],
#          ...,
#          [ 0.40298855],
#          [ 0.21516433],
#          [-0.02380498]],
#
#         [[-0.20621492],
#          [-0.38883862],
#          [-0.19492134],
#          ...,
#          [ 0.72179794],
#          [ 0.28261158],
#          [ 0.0944671 ]],
#
#         ...,
#
#         [[ 0.08341316],
#          [ 0.0017465 ],
#          [-0.13737738],
#          ...,
#          [ 0.25961217],
#          [ 0.08408349],
#          [-0.21951461]],
#
#         [[ 0.03618521],
#          [ 0.02928934],
#          [ 0.2446346 ],
#          ...,
#          [ 0.208543  ],
#          [-0.01457826],
#          [-0.05701493]],
#
#         [[ 0.16518505],
#          [ 0.16007763],
#          [ 0.2582733 ],
#          ...,
#          [-0.06952386],
#          [-0.13171908],
#          [-0.01902144]]],
#
#
#        [[[ 0.00929416],
#          [-0.3091663 ],
#          [-0.45223325],
#          ...,
#          [ 0.13291648],
#          [ 0.24230836],
#          [-0.09288248]],
#
#         [[ 0.01541963],
#          [-0.65115917],
#          [-1.0306382 ],
#          ...,
#          [ 0.24818811],
#          [ 0.30586386],
#          [ 0.02827091]],
#
#         [[ 0.1794795 ],
#          [-0.7494875 ],
#          [-1.1396477 ],
#          ...,
#          [ 0.18340705],
#          [ 0.12222679],
#          [-0.02293093]],
#
#         ...,
#
#         [[-0.0965817 ],
#          [-0.11718856],
#          [-0.10918695],
#          ...,
#          [-0.20211098],
#          [-0.28442338],
#          [-0.33465132]],
#
#         [[ 0.00457437],
#          [-0.06490357],
#          [-0.01672528],
#          ...,
#          [-0.07119107],
#          [-0.14367324],
#          [-0.21935211]],
#
#         [[ 0.05840216],
#          [-0.03823005],
#          [ 0.08571137],
#          ...,
#          [ 0.00492467],
#          [-0.06030841],
#          [-0.11262219]]],
#
#
#        [[[ 0.01764736],
#          [-0.4455223 ],
#          [-0.59824216],
#          ...,
#          [-0.35796997],
#          [-0.36691397],
#          [-0.37733167]],
#
#         [[ 0.07029101],
#          [-0.51756096],
#          [-0.5925917 ],
#          ...,
#          [-0.2230427 ],
#          [-0.15732612],
#          [-0.2339868 ]],
#
#         [[ 0.11644495],
#          [-0.36843044],
#          [-0.45603555],
#          ...,
#          [-0.3013343 ],
#          [-0.29325753],
#          [-0.24946587]],
#
#         ...,
#
#         [[-0.16599426],
#          [-0.3226061 ],
#          [-0.12397002],
#          ...,
#          [-0.6160234 ],
#          [-0.745395  ],
#          [-0.67448246]],
#
#         [[-0.04712567],
#          [-0.01954693],
#          [ 0.06395026],
#          ...,
#          [-0.35336804],
#          [-0.48293987],
#          [-0.50717   ]],
#
#         [[-0.08607372],
#          [ 0.02585923],
#          [ 0.10688651],
#          ...,
#          [-0.1638261 ],
#          [-0.22893149],
#          [-0.23480083]]]], dtype=float32)

# %%
modelCNN.evaluate(
    x=train_ds_eval,
    y=None,
    batch_size=None,
    verbose='auto',
    sample_weight=None,
    steps=None,
    callbacks=None,
    return_dict=False
)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8741 - mean_absolute_error: 0.8577 - mean_squared_error: 0.8741
# [0.8999228477478027, 0.8732779026031494, 0.8999229669570923]

# %%
modelCNN.evaluate(
    x=train_ds_eval,
    y=None,
    batch_size=None,
    verbose='auto',
    sample_weight=None,
    steps=None,
    callbacks=None,
    return_dict=True
)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.9632 - mean_absolute_error: 0.9084 - mean_squared_error: 0.9632
# {'loss': 0.9310072660446167,
#  'mean_absolute_error': 0.890872597694397,
#  'mean_squared_error': 0.9310072660446167}

# %%
y = np.concatenate([y for x, y in train_ds_eval], axis=0)

# %%
y
# Out:
# array([[[[0.40964118],
#          [0.49510294],
#          [0.54475365],
#          ...,
#          [0.64748419],
#          [0.6342865 ],
#          [0.59910304]],
#
#         [[0.40964118],
#          [0.49510294],
#          [0.54475365],
#          ...,
#          [0.64748419],
#          [0.6342865 ],
#          [0.59910304]],
#
#         [[0.4473532 ],
#          [0.47884189],
#          [0.50509638],
#          ...,
#          [0.55304176],
#          [0.57861639],
#          [0.64877468]],
#
#         ...,
#
#         [[0.32742196],
#          [0.36228851],
#          [0.39028414],
#          ...,
#          [0.60395726],
#          [0.61243593],
#          [0.63603521]],
#
#         [[0.3542636 ],
#          [0.37291474],
#          [0.39741712],
#          ...,
#          [0.7077027 ],
#          [0.69536647],
#          [0.64628146]],
#
#         [[0.3542636 ],
#          [0.37291474],
#          [0.39741712],
#          ...,
#          [0.7077027 ],
#          [0.69536647],
#          [0.64628146]]],
#
#
#        [[[0.42990696],
#          [0.50067061],
#          [0.52542382],
#          ...,
#          [0.55253001],
#          [0.56689161],
#          [0.5596373 ]],
#
#         [[0.42990696],
#          [0.50067061],
#          [0.52542382],
#          ...,
#          [0.55253001],
#          [0.56689161],
#          [0.5596373 ]],
#
#         [[0.61321678],
#          [0.52438558],
#          [0.49206308],
#          ...,
#          [0.49157026],
#          [0.50387842],
#          [0.54780794]],
#
#         ...,
#
#         [[0.45606168],
#          [0.51883568],
#          [0.55524185],
#          ...,
#          [0.88432952],
#          [0.88366812],
#          [0.81667791]],
#
#         [[0.45114796],
#          [0.50613066],
#          [0.54329501],
#          ...,
#          [0.86465288],
#          [0.90296905],
#          [1.        ]],
#
#         [[0.45114796],
#          [0.50613066],
#          [0.54329501],
#          ...,
#          [0.86465288],
#          [0.90296905],
#          [1.        ]]],
#
#
#        [[[0.49432774],
#          [0.42603454],
#          [0.40604155],
#          ...,
#          [0.50774779],
#          [0.4752893 ],
#          [0.41610592]],
#
#         [[0.49432774],
#          [0.42603454],
#          [0.40604155],
#          ...,
#          [0.50774779],
#          [0.4752893 ],
#          [0.41610592]],
#
#         [[0.38866487],
#          [0.41480801],
#          [0.41737133],
#          ...,
#          [0.5669854 ],
#          [0.58086222],
#          [0.59972926]],
#
#         ...,
#
#         [[0.64181344],
#          [0.57917069],
#          [0.55904146],
#          ...,
#          [0.32500173],
#          [0.3368955 ],
#          [0.38610161]],
#
#         [[0.50583507],
#          [0.58911274],
#          [0.62327332],
#          ...,
#          [0.45675287],
#          [0.41365587],
#          [0.31685103]],
#
#         [[0.50583507],
#          [0.58911274],
#          [0.62327332],
#          ...,
#          [0.45675287],
#          [0.41365587],
#          [0.31685103]]],
#
#
#        ...,
#
#
#        [[[0.56728635],
#          [0.58728274],
#          [0.59836162],
#          ...,
#          [0.5609837 ],
#          [0.53447926],
#          [0.5009346 ]],
#
#         [[0.56728635],
#          [0.58728274],
#          [0.59836162],
#          ...,
#          [0.5609837 ],
#          [0.53447926],
#          [0.5009346 ]],
#
#         [[0.55988629],
#          [0.6256325 ],
#          [0.64293566],
#          ...,
#          [0.5711765 ],
#          [0.52034253],
#          [0.44278405]],
#
#         ...,
#
#         [[0.53245204],
#          [0.5641435 ],
#          [0.58391283],
#          ...,
#          [0.8424678 ],
#          [0.89494027],
#          [0.9747763 ]],
#
#         [[0.54547051],
#          [0.53891698],
#          [0.5370361 ],
#          ...,
#          [0.91793552],
#          [0.88888374],
#          [0.84548081]],
#
#         [[0.54547051],
#          [0.53891698],
#          [0.5370361 ],
#          ...,
#          [0.91793552],
#          [0.88888374],
#          [0.84548081]]],
#
#
#        [[[0.52926308],
#          [0.67240748],
#          [0.73850033],
#          ...,
#          [0.58928777],
#          [0.64541022],
#          [0.78279647]],
#
#         [[0.52926308],
#          [0.67240748],
#          [0.73850033],
#          ...,
#          [0.58928777],
#          [0.64541022],
#          [0.78279647]],
#
#         [[0.56095377],
#          [0.59434885],
#          [0.63892837],
#          ...,
#          [0.68699451],
#          [0.68423591],
#          [0.66478089]],
#
#         ...,
#
#         [[0.8039947 ],
#          [0.70478286],
#          [0.65438472],
#          ...,
#          [0.48122861],
#          [0.46617274],
#          [0.41065408]],
#
#         [[0.79614927],
#          [0.75145731],
#          [0.71390868],
#          ...,
#          [0.39720849],
#          [0.37412089],
#          [0.34251426]],
#
#         [[0.79614927],
#          [0.75145731],
#          [0.71390868],
#          ...,
#          [0.39720849],
#          [0.37412089],
#          [0.34251426]]],
#
#
#        [[[0.4356763 ],
#          [0.44338135],
#          [0.44580441],
#          ...,
#          [0.61730586],
#          [0.61260234],
#          [0.5925686 ]],
#
#         [[0.4356763 ],
#          [0.44338135],
#          [0.44580441],
#          ...,
#          [0.61730586],
#          [0.61260234],
#          [0.5925686 ]],
#
#         [[0.41326229],
#          [0.45106169],
#          [0.46403638],
#          ...,
#          [0.60660809],
#          [0.60231154],
#          [0.61493962]],
#
#         ...,
#
#         [[0.63727593],
#          [0.65748447],
#          [0.6760869 ],
#          ...,
#          [0.57136768],
#          [0.58444663],
#          [0.65410243]],
#
#         [[0.55605341],
#          [0.62910768],
#          [0.64686912],
#          ...,
#          [0.60398736],
#          [0.62676078],
#          [0.64160738]],
#
#         [[0.55605341],
#          [0.62910768],
#          [0.64686912],
#          ...,
#          [0.60398736],
#          [0.62676078],
#          [0.64160738]]]])

# %%
images, labels = tuple(zip(*train_ds_eval))

# %%
labels
# Out:
# (<tf.Tensor: shape=(8, 60, 20, 1), dtype=float64, numpy=
#  array([[[[0.62978304],
#           [0.61582849],
#           [0.63036539],
#           ...,
#           [0.50395259],
#           [0.49446082],
#           [0.46591354]],
#
#          [[0.62978304],
#           [0.61582849],
#           [0.63036539],
#           ...,
#           [0.50395259],
#           [0.49446082],
#           [0.46591354]],
#
#          [[0.77415809],
#           [0.71228515],
#           [0.66327069],
#           ...,
#           [0.49968216],
#           [0.50992255],
#           [0.54588059]],
#
#          ...,
#
#          [[0.65046369],
#           [0.62113258],
#           [0.61375937],
#           ...,
#           [0.68006553],
#           [0.71894077],
#           [0.80038617]],
#
#          [[0.51349282],
#           [0.54749396],
#           [0.54681717],
#           ...,
#           [0.70921385],
#           [0.76395814],
#           [0.88820111]],
#
#          [[0.51349282],
#           [0.54749396],
#           [0.54681717],
#           ...,
#           [0.70921385],
#           [0.76395814],
#           [0.88820111]]],
#
#
#         [[[0.41437487],
#           [0.51963554],
#           [0.56408327],
#           ...,
#           [0.59175299],
#           [0.56950545],
#           [0.54538549]],
#
#          [[0.41437487],
#           [0.51963554],
#           [0.56408327],
#           ...,
#           [0.59175299],
#           [0.56950545],
#           [0.54538549]],
#
#          [[0.53833327],
#           [0.55181328],
#           [0.56794772],
#           ...,
#           [0.60487321],
#           [0.56572609],
#           [0.53814363]],
#
#          ...,
#
#          [[0.46417619],
#           [0.46654102],
#           [0.4692851 ],
#           ...,
#           [0.43657404],
#           [0.4195809 ],
#           [0.39391591]],
#
#          [[0.42468222],
#           [0.42150118],
#           [0.42515649],
#           ...,
#           [0.50490304],
#           [0.5054069 ],
#           [0.49330048]],
#
#          [[0.42468222],
#           [0.42150118],
#           [0.42515649],
#           ...,
#           [0.50490304],
#           [0.5054069 ],
#           [0.49330048]]],
#
#
#         [[[0.24751074],
#           [0.31236346],
#           [0.35335485],
#           ...,
#           [0.93305241],
#           [0.92054216],
#           [0.82779144]],
#
#          [[0.24751074],
#           [0.31236346],
#           [0.35335485],
#           ...,
#           [0.93305241],
#           [0.92054216],
#           [0.82779144]],
#
#          [[0.29415071],
#           [0.30717135],
#           [0.3266693 ],
#           ...,
#           [0.87827205],
#           [0.92110867],
#           [0.97101161]],
#
#          ...,
#
#          [[0.56052606],
#           [0.52094002],
#           [0.50484038],
#           ...,
#           [0.52626529],
#           [0.51000029],
#           [0.46832615]],
#
#          [[0.62920011],
#           [0.62992723],
#           [0.61565459],
#           ...,
#           [0.49794355],
#           [0.47454633],
#           [0.42884301]],
#
#          [[0.62920011],
#           [0.62992723],
#           [0.61565459],
#           ...,
#           [0.49794355],
#           [0.47454633],
#           [0.42884301]]],
#
#
#         ...,
#
#
#         [[[0.6780266 ],
#           [0.64878194],
#           [0.64649555],
#           ...,
#           [0.52449651],
#           [0.50295059],
#           [0.44151517]],
#
#          [[0.6780266 ],
#           [0.64878194],
#           [0.64649555],
#           ...,
#           [0.52449651],
#           [0.50295059],
#           [0.44151517]],
#
#          [[0.84667257],
#           [0.73917562],
#           [0.67828527],
#           ...,
#           [0.5392403 ],
#           [0.5442769 ],
#           [0.5640983 ]],
#
#          ...,
#
#          [[0.47444554],
#           [0.52012432],
#           [0.52925521],
#           ...,
#           [0.79286253],
#           [0.85740948],
#           [0.99469193]],
#
#          [[0.38230353],
#           [0.4373846 ],
#           [0.49126702],
#           ...,
#           [0.79062067],
#           [0.77361472],
#           [0.72196939]],
#
#          [[0.38230353],
#           [0.4373846 ],
#           [0.49126702],
#           ...,
#           [0.79062067],
#           [0.77361472],
#           [0.72196939]]],
#
#
#         [[[0.66771109],
#           [0.6853175 ],
#           [0.66856458],
#           ...,
#           [0.63266673],
#           [0.66411164],
#           [0.72348464]],
#
#          [[0.66771109],
#           [0.6853175 ],
#           [0.66856458],
#           ...,
#           [0.63266673],
#           [0.66411164],
#           [0.72348464]],
#
#          [[0.71041454],
#           [0.69948591],
#           [0.72547225],
#           ...,
#           [0.63253705],
#           [0.61810677],
#           [0.60717514]],
#
#          ...,
#
#          [[0.52126174],
#           [0.47720903],
#           [0.46223832],
#           ...,
#           [0.61735299],
#           [0.64046846],
#           [0.66268438]],
#
#          [[0.48708344],
#           [0.50535492],
#           [0.51236987],
#           ...,
#           [0.76331718],
#           [0.81749463],
#           [0.90659923]],
#
#          [[0.48708344],
#           [0.50535492],
#           [0.51236987],
#           ...,
#           [0.76331718],
#           [0.81749463],
#           [0.90659923]]],
#
#
#         [[[0.40096759],
#           [0.44484952],
#           [0.47573661],
#           ...,
#           [0.65513298],
#           [0.63209562],
#           [0.59497158]],
#
#          [[0.40096759],
#           [0.44484952],
#           [0.47573661],
#           ...,
#           [0.65513298],
#           [0.63209562],
#           [0.59497158]],
#
#          [[0.41722135],
#           [0.43378788],
#           [0.45930761],
#           ...,
#           [0.64602972],
#           [0.67616174],
#           [0.72698546]],
#
#          ...,
#
#          [[0.84890734],
#           [0.78409495],
#           [0.77500449],
#           ...,
#           [0.54538133],
#           [0.52760204],
#           [0.50825798]],
#
#          [[0.84472427],
#           [0.76628666],
#           [0.72827556],
#           ...,
#           [0.51040277],
#           [0.50780467],
#           [0.53044607]],
#
#          [[0.84472427],
#           [0.76628666],
#           [0.72827556],
#           ...,
#           [0.51040277],
#           [0.50780467],
#           [0.53044607]]]])>,
#  <tf.Tensor: shape=(8, 60, 20, 1), dtype=float64, numpy=
#  array([[[[0.48267962],
#           [0.51920627],
#           [0.543604  ],
#           ...,
#           [0.67351591],
#           [0.67261095],
#           [0.63273665]],
#
#          [[0.48267962],
#           [0.51920627],
#           [0.543604  ],
#           ...,
#           [0.67351591],
#           [0.67261095],
#           [0.63273665]],
#
#          [[0.55250962],
#           [0.6041566 ],
#           [0.63547048],
#           ...,
#           [0.61504412],
#           [0.59318878],
#           [0.60814026]],
#
#          ...,
#
#          [[0.35912469],
#           [0.37216465],
#           [0.376824  ],
#           ...,
#           [0.55222915],
#           [0.56489797],
#           [0.60903997]],
#
#          [[0.31960004],
#           [0.34410957],
#           [0.35783438],
#           ...,
#           [0.48589909],
#           [0.5189352 ],
#           [0.60183827]],
#
#          [[0.31960004],
#           [0.34410957],
#           [0.35783438],
#           ...,
#           [0.48589909],
#           [0.5189352 ],
#           [0.60183827]]],
#
#
#         [[[0.32110046],
#           [0.40443748],
#           [0.44488384],
#           ...,
#           [0.55659378],
#           [0.57065222],
#           [0.59506772]],
#
#          [[0.32110046],
#           [0.40443748],
#           [0.44488384],
#           ...,
#           [0.55659378],
#           [0.57065222],
#           [0.59506772]],
#
#          [[0.38158477],
#           [0.42871225],
#           [0.44747659],
#           ...,
#           [0.49856712],
#           [0.49003811],
#           [0.48991627]],
#
#          ...,
#
#          [[0.90517258],
#           [0.92654126],
#           [0.89551824],
#           ...,
#           [0.53070231],
#           [0.54087841],
#           [0.57580693]],
#
#          [[1.        ],
#           [0.84475624],
#           [0.76606847],
#           ...,
#           [0.65239725],
#           [0.62982966],
#           [0.58700712]],
#
#          [[1.        ],
#           [0.84475624],
#           [0.76606847],
#           ...,
#           [0.65239725],
#           [0.62982966],
#           [0.58700712]]],
#
#
#         [[[0.41671114],
#           [0.4479974 ],
#           [0.46723191],
#           ...,
#           [0.70568326],
#           [0.74464731],
#           [0.83255949]],
#
#          [[0.41671114],
#           [0.4479974 ],
#           [0.46723191],
#           ...,
#           [0.70568326],
#           [0.74464731],
#           [0.83255949]],
#
#          [[0.46092473],
#           [0.51820841],
#           [0.56770482],
#           ...,
#           [0.76209767],
#           [0.80652667],
#           [0.86503506]],
#
#          ...,
#
#          [[0.59686804],
#           [0.56669208],
#           [0.54040133],
#           ...,
#           [0.56845084],
#           [0.55680591],
#           [0.5476613 ]],
#
#          [[0.60713909],
#           [0.61435995],
#           [0.60391529],
#           ...,
#           [0.63994183],
#           [0.69018072],
#           [0.77317162]],
#
#          [[0.60713909],
#           [0.61435995],
#           [0.60391529],
#           ...,
#           [0.63994183],
#           [0.69018072],
#           [0.77317162]]],
#
#
#         ...,
#
#
#         [[[0.83810139],
#           [0.85206807],
#           [0.84093053],
#           ...,
#           [0.54824266],
#           [0.51211034],
#           [0.477739  ]],
#
#          [[0.83810139],
#           [0.85206807],
#           [0.84093053],
#           ...,
#           [0.54824266],
#           [0.51211034],
#           [0.477739  ]],
#
#          [[0.76422779],
#           [0.80659396],
#           [0.83167134],
#           ...,
#           [0.63390263],
#           [0.62798083],
#           [0.58706272]],
#
#          ...,
#
#          [[0.71756965],
#           [0.6810247 ],
#           [0.64398649],
#           ...,
#           [0.57243391],
#           [0.5599754 ],
#           [0.53252481]],
#
#          [[0.77535675],
#           [0.67887209],
#           [0.62290132],
#           ...,
#           [0.58133526],
#           [0.59324429],
#           [0.61062943]],
#
#          [[0.77535675],
#           [0.67887209],
#           [0.62290132],
#           ...,
#           [0.58133526],
#           [0.59324429],
#           [0.61062943]]],
#
#
#         [[[0.56584518],
#           [0.5366678 ],
#           [0.52413807],
#           ...,
#           [0.7510212 ],
#           [0.76804445],
#           [0.83588562]],
#
#          [[0.56584518],
#           [0.5366678 ],
#           [0.52413807],
#           ...,
#           [0.7510212 ],
#           [0.76804445],
#           [0.83588562]],
#
#          [[0.51870257],
#           [0.54876679],
#           [0.5735827 ],
#           ...,
#           [0.64647492],
#           [0.65437393],
#           [0.63862647]],
#
#          ...,
#
#          [[0.54610471],
#           [0.55702081],
#           [0.55883988],
#           ...,
#           [0.68727246],
#           [0.71886795],
#           [0.74485506]],
#
#          [[0.62390709],
#           [0.65285419],
#           [0.65405558],
#           ...,
#           [0.79743626],
#           [0.87162177],
#           [1.        ]],
#
#          [[0.62390709],
#           [0.65285419],
#           [0.65405558],
#           ...,
#           [0.79743626],
#           [0.87162177],
#           [1.        ]]],
#
#
#         [[[0.71365843],
#           [0.60300473],
#           [0.56366823],
#           ...,
#           [0.78436955],
#           [0.80092203],
#           [0.79896251]],
#
#          [[0.71365843],
#           [0.60300473],
#           [0.56366823],
#           ...,
#           [0.78436955],
#           [0.80092203],
#           [0.79896251]],
#
#          [[0.68276686],
#           [0.66703384],
#           [0.64453245],
#           ...,
#           [0.79152651],
#           [0.8081696 ],
#           [0.86839425]],
#
#          ...,
#
#          [[0.54327023],
#           [0.58451811],
#           [0.61040251],
#           ...,
#           [0.6132583 ],
#           [0.60783607],
#           [0.6009071 ]],
#
#          [[0.66710198],
#           [0.64714607],
#           [0.63854408],
#           ...,
#           [0.63714419],
#           [0.59467858],
#           [0.51142382]],
#
#          [[0.66710198],
#           [0.64714607],
#           [0.63854408],
#           ...,
#           [0.63714419],
#           [0.59467858],
#           [0.51142382]]]])>,
#  <tf.Tensor: shape=(8, 60, 20, 1), dtype=float64, numpy=
#  array([[[[0.47084033],
#           [0.47528254],
#           [0.50040742],
#           ...,
#           [0.8718596 ],
#           [0.91846505],
#           [1.        ]],
#
#          [[0.47084033],
#           [0.47528254],
#           [0.50040742],
#           ...,
#           [0.8718596 ],
#           [0.91846505],
#           [1.        ]],
#
#          [[0.53649962],
#           [0.53813866],
#           [0.53200231],
#           ...,
#           [0.76860288],
#           [0.75939541],
#           [0.73861441]],
#
#          ...,
#
#          [[0.61879525],
#           [0.60708578],
#           [0.60356109],
#           ...,
#           [0.65182433],
#           [0.63470792],
#           [0.58172597]],
#
#          [[0.60544553],
#           [0.59968078],
#           [0.60599489],
#           ...,
#           [0.67353361],
#           [0.69454997],
#           [0.76378912]],
#
#          [[0.60544553],
#           [0.59968078],
#           [0.60599489],
#           ...,
#           [0.67353361],
#           [0.69454997],
#           [0.76378912]]],
#
#
#         [[[0.60575653],
#           [0.58530219],
#           [0.57578978],
#           ...,
#           [0.48485531],
#           [0.46865804],
#           [0.49234256]],
#
#          [[0.60575653],
#           [0.58530219],
#           [0.57578978],
#           ...,
#           [0.48485531],
#           [0.46865804],
#           [0.49234256]],
#
#          [[0.63090261],
#           [0.61419812],
#           [0.60902213],
#           ...,
#           [0.51653616],
#           [0.49532551],
#           [0.43089867]],
#
#          ...,
#
#          [[0.54589454],
#           [0.52552185],
#           [0.5071646 ],
#           ...,
#           [0.6869641 ],
#           [0.68939807],
#           [0.71218854]],
#
#          [[0.63446288],
#           [0.60561571],
#           [0.59711913],
#           ...,
#           [0.51915876],
#           [0.52724073],
#           [0.55450397]],
#
#          [[0.63446288],
#           [0.60561571],
#           [0.59711913],
#           ...,
#           [0.51915876],
#           [0.52724073],
#           [0.55450397]]],
#
#
#         [[[0.60973418],
#           [0.62316954],
#           [0.62612398],
#           ...,
#           [0.43461423],
#           [0.43014334],
#           [0.41093089]],
#
#          [[0.60973418],
#           [0.62316954],
#           [0.62612398],
#           ...,
#           [0.43461423],
#           [0.43014334],
#           [0.41093089]],
#
#          [[0.65928678],
#           [0.64722023],
#           [0.64721366],
#           ...,
#           [0.40599506],
#           [0.39000838],
#           [0.37550419]],
#
#          ...,
#
#          [[0.4230324 ],
#           [0.48868505],
#           [0.52838517],
#           ...,
#           [0.82345339],
#           [0.82245958],
#           [0.76668553]],
#
#          [[0.40997521],
#           [0.43394837],
#           [0.45866159],
#           ...,
#           [0.63458653],
#           [0.67544013],
#           [0.77516686]],
#
#          [[0.40997521],
#           [0.43394837],
#           [0.45866159],
#           ...,
#           [0.63458653],
#           [0.67544013],
#           [0.77516686]]],
#
#
#         ...,
#
#
#         [[[0.51400738],
#           [0.4903568 ],
#           [0.47871987],
#           ...,
#           [0.60231489],
#           [0.58525216],
#           [0.52439011]],
#
#          [[0.51400738],
#           [0.4903568 ],
#           [0.47871987],
#           ...,
#           [0.60231489],
#           [0.58525216],
#           [0.52439011]],
#
#          [[0.6321955 ],
#           [0.61540314],
#           [0.59217008],
#           ...,
#           [0.56872359],
#           [0.55008014],
#           [0.54362901]],
#
#          ...,
#
#          [[0.65202159],
#           [0.69488866],
#           [0.7126438 ],
#           ...,
#           [0.62194571],
#           [0.63455078],
#           [0.63881718]],
#
#          [[0.59376439],
#           [0.63844123],
#           [0.67307959],
#           ...,
#           [0.58118283],
#           [0.5988383 ],
#           [0.62324813]],
#
#          [[0.59376439],
#           [0.63844123],
#           [0.67307959],
#           ...,
#           [0.58118283],
#           [0.5988383 ],
#           [0.62324813]]],
#
#
#         [[[0.85365356],
#           [0.7426229 ],
#           [0.68983102],
#           ...,
#           [0.63990104],
#           [0.60975833],
#           [0.55719187]],
#
#          [[0.85365356],
#           [0.7426229 ],
#           [0.68983102],
#           ...,
#           [0.63990104],
#           [0.60975833],
#           [0.55719187]],
#
#          [[0.79243087],
#           [0.81202376],
#           [0.84051302],
#           ...,
#           [0.50027537],
#           [0.47856036],
#           [0.45134189]],
#
#          ...,
#
#          [[0.66736609],
#           [0.58442161],
#           [0.56418574],
#           ...,
#           [0.66516446],
#           [0.65629683],
#           [0.62099158]],
#
#          [[0.53277521],
#           [0.59810349],
#           [0.61659564],
#           ...,
#           [0.73871008],
#           [0.72112579],
#           [0.66833541]],
#
#          [[0.53277521],
#           [0.59810349],
#           [0.61659564],
#           ...,
#           [0.73871008],
#           [0.72112579],
#           [0.66833541]]],
#
#
#         [[[0.38606061],
#           [0.4354292 ],
#           [0.47869855],
#           ...,
#           [0.79869231],
#           [0.78604668],
#           [0.74132058]],
#
#          [[0.38606061],
#           [0.4354292 ],
#           [0.47869855],
#           ...,
#           [0.79869231],
#           [0.78604668],
#           [0.74132058]],
#
#          [[0.42314455],
#           [0.46633315],
#           [0.49315218],
#           ...,
#           [0.84061769],
#           [0.8144544 ],
#           [0.77781817]],
#
#          ...,
#
#          [[0.52884166],
#           [0.55235358],
#           [0.56586886],
#           ...,
#           [0.6488273 ],
#           [0.6365903 ],
#           [0.57787275]],
#
#          [[0.55311904],
#           [0.51251176],
#           [0.49007015],
#           ...,
#           [0.61059377],
#           [0.60691758],
#           [0.59044755]],
#
#          [[0.55311904],
#           [0.51251176],
#           [0.49007015],
#           ...,
#           [0.61059377],
#           [0.60691758],
#           [0.59044755]]]])>,
#  <tf.Tensor: shape=(8, 60, 20, 1), dtype=float64, numpy=
#  array([[[[0.46801614],
#           [0.46549989],
#           [0.46527605],
#           ...,
#           [0.58895044],
#           [0.60920404],
#           [0.61708586]],
#
#          [[0.46801614],
#           [0.46549989],
#           [0.46527605],
#           ...,
#           [0.58895044],
#           [0.60920404],
#           [0.61708586]],
#
#          [[0.50463758],
#           [0.51548917],
#           [0.51874897],
#           ...,
#           [0.57380795],
#           [0.58281957],
#           [0.6485473 ]],
#
#          ...,
#
#          [[0.70295298],
#           [0.65280621],
#           [0.63949305],
#           ...,
#           [0.87516237],
#           [0.84364209],
#           [0.82463813]],
#
#          [[0.70674253],
#           [0.70130418],
#           [0.68078643],
#           ...,
#           [0.8945038 ],
#           [0.83785661],
#           [0.72302154]],
#
#          [[0.70674253],
#           [0.70130418],
#           [0.68078643],
#           ...,
#           [0.8945038 ],
#           [0.83785661],
#           [0.72302154]]],
#
#
#         [[[0.50807906],
#           [0.46144736],
#           [0.44027645],
#           ...,
#           [0.44742259],
#           [0.43058803],
#           [0.36874008]],
#
#          [[0.50807906],
#           [0.46144736],
#           [0.44027645],
#           ...,
#           [0.44742259],
#           [0.43058803],
#           [0.36874008]],
#
#          [[0.53587327],
#           [0.51175142],
#           [0.49677764],
#           ...,
#           [0.46941491],
#           [0.47677218],
#           [0.48537153]],
#
#          ...,
#
#          [[0.7196658 ],
#           [0.69428769],
#           [0.69099002],
#           ...,
#           [0.51360163],
#           [0.48831087],
#           [0.43855363]],
#
#          [[0.74499103],
#           [0.72217879],
#           [0.69309056],
#           ...,
#           [0.51552081],
#           [0.48709985],
#           [0.42480084]],
#
#          [[0.74499103],
#           [0.72217879],
#           [0.69309056],
#           ...,
#           [0.51552081],
#           [0.48709985],
#           [0.42480084]]],
#
#
#         [[[0.45263997],
#           [0.44116079],
#           [0.43930856],
#           ...,
#           [0.51787214],
#           [0.5153601 ],
#           [0.52459454]],
#
#          [[0.45263997],
#           [0.44116079],
#           [0.43930856],
#           ...,
#           [0.51787214],
#           [0.5153601 ],
#           [0.52459454]],
#
#          [[0.43514753],
#           [0.44430165],
#           [0.45475298],
#           ...,
#           [0.51086276],
#           [0.52435951],
#           [0.55170496]],
#
#          ...,
#
#          [[0.31030942],
#           [0.31819024],
#           [0.3239045 ],
#           ...,
#           [0.42108565],
#           [0.40723746],
#           [0.39132554]],
#
#          [[0.30836448],
#           [0.33565625],
#           [0.35236056],
#           ...,
#           [0.41704443],
#           [0.41329635],
#           [0.40764673]],
#
#          [[0.30836448],
#           [0.33565625],
#           [0.35236056],
#           ...,
#           [0.41704443],
#           [0.41329635],
#           [0.40764673]]],
#
#
#         ...,
#
#
#         [[[0.95080347],
#           [0.96285083],
#           [0.96344461],
#           ...,
#           [0.98373078],
#           [0.99825384],
#           [1.        ]],
#
#          [[0.95080347],
#           [0.96285083],
#           [0.96344461],
#           ...,
#           [0.98373078],
#           [0.99825384],
#           [1.        ]],
#
#          [[0.71437165],
#           [0.76894254],
#           [0.80944507],
#           ...,
#           [0.96309217],
#           [0.96967773],
#           [0.94377039]],
#
#          ...,
#
#          [[0.53415064],
#           [0.5609583 ],
#           [0.5775767 ],
#           ...,
#           [0.73951089],
#           [0.70539947],
#           [0.63897599]],
#
#          [[0.61570511],
#           [0.62907702],
#           [0.65161658],
#           ...,
#           [0.67045268],
#           [0.61350833],
#           [0.56095128]],
#
#          [[0.61570511],
#           [0.62907702],
#           [0.65161658],
#           ...,
#           [0.67045268],
#           [0.61350833],
#           [0.56095128]]],
#
#
#         [[[0.56771044],
#           [0.56264179],
#           [0.56422163],
#           ...,
#           [0.55818913],
#           [0.58392078],
#           [0.62311255]],
#
#          [[0.56771044],
#           [0.56264179],
#           [0.56422163],
#           ...,
#           [0.55818913],
#           [0.58392078],
#           [0.62311255]],
#
#          [[0.48065329],
#           [0.53661264],
#           [0.57012228],
#           ...,
#           [0.60892793],
#           [0.62626044],
#           [0.67603595]],
#
#          ...,
#
#          [[0.65982746],
#           [0.64668644],
#           [0.65189748],
#           ...,
#           [0.65227044],
#           [0.65002583],
#           [0.63894147]],
#
#          [[0.70888721],
#           [0.68557355],
#           [0.68043362],
#           ...,
#           [0.49493777],
#           [0.45232787],
#           [0.37427655]],
#
#          [[0.70888721],
#           [0.68557355],
#           [0.68043362],
#           ...,
#           [0.49493777],
#           [0.45232787],
#           [0.37427655]]],
#
#
#         [[[0.48314534],
#           [0.47727196],
#           [0.46824611],
#           ...,
#           [0.49955587],
#           [0.45650203],
#           [0.39761264]],
#
#          [[0.48314534],
#           [0.47727196],
#           [0.46824611],
#           ...,
#           [0.49955587],
#           [0.45650203],
#           [0.39761264]],
#
#          [[0.3968247 ],
#           [0.40520811],
#           [0.41128394],
#           ...,
#           [0.62172793],
#           [0.56504942],
#           [0.46775656]],
#
#          ...,
#
#          [[0.27683862],
#           [0.2864109 ],
#           [0.30126144],
#           ...,
#           [0.3695185 ],
#           [0.38655136],
#           [0.43053492]],
#
#          [[0.25163579],
#           [0.28750821],
#           [0.30087561],
#           ...,
#           [0.37100452],
#           [0.38140293],
#           [0.40027606]],
#
#          [[0.25163579],
#           [0.28750821],
#           [0.30087561],
#           ...,
#           [0.37100452],
#           [0.38140293],
#           [0.40027606]]]])>,
#  <tf.Tensor: shape=(8, 60, 20, 1), dtype=float64, numpy=
#  array([[[[0.7642305 ],
#           [0.72194867],
#           [0.70489318],
#           ...,
#           [0.50568523],
#           [0.49987637],
#           [0.47605115]],
#
#          [[0.7642305 ],
#           [0.72194867],
#           [0.70489318],
#           ...,
#           [0.50568523],
#           [0.49987637],
#           [0.47605115]],
#
#          [[0.72116985],
#           [0.69279127],
#           [0.66905236],
#           ...,
#           [0.50310783],
#           [0.49518692],
#           [0.47859148]],
#
#          ...,
#
#          [[0.52921047],
#           [0.53543481],
#           [0.55437972],
#           ...,
#           [0.739286  ],
#           [0.77264513],
#           [0.80437598]],
#
#          [[0.68334807],
#           [0.65096116],
#           [0.60822321],
#           ...,
#           [0.74297455],
#           [0.77619168],
#           [0.86914395]],
#
#          [[0.68334807],
#           [0.65096116],
#           [0.60822321],
#           ...,
#           [0.74297455],
#           [0.77619168],
#           [0.86914395]]],
#
#
#         [[[0.49431274],
#           [0.59646372],
#           [0.62769989],
#           ...,
#           [0.64851656],
#           [0.65030848],
#           [0.61238481]],
#
#          [[0.49431274],
#           [0.59646372],
#           [0.62769989],
#           ...,
#           [0.64851656],
#           [0.65030848],
#           [0.61238481]],
#
#          [[0.50998734],
#           [0.48828216],
#           [0.4882459 ],
#           ...,
#           [0.53733375],
#           [0.53809522],
#           [0.56008929]],
#
#          ...,
#
#          [[0.66922091],
#           [0.62491033],
#           [0.59654646],
#           ...,
#           [0.77352344],
#           [0.77617245],
#           [0.83358946]],
#
#          [[0.63162169],
#           [0.60768361],
#           [0.59445104],
#           ...,
#           [0.71792498],
#           [0.71338338],
#           [0.68103956]],
#
#          [[0.63162169],
#           [0.60768361],
#           [0.59445104],
#           ...,
#           [0.71792498],
#           [0.71338338],
#           [0.68103956]]],
#
#
#         [[[0.62774239],
#           [0.62267357],
#           [0.62922592],
#           ...,
#           [0.45368582],
#           [0.45547409],
#           [0.46334424]],
#
#          [[0.62774239],
#           [0.62267357],
#           [0.62922592],
#           ...,
#           [0.45368582],
#           [0.45547409],
#           [0.46334424]],
#
#          [[0.44526235],
#           [0.47216087],
#           [0.47191815],
#           ...,
#           [0.45432912],
#           [0.45645253],
#           [0.46705273]],
#
#          ...,
#
#          [[0.31699906],
#           [0.29879912],
#           [0.29880366],
#           ...,
#           [0.67066996],
#           [0.78561991],
#           [1.        ]],
#
#          [[0.40397643],
#           [0.39421711],
#           [0.38020306],
#           ...,
#           [0.54953124],
#           [0.53715355],
#           [0.4782268 ]],
#
#          [[0.40397643],
#           [0.39421711],
#           [0.38020306],
#           ...,
#           [0.54953124],
#           [0.53715355],
#           [0.4782268 ]]],
#
#
#         ...,
#
#
#         [[[0.49432774],
#           [0.42603454],
#           [0.40604155],
#           ...,
#           [0.50774779],
#           [0.4752893 ],
#           [0.41610592]],
#
#          [[0.49432774],
#           [0.42603454],
#           [0.40604155],
#           ...,
#           [0.50774779],
#           [0.4752893 ],
#           [0.41610592]],
#
#          [[0.38866487],
#           [0.41480801],
#           [0.41737133],
#           ...,
#           [0.5669854 ],
#           [0.58086222],
#           [0.59972926]],
#
#          ...,
#
#          [[0.64181344],
#           [0.57917069],
#           [0.55904146],
#           ...,
#           [0.32500173],
#           [0.3368955 ],
#           [0.38610161]],
#
#          [[0.50583507],
#           [0.58911274],
#           [0.62327332],
#           ...,
#           [0.45675287],
#           [0.41365587],
#           [0.31685103]],
#
#          [[0.50583507],
#           [0.58911274],
#           [0.62327332],
#           ...,
#           [0.45675287],
#           [0.41365587],
#           [0.31685103]]],
#
#
#         [[[0.57880276],
#           [0.54333904],
#           [0.54908258],
#           ...,
#           [0.6176281 ],
#           [0.63489677],
#           [0.65251505]],
#
#          [[0.57880276],
#           [0.54333904],
#           [0.54908258],
#           ...,
#           [0.6176281 ],
#           [0.63489677],
#           [0.65251505]],
#
#          [[0.56454904],
#           [0.65391908],
#           [0.68805069],
#           ...,
#           [0.48371614],
#           [0.4963363 ],
#           [0.52191442]],
#
#          ...,
#
#          [[0.68627079],
#           [0.71080048],
#           [0.71080788],
#           ...,
#           [0.59106541],
#           [0.55728064],
#           [0.51326657]],
#
#          [[0.70569957],
#           [0.7003323 ],
#           [0.72967863],
#           ...,
#           [0.61032023],
#           [0.5965125 ],
#           [0.56899694]],
#
#          [[0.70569957],
#           [0.7003323 ],
#           [0.72967863],
#           ...,
#           [0.61032023],
#           [0.5965125 ],
#           [0.56899694]]],
#
#
#         [[[0.31856311],
#           [0.37178486],
#           [0.4093101 ],
#           ...,
#           [0.64975013],
#           [0.67104321],
#           [0.69944424]],
#
#          [[0.31856311],
#           [0.37178486],
#           [0.4093101 ],
#           ...,
#           [0.64975013],
#           [0.67104321],
#           [0.69944424]],
#
#          [[0.29027599],
#           [0.34775531],
#           [0.39415477],
#           ...,
#           [0.69481569],
#           [0.72566974],
#           [0.7783837 ]],
#
#          ...,
#
#          [[0.57690857],
#           [0.55819901],
#           [0.560134  ],
#           ...,
#           [0.58293082],
#           [0.57040454],
#           [0.53449358]],
#
#          [[0.56018239],
#           [0.58794873],
#           [0.60961745],
#           ...,
#           [0.50848779],
#           [0.53674539],
#           [0.59412284]],
#
#          [[0.56018239],
#           [0.58794873],
#           [0.60961745],
#           ...,
#           [0.50848779],
#           [0.53674539],
#           [0.59412284]]]])>,
#  <tf.Tensor: shape=(8, 60, 20, 1), dtype=float64, numpy=
#  array([[[[0.33291065],
#           [0.36684518],
#           [0.39002165],
#           ...,
#           [0.40943471],
#           [0.40798872],
#           [0.42142137]],
#
#          [[0.33291065],
#           [0.36684518],
#           [0.39002165],
#           ...,
#           [0.40943471],
#           [0.40798872],
#           [0.42142137]],
#
#          [[0.37670574],
#           [0.41196477],
#           [0.4303398 ],
#           ...,
#           [0.44200087],
#           [0.45287666],
#           [0.44087802]],
#
#          ...,
#
#          [[0.49814654],
#           [0.49097241],
#           [0.48661595],
#           ...,
#           [0.65369228],
#           [0.63225708],
#           [0.6037665 ]],
#
#          [[0.59593406],
#           [0.51186181],
#           [0.46639061],
#           ...,
#           [0.60754421],
#           [0.61071256],
#           [0.63536842]],
#
#          [[0.59593406],
#           [0.51186181],
#           [0.46639061],
#           ...,
#           [0.60754421],
#           [0.61071256],
#           [0.63536842]]],
#
#
#         [[[0.42228027],
#           [0.59386237],
#           [0.66410091],
#           ...,
#           [0.51374205],
#           [0.47227938],
#           [0.42560936]],
#
#          [[0.42228027],
#           [0.59386237],
#           [0.66410091],
#           ...,
#           [0.51374205],
#           [0.47227938],
#           [0.42560936]],
#
#          [[0.85388942],
#           [0.84765759],
#           [0.79517319],
#           ...,
#           [0.57363619],
#           [0.55921798],
#           [0.51700789]],
#
#          ...,
#
#          [[0.54940135],
#           [0.53816903],
#           [0.53050228],
#           ...,
#           [0.45991718],
#           [0.44708338],
#           [0.40260062]],
#
#          [[0.46291974],
#           [0.46150099],
#           [0.46814834],
#           ...,
#           [0.51821826],
#           [0.49441718],
#           [0.43916619]],
#
#          [[0.46291974],
#           [0.46150099],
#           [0.46814834],
#           ...,
#           [0.51821826],
#           [0.49441718],
#           [0.43916619]]],
#
#
#         [[[0.56573231],
#           [0.62866027],
#           [0.65776884],
#           ...,
#           [0.63590375],
#           [0.65814575],
#           [0.69234679]],
#
#          [[0.56573231],
#           [0.62866027],
#           [0.65776884],
#           ...,
#           [0.63590375],
#           [0.65814575],
#           [0.69234679]],
#
#          [[0.6145782 ],
#           [0.62104161],
#           [0.63308929],
#           ...,
#           [0.63903177],
#           [0.64362508],
#           [0.63829883]],
#
#          ...,
#
#          [[0.4875023 ],
#           [0.45807691],
#           [0.44554487],
#           ...,
#           [0.38922556],
#           [0.39971305],
#           [0.41042617]],
#
#          [[0.47650114],
#           [0.43479465],
#           [0.40416234],
#           ...,
#           [0.43085854],
#           [0.41919153],
#           [0.38760164]],
#
#          [[0.47650114],
#           [0.43479465],
#           [0.40416234],
#           ...,
#           [0.43085854],
#           [0.41919153],
#           [0.38760164]]],
#
#
#         ...,
#
#
#         [[[0.95339087],
#           [0.94359481],
#           [0.92072615],
#           ...,
#           [0.55647195],
#           [0.54457261],
#           [0.52567216]],
#
#          [[0.95339087],
#           [0.94359481],
#           [0.92072615],
#           ...,
#           [0.55647195],
#           [0.54457261],
#           [0.52567216]],
#
#          [[0.82604618],
#           [0.78999468],
#           [0.76079551],
#           ...,
#           [0.50793995],
#           [0.49662046],
#           [0.50291783]],
#
#          ...,
#
#          [[0.49795503],
#           [0.49870293],
#           [0.48995939],
#           ...,
#           [0.46320997],
#           [0.45944568],
#           [0.46328347]],
#
#          [[0.5736682 ],
#           [0.50918038],
#           [0.48416669],
#           ...,
#           [0.42464116],
#           [0.414128  ],
#           [0.43242956]],
#
#          [[0.5736682 ],
#           [0.50918038],
#           [0.48416669],
#           ...,
#           [0.42464116],
#           [0.414128  ],
#           [0.43242956]]],
#
#
#         [[[0.9513002 ],
#           [0.84864085],
#           [0.79640095],
#           ...,
#           [0.39443038],
#           [0.38619185],
#           [0.37228485]],
#
#          [[0.9513002 ],
#           [0.84864085],
#           [0.79640095],
#           ...,
#           [0.39443038],
#           [0.38619185],
#           [0.37228485]],
#
#          [[0.7538572 ],
#           [0.6943011 ],
#           [0.6649058 ],
#           ...,
#           [0.47263004],
#           [0.46316875],
#           [0.45617824]],
#
#          ...,
#
#          [[0.63850857],
#           [0.66197916],
#           [0.64181245],
#           ...,
#           [0.46749133],
#           [0.4772725 ],
#           [0.49905643]],
#
#          [[0.62809613],
#           [0.5376972 ],
#           [0.49785991],
#           ...,
#           [0.53527017],
#           [0.53364186],
#           [0.4978793 ]],
#
#          [[0.62809613],
#           [0.5376972 ],
#           [0.49785991],
#           ...,
#           [0.53527017],
#           [0.53364186],
#           [0.4978793 ]]],
#
#
#         [[[0.57564569],
#           [0.6122875 ],
#           [0.6294801 ],
#           ...,
#           [0.51861129],
#           [0.49218443],
#           [0.43435573]],
#
#          [[0.57564569],
#           [0.6122875 ],
#           [0.6294801 ],
#           ...,
#           [0.51861129],
#           [0.49218443],
#           [0.43435573]],
#
#          [[0.66403323],
#           [0.67525519],
#           [0.67944194],
#           ...,
#           [0.57688731],
#           [0.57710092],
#           [0.574624  ]],
#
#          ...,
#
#          [[0.50657797],
#           [0.51272947],
#           [0.51301262],
#           ...,
#           [0.63859622],
#           [0.65153787],
#           [0.68115114]],
#
#          [[0.51379769],
#           [0.51801201],
#           [0.5292972 ],
#           ...,
#           [0.68737665],
#           [0.66798149],
#           [0.61358106]],
#
#          [[0.51379769],
#           [0.51801201],
#           [0.5292972 ],
#           ...,
#           [0.68737665],
#           [0.66798149],
#           [0.61358106]]]])>,
#  <tf.Tensor: shape=(8, 60, 20, 1), dtype=float64, numpy=
#  array([[[[0.40964118],
#           [0.49510294],
#           [0.54475365],
#           ...,
#           [0.64748419],
#           [0.6342865 ],
#           [0.59910304]],
#
#          [[0.40964118],
#           [0.49510294],
#           [0.54475365],
#           ...,
#           [0.64748419],
#           [0.6342865 ],
#           [0.59910304]],
#
#          [[0.4473532 ],
#           [0.47884189],
#           [0.50509638],
#           ...,
#           [0.55304176],
#           [0.57861639],
#           [0.64877468]],
#
#          ...,
#
#          [[0.32742196],
#           [0.36228851],
#           [0.39028414],
#           ...,
#           [0.60395726],
#           [0.61243593],
#           [0.63603521]],
#
#          [[0.3542636 ],
#           [0.37291474],
#           [0.39741712],
#           ...,
#           [0.7077027 ],
#           [0.69536647],
#           [0.64628146]],
#
#          [[0.3542636 ],
#           [0.37291474],
#           [0.39741712],
#           ...,
#           [0.7077027 ],
#           [0.69536647],
#           [0.64628146]]],
#
#
#         [[[0.39211593],
#           [0.44005105],
#           [0.44379219],
#           ...,
#           [0.48212811],
#           [0.4920296 ],
#           [0.49271766]],
#
#          [[0.39211593],
#           [0.44005105],
#           [0.44379219],
#           ...,
#           [0.48212811],
#           [0.4920296 ],
#           [0.49271766]],
#
#          [[0.41305611],
#           [0.39586971],
#           [0.39568553],
#           ...,
#           [0.53064889],
#           [0.52811547],
#           [0.52555223]],
#
#          ...,
#
#          [[0.45695513],
#           [0.49486334],
#           [0.50678774],
#           ...,
#           [0.4074914 ],
#           [0.39244395],
#           [0.3735066 ]],
#
#          [[0.41168879],
#           [0.50470874],
#           [0.5603696 ],
#           ...,
#           [0.39940272],
#           [0.41022498],
#           [0.43549034]],
#
#          [[0.41168879],
#           [0.50470874],
#           [0.5603696 ],
#           ...,
#           [0.39940272],
#           [0.41022498],
#           [0.43549034]]],
#
#
#         [[[0.61978053],
#           [0.60136132],
#           [0.58087736],
#           ...,
#           [0.73535653],
#           [0.77704438],
#           [0.8259016 ]],
#
#          [[0.61978053],
#           [0.60136132],
#           [0.58087736],
#           ...,
#           [0.73535653],
#           [0.77704438],
#           [0.8259016 ]],
#
#          [[0.50485516],
#           [0.50079728],
#           [0.50095278],
#           ...,
#           [0.68953102],
#           [0.70957103],
#           [0.77641904]],
#
#          ...,
#
#          [[0.40128068],
#           [0.4366136 ],
#           [0.45224283],
#           ...,
#           [0.64974034],
#           [0.65560953],
#           [0.65810195]],
#
#          [[0.46226917],
#           [0.48484071],
#           [0.50029254],
#           ...,
#           [0.64608125],
#           [0.65891272],
#           [0.69483347]],
#
#          [[0.46226917],
#           [0.48484071],
#           [0.50029254],
#           ...,
#           [0.64608125],
#           [0.65891272],
#           [0.69483347]]],
#
#
#         ...,
#
#
#         [[[0.54127113],
#           [0.5525546 ],
#           [0.53989448],
#           ...,
#           [0.40882869],
#           [0.40169026],
#           [0.40439363]],
#
#          [[0.54127113],
#           [0.5525546 ],
#           [0.53989448],
#           ...,
#           [0.40882869],
#           [0.40169026],
#           [0.40439363]],
#
#          [[0.59711388],
#           [0.56082423],
#           [0.5428504 ],
#           ...,
#           [0.42904515],
#           [0.41583049],
#           [0.37480268]],
#
#          ...,
#
#          [[0.61987223],
#           [0.63536242],
#           [0.62616253],
#           ...,
#           [0.50918397],
#           [0.47024965],
#           [0.41674775]],
#
#          [[1.        ],
#           [0.87056611],
#           [0.81408141],
#           ...,
#           [0.4335135 ],
#           [0.37306341],
#           [0.27214605]],
#
#          [[1.        ],
#           [0.87056611],
#           [0.81408141],
#           ...,
#           [0.4335135 ],
#           [0.37306341],
#           [0.27214605]]],
#
#
#         [[[0.59680017],
#           [0.58942104],
#           [0.5786187 ],
#           ...,
#           [0.79936836],
#           [0.78189251],
#           [0.75507969]],
#
#          [[0.59680017],
#           [0.58942104],
#           [0.5786187 ],
#           ...,
#           [0.79936836],
#           [0.78189251],
#           [0.75507969]],
#
#          [[0.64951443],
#           [0.61832483],
#           [0.6031702 ],
#           ...,
#           [0.80572728],
#           [0.7916483 ],
#           [0.76651122]],
#
#          ...,
#
#          [[0.42973551],
#           [0.43889073],
#           [0.43974512],
#           ...,
#           [0.64993766],
#           [0.62932888],
#           [0.56169158]],
#
#          [[0.45372031],
#           [0.45890871],
#           [0.45952024],
#           ...,
#           [0.62049798],
#           [0.6205698 ],
#           [0.63425547]],
#
#          [[0.45372031],
#           [0.45890871],
#           [0.45952024],
#           ...,
#           [0.62049798],
#           [0.6205698 ],
#           [0.63425547]]],
#
#
#         [[[0.33412439],
#           [0.35507791],
#           [0.38208587],
#           ...,
#           [0.53059007],
#           [0.51958985],
#           [0.53946135]],
#
#          [[0.33412439],
#           [0.35507791],
#           [0.38208587],
#           ...,
#           [0.53059007],
#           [0.51958985],
#           [0.53946135]],
#
#          [[0.41814064],
#           [0.47227205],
#           [0.50127512],
#           ...,
#           [0.51591671],
#           [0.5206312 ],
#           [0.51994988]],
#
#          ...,
#
#          [[0.83163095],
#           [0.81414241],
#           [0.85361485],
#           ...,
#           [0.45604042],
#           [0.42550924],
#           [0.37018878]],
#
#          [[0.7165558 ],
#           [0.83453484],
#           [0.8706222 ],
#           ...,
#           [0.42348622],
#           [0.38807127],
#           [0.3395785 ]],
#
#          [[0.7165558 ],
#           [0.83453484],
#           [0.8706222 ],
#           ...,
#           [0.42348622],
#           [0.38807127],
#           [0.3395785 ]]]])>,
#  <tf.Tensor: shape=(8, 60, 20, 1), dtype=float64, numpy=
#  array([[[[0.52926308],
#           [0.67240748],
#           [0.73850033],
#           ...,
#           [0.58928777],
#           [0.64541022],
#           [0.78279647]],
#
#          [[0.52926308],
#           [0.67240748],
#           [0.73850033],
#           ...,
#           [0.58928777],
#           [0.64541022],
#           [0.78279647]],
#
#          [[0.56095377],
#           [0.59434885],
#           [0.63892837],
#           ...,
#           [0.68699451],
#           [0.68423591],
#           [0.66478089]],
#
#          ...,
#
#          [[0.8039947 ],
#           [0.70478286],
#           [0.65438472],
#           ...,
#           [0.48122861],
#           [0.46617274],
#           [0.41065408]],
#
#          [[0.79614927],
#           [0.75145731],
#           [0.71390868],
#           ...,
#           [0.39720849],
#           [0.37412089],
#           [0.34251426]],
#
#          [[0.79614927],
#           [0.75145731],
#           [0.71390868],
#           ...,
#           [0.39720849],
#           [0.37412089],
#           [0.34251426]]],
#
#
#         [[[0.48008757],
#           [0.53035572],
#           [0.56886271],
#           ...,
#           [0.77380903],
#           [0.75746072],
#           [0.70864398]],
#
#          [[0.48008757],
#           [0.53035572],
#           [0.56886271],
#           ...,
#           [0.77380903],
#           [0.75746072],
#           [0.70864398]],
#
#          [[0.55312324],
#           [0.57863103],
#           [0.59418011],
#           ...,
#           [0.74433158],
#           [0.71914021],
#           [0.65958908]],
#
#          ...,
#
#          [[0.70193744],
#           [0.69773963],
#           [0.70226687],
#           ...,
#           [0.69029026],
#           [0.67232618],
#           [0.64760113]],
#
#          [[0.74800075],
#           [0.73955996],
#           [0.73704365],
#           ...,
#           [0.66195048],
#           [0.65652385],
#           [0.61177543]],
#
#          [[0.74800075],
#           [0.73955996],
#           [0.73704365],
#           ...,
#           [0.66195048],
#           [0.65652385],
#           [0.61177543]]],
#
#
#         [[[0.57646527],
#           [0.55972731],
#           [0.54768097],
#           ...,
#           [0.68855068],
#           [0.65999377],
#           [0.6346051 ]],
#
#          [[0.57646527],
#           [0.55972731],
#           [0.54768097],
#           ...,
#           [0.68855068],
#           [0.65999377],
#           [0.6346051 ]],
#
#          [[0.59694504],
#           [0.59189566],
#           [0.58179963],
#           ...,
#           [0.64104999],
#           [0.61529183],
#           [0.55348659]],
#
#          ...,
#
#          [[0.67358352],
#           [0.59893125],
#           [0.58880072],
#           ...,
#           [0.7616238 ],
#           [0.76967322],
#           [0.71773327]],
#
#          [[0.68851185],
#           [0.61767238],
#           [0.58099049],
#           ...,
#           [0.75247516],
#           [0.80743636],
#           [0.92678665]],
#
#          [[0.68851185],
#           [0.61767238],
#           [0.58099049],
#           ...,
#           [0.75247516],
#           [0.80743636],
#           [0.92678665]]],
#
#
#         ...,
#
#
#         [[[0.77829616],
#           [0.84943982],
#           [0.87208424],
#           ...,
#           [0.67709891],
#           [0.6226321 ],
#           [0.57202657]],
#
#          [[0.77829616],
#           [0.84943982],
#           [0.87208424],
#           ...,
#           [0.67709891],
#           [0.6226321 ],
#           [0.57202657]],
#
#          [[0.85675067],
#           [0.76929852],
#           [0.74411313],
#           ...,
#           [0.73709481],
#           [0.70369173],
#           [0.64489238]],
#
#          ...,
#
#          [[0.67212349],
#           [0.6312206 ],
#           [0.61998352],
#           ...,
#           [0.48505451],
#           [0.47289544],
#           [0.44708664]],
#
#          [[0.62150782],
#           [0.62452616],
#           [0.62773029],
#           ...,
#           [0.40855584],
#           [0.37024745],
#           [0.3123706 ]],
#
#          [[0.62150782],
#           [0.62452616],
#           [0.62773029],
#           ...,
#           [0.40855584],
#           [0.37024745],
#           [0.3123706 ]]],
#
#
#         [[[0.64267926],
#           [0.66195584],
#           [0.68176697],
#           ...,
#           [0.67894862],
#           [0.68287104],
#           [0.68787576]],
#
#          [[0.64267926],
#           [0.66195584],
#           [0.68176697],
#           ...,
#           [0.67894862],
#           [0.68287104],
#           [0.68787576]],
#
#          [[0.65483501],
#           [0.73270342],
#           [0.7747715 ],
#           ...,
#           [0.79299779],
#           [0.80498734],
#           [0.79307777]],
#
#          ...,
#
#          [[0.62031251],
#           [0.65586091],
#           [0.64829478],
#           ...,
#           [0.47442753],
#           [0.45418968],
#           [0.41971441]],
#
#          [[0.59664197],
#           [0.58592335],
#           [0.59578941],
#           ...,
#           [0.4482288 ],
#           [0.48373614],
#           [0.54749794]],
#
#          [[0.59664197],
#           [0.58592335],
#           [0.59578941],
#           ...,
#           [0.4482288 ],
#           [0.48373614],
#           [0.54749794]]],
#
#
#         [[[0.41103665],
#           [0.54880756],
#           [0.619529  ],
#           ...,
#           [0.79232148],
#           [0.75968104],
#           [0.65107999]],
#
#          [[0.41103665],
#           [0.54880756],
#           [0.619529  ],
#           ...,
#           [0.79232148],
#           [0.75968104],
#           [0.65107999]],
#
#          [[0.63629221],
#           [0.645252  ],
#           [0.66500301],
#           ...,
#           [0.75058275],
#           [0.73022972],
#           [0.67058632]],
#
#          ...,
#
#          [[0.74128357],
#           [0.68490448],
#           [0.65003002],
#           ...,
#           [0.50266328],
#           [0.48277181],
#           [0.43249656]],
#
#          [[0.78634771],
#           [0.7104174 ],
#           [0.6626027 ],
#           ...,
#           [0.46037655],
#           [0.43942172],
#           [0.40483713]],
#
#          [[0.78634771],
#           [0.7104174 ],
#           [0.6626027 ],
#           ...,
#           [0.46037655],
#           [0.43942172],
#           [0.40483713]]]])>,
#  <tf.Tensor: shape=(6, 60, 20, 1), dtype=float64, numpy=
#  array([[[[0.50968873],
#           [0.57752693],
#           [0.62437451],
#           ...,
#           [0.562378  ],
#           [0.52703356],
#           [0.45469386]],
#
#          [[0.50968873],
#           [0.57752693],
#           [0.62437451],
#           ...,
#           [0.562378  ],
#           [0.52703356],
#           [0.45469386]],
#
#          [[0.56595875],
#           [0.58796252],
#           [0.60676469],
#           ...,
#           [0.54825127],
#           [0.51237084],
#           [0.46841042]],
#
#          ...,
#
#          [[0.48129498],
#           [0.49591232],
#           [0.51632272],
#           ...,
#           [0.80703698],
#           [0.86221775],
#           [0.94812894]],
#
#          [[0.51178823],
#           [0.5385185 ],
#           [0.55153119],
#           ...,
#           [0.84185014],
#           [0.79378972],
#           [0.69838918]],
#
#          [[0.51178823],
#           [0.5385185 ],
#           [0.55153119],
#           ...,
#           [0.84185014],
#           [0.79378972],
#           [0.69838918]]],
#
#
#         [[[0.43180089],
#           [0.45967811],
#           [0.50102546],
#           ...,
#           [0.76351139],
#           [0.75479938],
#           [0.74768044]],
#
#          [[0.43180089],
#           [0.45967811],
#           [0.50102546],
#           ...,
#           [0.76351139],
#           [0.75479938],
#           [0.74768044]],
#
#          [[0.58483153],
#           [0.6492182 ],
#           [0.66196022],
#           ...,
#           [0.698675  ],
#           [0.73528219],
#           [0.7817702 ]],
#
#          ...,
#
#          [[0.45517045],
#           [0.46224378],
#           [0.46925289],
#           ...,
#           [0.5490527 ],
#           [0.54178872],
#           [0.51737841]],
#
#          [[0.39313935],
#           [0.42665165],
#           [0.44233184],
#           ...,
#           [0.54404871],
#           [0.54574969],
#           [0.5511291 ]],
#
#          [[0.39313935],
#           [0.42665165],
#           [0.44233184],
#           ...,
#           [0.54404871],
#           [0.54574969],
#           [0.5511291 ]]],
#
#
#         [[[0.79443632],
#           [0.80498509],
#           [0.80212039],
#           ...,
#           [0.46144709],
#           [0.45168122],
#           [0.42581379]],
#
#          [[0.79443632],
#           [0.80498509],
#           [0.80212039],
#           ...,
#           [0.46144709],
#           [0.45168122],
#           [0.42581379]],
#
#          [[0.8087351 ],
#           [0.73950466],
#           [0.70470663],
#           ...,
#           [0.47563404],
#           [0.44821856],
#           [0.4106822 ]],
#
#          ...,
#
#          [[0.5431143 ],
#           [0.56213491],
#           [0.5862019 ],
#           ...,
#           [0.63378202],
#           [0.65200936],
#           [0.6750727 ]],
#
#          [[0.60243766],
#           [0.64541254],
#           [0.65034822],
#           ...,
#           [0.56923173],
#           [0.58693086],
#           [0.63752101]],
#
#          [[0.60243766],
#           [0.64541254],
#           [0.65034822],
#           ...,
#           [0.56923173],
#           [0.58693086],
#           [0.63752101]]],
#
#
#         [[[0.8959753 ],
#           [0.84927779],
#           [0.82472795],
#           ...,
#           [0.40281851],
#           [0.34192244],
#           [0.2531121 ]],
#
#          [[0.8959753 ],
#           [0.84927779],
#           [0.82472795],
#           ...,
#           [0.40281851],
#           [0.34192244],
#           [0.2531121 ]],
#
#          [[0.6631207 ],
#           [0.68519769],
#           [0.67668387],
#           ...,
#           [0.4580593 ],
#           [0.4088659 ],
#           [0.32057836]],
#
#          ...,
#
#          [[0.33213863],
#           [0.3904862 ],
#           [0.42995474],
#           ...,
#           [0.68388045],
#           [0.70619781],
#           [0.75309636]],
#
#          [[0.37945141],
#           [0.4206822 ],
#           [0.44693579],
#           ...,
#           [0.73385429],
#           [0.78133671],
#           [0.86084055]],
#
#          [[0.37945141],
#           [0.4206822 ],
#           [0.44693579],
#           ...,
#           [0.73385429],
#           [0.78133671],
#           [0.86084055]]],
#
#
#         [[[0.43246618],
#           [0.49258376],
#           [0.52789795],
#           ...,
#           [0.52124997],
#           [0.53454279],
#           [0.54019015]],
#
#          [[0.43246618],
#           [0.49258376],
#           [0.52789795],
#           ...,
#           [0.52124997],
#           [0.53454279],
#           [0.54019015]],
#
#          [[0.45874799],
#           [0.48667377],
#           [0.51574686],
#           ...,
#           [0.54487635],
#           [0.55354659],
#           [0.56758088]],
#
#          ...,
#
#          [[0.84414393],
#           [0.71059816],
#           [0.66644187],
#           ...,
#           [0.701547  ],
#           [0.70553628],
#           [0.71187328]],
#
#          [[0.75114118],
#           [0.80915239],
#           [0.81493461],
#           ...,
#           [0.71867689],
#           [0.75498814],
#           [0.79913261]],
#
#          [[0.75114118],
#           [0.80915239],
#           [0.81493461],
#           ...,
#           [0.71867689],
#           [0.75498814],
#           [0.79913261]]],
#
#
#         [[[0.41691377],
#           [0.46442322],
#           [0.49681627],
#           ...,
#           [0.4929423 ],
#           [0.5226989 ],
#           [0.59403734]],
#
#          [[0.41691377],
#           [0.46442322],
#           [0.49681627],
#           ...,
#           [0.4929423 ],
#           [0.5226989 ],
#           [0.59403734]],
#
#          [[0.49234169],
#           [0.50363046],
#           [0.51700599],
#           ...,
#           [0.45047348],
#           [0.43993157],
#           [0.42506089]],
#
#          ...,
#
#          [[0.7895143 ],
#           [0.72473426],
#           [0.6923251 ],
#           ...,
#           [0.62386598],
#           [0.65486169],
#           [0.69413044]],
#
#          [[1.        ],
#           [0.98031782],
#           [0.97493393],
#           ...,
#           [0.60562178],
#           [0.59847749],
#           [0.58142766]],
#
#          [[1.        ],
#           [0.98031782],
#           [0.97493393],
#           ...,
#           [0.60562178],
#           [0.59847749],
#           [0.58142766]]]])>)

# %%
images
# Out:
# (<tf.Tensor: shape=(8, 60, 20, 5), dtype=float64, numpy=
#  array([[[[2.17470686e+04, 4.65741346e+04, 1.62712502e+04,
#            4.27500000e-01, 6.56203325e-01],
#           [3.62469870e+04, 6.55405008e+04, 2.27564124e+04,
#            6.27000000e-01, 6.23420529e-01],
#           [3.97287505e+04, 5.05941661e+04, 2.36018546e+04,
#            5.98500000e-01, 5.60082325e-01],
#           ...,
#           [6.48034249e+04, 4.71002047e+04, 2.05840807e+04,
#            6.27000000e-01, 4.26963468e-01],
#           [6.27821127e+04, 5.47163829e+04, 2.14106532e+04,
#            6.55500000e-01, 4.69012824e-01],
#           [6.27694022e+04, 6.47900917e+04, 2.33259543e+04,
#            7.12500000e-01, 5.06827771e-01]],
#
#          [[3.03897538e+04, 4.63606742e+04, 2.08624744e+04,
#            5.13000000e-01, 5.84557134e-01],
#           [2.70971556e+04, 5.67106385e+04, 1.67161636e+04,
#            4.84500000e-01, 6.60489575e-01],
#           [2.71369799e+04, 4.78327251e+04, 1.84788184e+04,
#            4.84500000e-01, 6.29696063e-01],
#           ...,
#           [6.43111662e+04, 5.25954877e+04, 1.91995520e+04,
#            6.27000000e-01, 4.52527801e-01],
#           [6.53883994e+04, 5.31574862e+04, 2.10915591e+04,
#            6.55500000e-01, 4.52990348e-01],
#           [7.66361319e+04, 6.68225877e+04, 2.36175355e+04,
#            7.69500000e-01, 4.67824557e-01]],
#
#          [[2.84728908e+04, 3.84373931e+04, 1.50345244e+04,
#            3.99000000e-01, 5.62650238e-01],
#           [3.55709427e+04, 5.49846358e+04, 1.74450254e+04,
#            5.13000000e-01, 5.97733001e-01],
#           [3.97527258e+04, 5.31918278e+04, 1.79411254e+04,
#            5.41500000e-01, 5.66819432e-01],
#           ...,
#           [6.39730315e+04, 4.68746984e+04, 1.85424760e+04,
#            5.98500000e-01, 4.27193926e-01],
#           [6.00554661e+04, 6.14514398e+04, 2.01838668e+04,
#            6.55500000e-01, 5.05232870e-01],
#           [6.41008164e+04, 5.95390581e+04, 1.96426248e+04,
#            6.55500000e-01, 4.82422079e-01]],
#
#          ...,
#
#          [[6.03935539e+04, 5.45586932e+04, 2.09531361e+04,
#            6.55500000e-01, 4.88434217e-01],
#           ...,
#           [2.58213862e+04, 3.98670949e+04, 1.39722456e+04,
#            3.99000000e-01, 6.24367160e-01],
#           [2.49875771e+04, 5.96589888e+04, 1.74119952e+04,
#            5.13000000e-01, 6.98870106e-01],
#           [2.47778587e+04, 4.94756949e+04, 1.48145718e+04,
#            4.27500000e-01, 6.56979272e-01]],
#
#          [[2.02525618e+04, 3.12213490e+04, 1.94300952e+04,
#            4.27500000e-01, 5.89162025e-01],
#           [1.97585834e+04, 3.42636098e+04, 1.65207069e+04,
#            3.99000000e-01, 6.15027348e-01],
#           [3.15566580e+04, 4.56948432e+04, 1.86507154e+04,
#            4.84500000e-01, 5.74739246e-01],
#           ...,
#           [2.95200884e+04, 5.02232035e+04, 2.12009650e+04,
#            5.41500000e-01, 6.14616961e-01],
#           [2.80081851e+04, 5.71175051e+04, 1.78335094e+04,
#            5.13000000e-01, 6.65243485e-01],
#           [2.76328715e+04, 5.33578502e+04, 1.71360151e+04,
#            4.84500000e-01, 6.51279588e-01]],
#
#          [[1.74349886e+04, 3.37790165e+04, 1.52141842e+04,
#            3.70500000e-01, 6.55307065e-01],
#           [2.69544270e+04, 4.04682033e+04, 1.81314970e+04,
#            4.56000000e-01, 5.81580143e-01],
#           [3.73337020e+04, 3.02172789e+04, 1.49001440e+04,
#            3.99000000e-01, 4.50937231e-01],
#           ...,
#           [4.43967804e+04, 4.53633152e+04, 2.14394985e+04,
#            5.70000000e-01, 5.18705081e-01],
#           [4.62687491e+04, 5.68867564e+04, 2.19990726e+04,
#            6.27000000e-01, 5.60748889e-01],
#           [6.07806318e+04, 5.63255609e+04, 2.36369217e+04,
#            7.12500000e-01, 5.12688694e-01]]]])>)

# %%
winKernel = 17

# %%
#####################################################################
# CNN Model definition
#####################################################################

def TBDCNet_modelCNN(inputShape, outputShape, params):
  '''
  This function returns a model based on the hyperparameters in the
  sweep definition

  Args
  ----------
  inputShape: the 55x20x3 input image shape
  outputShape: the prediction image shape (currently unused)
  params: The hyperparameters for the given sweep index

  Returns
  ----------
  model: tensorflow model

  '''
  # Kernel regularizer (both linear and quadratic)
  if params['L1kernel_regularizer'] > 0 and params['L2kernel_regularizer'] > 0: 
     regularizer = tf.keras.regularizers.L1L2(l1=params['L1kernel_regularizer'], l2=params['L2kernel_regularizer'])
  elif params['L1kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L1(params['L1kernel_regularizer'])
  elif params['L2kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L2(params['L2kernel_regularizer'])
  else:
    regularizer = None

  # Define the model architecture. Each convolutional layer has settings related to the kernel size, 
  # activation function, and regularizer. After each convolutional layer there may be a batch-
  # normalization layer, a max pooling layer, and a dropout layer. The number of convolutional layers
  # is given in the sweep definition


  input = tf.keras.layers.Input(shape=inputShape) # Shape (Long, short, inputs)
  x = normalizer(input)
  if params['dsAugmentation'] == 1:
    x = tf.keras.layers.RandomFlip(mode="horizontal_and_vertical", seed=seed)(x)


  x = tf.keras.layers.Conv2D(filters = 32, kernel_size=(int(params['layer1Kernel']), int(params['layer1Kernel'])),activation=params['conv1Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
  if params['batchNorm'] == 1:
    x = tf.keras.layers.BatchNormalization()(x)
  if params['pooling'] == 1:
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
  if params['dropout'] > 0:
    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
  encoder1 = x # Use this if skip connections need to be used


  if params['layer2'] == 1:
    x = tf.keras.layers.Conv2D(filters = 64, kernel_size=(int(params['layer2Kernel']), int(params['layer2Kernel'])),activation=params['conv2Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
    if params['batchNorm'] == 1:
      x = tf.keras.layers.BatchNormalization()(x)
    if params['pooling'] == 1:
       x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
    if params['dropout'] > 0:
       x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
    encoder2 = x
        

    if params['layer3'] == 1:
        x = tf.keras.layers.Conv2D(filters = 128, kernel_size=(int(params['layer3Kernel']), int(params['layer3Kernel'])),activation=params['conv3Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
        if params['batchNorm'] == 1:
           x = tf.keras.layers.BatchNormalization()(x)
        if params['pooling'] == 1:
           x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
        if params['dropout'] > 0:
           x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
        encoder3 = x


        if params['layer4'] == 1:
            x = tf.keras.layers.Conv2D(filters = 256, kernel_size=(int(params['layer4Kernel']), int(params['layer4Kernel'])),activation=params['conv4Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
            if params['batchNorm'] == 1:
                x = tf.keras.layers.BatchNormalization()(x)
            if params['pooling'] == 1:
                x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
            if params['dropout'] > 0:
                x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
            encoder4 = x


            if params['layer5'] == 1:
                x = tf.keras.layers.Conv2D(filters = 512, kernel_size=(int(params['layer5Kernel']), int(params['layer5Kernel'])),activation=params['conv5Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                if params['batchNorm'] == 1:
                    x = tf.keras.layers.BatchNormalization()(x)
                if params['pooling'] == 1:
                    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                if params['dropout'] > 0:
                    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                encoder5 = x


                if params['layer6'] == 1:
                    x = tf.keras.layers.Conv2D(filters = 1024, kernel_size=(int(params['layer6Kernel']), int(params['layer6Kernel'])),activation=params['conv6Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                    if params['batchNorm'] == 1:
                        x = tf.keras.layers.BatchNormalization()(x)
                    if params['pooling'] == 1:
                        x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                    if params['dropout'] > 0:
                        x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                    encoder6 = x

                    if params['ActivationUp'] == 0:
                       temp_activation = 'linear'
                    else:
                       temp_activation = params['conv6Activation']

                    x = tf.keras.layers.Conv2DTranspose(filters = 512, kernel_size = (int(params['layer6Kernel']),int(params['layer6Kernel'])),  padding='same',activation=temp_activation)(x)
                    if params['skipConnections'] == 1:
                      x = tf.keras.layers.Concatenate()([x, encoder5])


                if params['ActivationUp'] == 0:
                    temp_activation = 'linear'
                else:
                    temp_activation = params['conv5Activation']

                x = tf.keras.layers.Conv2DTranspose(filters = 256, kernel_size = (int(params['layer5Kernel']),int(params['layer5Kernel'])),  padding='same',activation=temp_activation)(x)
                if params['skipConnections'] == 1:
                  x = tf.keras.layers.Concatenate()([x, encoder4])
            
            
            if params['type'] == 'dense':
              y = tf.keras.layers.Flatten()(x)
              y = tf.keras.layers.Dense(64, activation='relu')(y)
              y = tf.keras.layers.Dense(outputShape[0]*outputShape[1])(y)
              y = tf.keras.layers.Reshape(outputShape)(y)

            if params['ActivationUp'] == 0:
                temp_activation = 'linear'
            else:
                temp_activation = params['conv4Activation']
            
            x = tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (int(params['layer4Kernel']),int(params['layer4Kernel'])),  padding='same',activation=temp_activation)(x)
            if params['skipConnections'] == 1:
              x = tf.keras.layers.Concatenate()([x, encoder3])

        if params['ActivationUp'] == 0:
            temp_activation = 'linear'
        else:
            temp_activation = params['conv3Activation']
        
        x = tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (int(params['layer3Kernel']),int(params['layer3Kernel'])),  padding='same',activation=temp_activation)(x)
        if params['skipConnections'] == 1:
          x = tf.keras.layers.Concatenate()([x, encoder2])

    if params['ActivationUp'] == 0:
        temp_activation = 'linear'
    else:
        temp_activation = params['conv2Activation']
    
    x = tf.keras.layers.Conv2DTranspose(filters = 32, kernel_size = (int(params['layer2Kernel']),int(params['layer2Kernel'])),  padding='same',activation=temp_activation)(x)
    if params['skipConnections'] == 1:
      x = tf.keras.layers.Concatenate()([x, encoder1])

   # Custom activation function is linear between 0 and 1 and otherwise constant
  def custom_activation(x):
      return tf.math.minimum(K.relu(x), 1)

  x = tf.keras.layers.Conv2DTranspose(filters = 1, kernel_size = (int(params['layer1Kernel']),int(params['layer1Kernel'])),  padding='same',activation='linear')(x)

  if params['type'] == 'dense': # For the dense model we jsut pull the output y
     output = y
  else:
    output = x

  model = tf.keras.Model(inputs=input, outputs=output) # Create model

  # Default initial learning rate is 0.001. If the the decay rate is 1 this will be held constant.
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=params['initial_lr'],
    decay_steps=steps_per_epoch*epochs,
    decay_rate=params['lr_decay_rate'])

  def custom_loss(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.nn.relu(y_true))))
    loss = tf.reduce_mean(loss)
    return loss
  
  def custom_loss5(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.math.multiply(tf.nn.relu(y_true),5))))
    loss = tf.reduce_mean(loss)
    return loss

  def peak_loss(y_true,y_pred):
    peakVal = tf.reduce_max(y_true, keepdims=True)
    cond = tf.equal(y_true, peakVal)
    # peakLoc = tf.where(cond)
    # peakLoc_1d = tf.squeeze(peakLoc)
    errorGrid = tf.math.subtract(y_true,y_pred)
    zeroGrid = tf.math.subtract(y_true,y_true) # Grid of zeros so we only get loss in peak location
    # peakPred = y_pred[peakLoc_1d.numpy()[0]]
    # peakPred = tf.slice(y_pred, peakLoc, [1,1])
    loss = tf.where(cond, errorGrid, zeroGrid)
    loss = tf.reduce_mean(loss)

    # loss = peakPred-peakVal
    return loss


#   Loss functions can be swept
  if params['loss'] == 'MSE':
    lossfunc = tf.keras.losses.MeanSquaredError()
  elif params['loss'] == 'MAE':
    lossfunc = tf.keras.losses.MeanAbsoluteError()
  elif params['loss'] == 'Custom':
    lossfunc = custom_loss
  elif params['loss'] == 'Peak':
    lossfunc = peak_loss
  elif params['loss'] == 'Custom5':
    lossfunc = custom_loss5
    

  # Additional metrics to computes
  def SSIM_metric(y_true, y_pred):
      return 1 - tf.reduce_mean(tf.image.ssim(
    img1 = y_true,
    img2 = y_pred,
    max_val = np.max(y_true)-np.min(y_true),
    filter_size=winKernel,
    filter_sigma=1.5,
    k1=0.01,
    k2=0.03,
    return_index_map=False
))



  # Compile model with the optimizer in the sweep definition
  if params['optimizer'] == 'Adadelta':
     model.compile(optimizer=tf.keras.optimizers.Adadelta(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  elif params['optimizer'] == 'Nadam':
     model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error'])
  else:
     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error', SSIM_metric])

  return model

# %%
#####################################################################
# Training callbacks
#####################################################################

# Checkpoints to allow saving best model at various points
# checkpoint_path = 'training_checkpoints_{jn}_{num}/cp.ckpt'.format(jn='TESTJOB', num = 1)
checkpoint_path = 'training_checkpoints_{jn}_{num}/model.weights.h5'.format(jn='TESTJOB', num = 1)
checkpoint_dir = os.path.dirname(checkpoint_path)

try:
  os.mkdir(checkpoint_dir) # Make checkpoint directory
except:
  pass

# Save best weights to checkpoint
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_best_only = True,
                                                 monitor = 'val_loss',
                                                 verbose=1)

# Early stopping callback which monitors improvements and stops training if
# it stagnates.
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', # Monitor validation loss
    min_delta=0, # Minimum improvement to consider an improvement
    patience=60, # Number of epochs with no improvement before stopping training
    verbose=1, # Records message when earlystopping
    mode='auto',
    baseline=None, 
    restore_best_weights=False # Do not restore best weights after early stopping, we do this manually to allow recording of the full training history
)

# %%
#####################################################################
# Model instantiation
#####################################################################

tf.keras.backend.clear_session() # Clear the state and frees up memory

# CNN Model creation
# modelCNN = TBDCNet_modelCNN(inputShape = train_in_shape[1:], outputShape = train_out_shape[1:], params = params)
modelCNN = TBDCNet_modelCNN(inputShape = X_trainShape[1:], outputShape = y_trainShape[1:], params = params)

modelCNNname = 'CNNModel1'

# %%
#####################################################################
# Model training
#####################################################################

# Known issue: sometimes throws error related to the shape of the labels...
# Fit model to Failure index
epochs = 80
modelCNN_history = modelCNN.fit(train_ds,
                                epochs=epochs,
                                steps_per_epoch=steps_per_epoch,
                                validation_data=val_ds,
                                validation_steps = validation_steps,
                                callbacks=[early_stopping_monitor, cp_callback]
                                )
# Out:
# Epoch 1/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.2477 - mean_absolute_error: 0.4026 - mean_squared_error: 0.2477
# Epoch 1: val_loss improved from inf to 0.05202, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.2370 - mean_absolute_error: 0.3914 - mean_squared_error: 0.2370 - val_loss: 0.0520 - val_mean_absolute_error: 0.1785 - val_mean_squared_error: 0.0520
# Epoch 2/80
# 2/8 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0700 - mean_absolute_error: 0.2077 - mean_squared_error: 0.0700
# c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0694 - mean_absolute_error: 0.2066 - mean_squared_error: 0.0694
# Epoch 2: val_loss improved from 0.05202 to 0.03545, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0688 - mean_absolute_error: 0.2058 - mean_squared_error: 0.0688 - val_loss: 0.0354 - val_mean_absolute_error: 0.1450 - val_mean_squared_error: 0.0354
# Epoch 3/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0584 - mean_absolute_error: 0.1889 - mean_squared_error: 0.0584
# Epoch 3: val_loss improved from 0.03545 to 0.02971, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0579 - mean_absolute_error: 0.1880 - mean_squared_error: 0.0579 - val_loss: 0.0297 - val_mean_absolute_error: 0.1332 - val_mean_squared_error: 0.0297
# Epoch 4/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0425 - mean_absolute_error: 0.1613 - mean_squared_error: 0.0425
# Epoch 4: val_loss improved from 0.02971 to 0.02689, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0423 - mean_absolute_error: 0.1609 - mean_squared_error: 0.0423 - val_loss: 0.0269 - val_mean_absolute_error: 0.1274 - val_mean_squared_error: 0.0269
# Epoch 5/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0381 - mean_absolute_error: 0.1519 - mean_squared_error: 0.0381
# Epoch 5: val_loss improved from 0.02689 to 0.02356, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0384 - mean_absolute_error: 0.1525 - mean_squared_error: 0.0384 - val_loss: 0.0236 - val_mean_absolute_error: 0.1202 - val_mean_squared_error: 0.0236
# Epoch 6/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0337 - mean_absolute_error: 0.1438 - mean_squared_error: 0.0337
# Epoch 6: val_loss improved from 0.02356 to 0.02132, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0337 - mean_absolute_error: 0.1439 - mean_squared_error: 0.0337 - val_loss: 0.0213 - val_mean_absolute_error: 0.1138 - val_mean_squared_error: 0.0213
# Epoch 7/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0281 - mean_absolute_error: 0.1305 - mean_squared_error: 0.0281
# Epoch 7: val_loss improved from 0.02132 to 0.01890, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0281 - mean_absolute_error: 0.1308 - mean_squared_error: 0.0281 - val_loss: 0.0189 - val_mean_absolute_error: 0.1083 - val_mean_squared_error: 0.0189
# Epoch 8/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0275 - mean_absolute_error: 0.1291 - mean_squared_error: 0.0275
# Epoch 8: val_loss did not improve from 0.01890
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0276 - mean_absolute_error: 0.1293 - mean_squared_error: 0.0276 - val_loss: 0.0190 - val_mean_absolute_error: 0.1089 - val_mean_squared_error: 0.0190
# Epoch 9/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0260 - mean_absolute_error: 0.1270 - mean_squared_error: 0.0260
# Epoch 9: val_loss improved from 0.01890 to 0.01838, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0261 - mean_absolute_error: 0.1273 - mean_squared_error: 0.0261 - val_loss: 0.0184 - val_mean_absolute_error: 0.1085 - val_mean_squared_error: 0.0184
# Epoch 10/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0274 - mean_absolute_error: 0.1291 - mean_squared_error: 0.0274
# Epoch 10: val_loss improved from 0.01838 to 0.01818, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 0.0273 - mean_absolute_error: 0.1291 - mean_squared_error: 0.0273 - val_loss: 0.0182 - val_mean_absolute_error: 0.1077 - val_mean_squared_error: 0.0182
# Epoch 11/80
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0224 - mean_absolute_error: 0.1182 - mean_squared_error: 0.0224
# Epoch 11: val_loss improved from 0.01818 to 0.01717, saving model to training_checkpoints_TESTJOB_1/model.weights.h5
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[140], line 9
#       1 #%%
#       2 #####################################################################
#       3 # Model training
#    (...)
#       6 # Known issue: sometimes throws error related to the shape of the labels...
#       7 # Fit model to Failure index
#       8 epochs = 80
# ----> 9 modelCNN_history = modelCNN.fit(train_ds,
#      10                                 epochs=epochs,
#      11                                 steps_per_epoch=steps_per_epoch,
#      12                                 validation_data=val_ds,
#      13                                 validation_steps = validation_steps,
#      14                                 callbacks=[early_stopping_monitor, cp_callback]
#      15                                 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\h5py\_hl\files.py:561, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     552     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     553                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     554                      alignment_threshold=alignment_threshold,
#     555                      alignment_interval=alignment_interval,
#     556                      meta_block_size=meta_block_size,
#     557                      **kwds)
#     558     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     559                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     560                      fs_page_size=fs_page_size)
# --> 561     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     563 if isinstance(libver, tuple):
#     564     self._libver = libver
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\h5py\_hl\files.py:241, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     239     fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     240 elif mode == 'w':
# --> 241     fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     242 elif mode == 'a':
#     243     # Open in append mode (read/write).
#     244     # If that fails, create a new file only if it won't clobber an
#     245     # existing one (ACC_EXCL)
#     246     try:
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:122, in h5py.h5f.create()
#
# PermissionError: [Errno 13] Unable to synchronously create file (unable to open file: name = 'training_checkpoints_TESTJOB_1/model.weights.h5', errno = 13, error message = 'Permission denied', flags = 13, o_flags = 302)

# %%
#####################################################################
# CNN Model definition
#####################################################################

def TBDCNet_modelCNN(inputShape, outputShape, params):
  '''
  This function returns a model based on the hyperparameters in the
  sweep definition

  Args
  ----------
  inputShape: the 55x20x3 input image shape
  outputShape: the prediction image shape (currently unused)
  params: The hyperparameters for the given sweep index

  Returns
  ----------
  model: tensorflow model

  '''
  # Kernel regularizer (both linear and quadratic)
  if params['L1kernel_regularizer'] > 0 and params['L2kernel_regularizer'] > 0: 
     regularizer = tf.keras.regularizers.L1L2(l1=params['L1kernel_regularizer'], l2=params['L2kernel_regularizer'])
  elif params['L1kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L1(params['L1kernel_regularizer'])
  elif params['L2kernel_regularizer'] > 0:
     regularizer = tf.keras.regularizers.L2(params['L2kernel_regularizer'])
  else:
    regularizer = None

  # Define the model architecture. Each convolutional layer has settings related to the kernel size, 
  # activation function, and regularizer. After each convolutional layer there may be a batch-
  # normalization layer, a max pooling layer, and a dropout layer. The number of convolutional layers
  # is given in the sweep definition


  input = tf.keras.layers.Input(shape=inputShape) # Shape (Long, short, inputs)
  x = normalizer(input)
  if params['dsAugmentation'] == 1:
    x = tf.keras.layers.RandomFlip(mode="horizontal_and_vertical", seed=seed)(x)


  x = tf.keras.layers.Conv2D(filters = 32, kernel_size=(int(params['layer1Kernel']), int(params['layer1Kernel'])),activation=params['conv1Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
  if params['batchNorm'] == 1:
    x = tf.keras.layers.BatchNormalization()(x)
  if params['pooling'] == 1:
    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
  if params['dropout'] > 0:
    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
  encoder1 = x # Use this if skip connections need to be used


  if params['layer2'] == 1:
    x = tf.keras.layers.Conv2D(filters = 64, kernel_size=(int(params['layer2Kernel']), int(params['layer2Kernel'])),activation=params['conv2Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
    if params['batchNorm'] == 1:
      x = tf.keras.layers.BatchNormalization()(x)
    if params['pooling'] == 1:
       x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
    if params['dropout'] > 0:
       x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
    encoder2 = x
        

    if params['layer3'] == 1:
        x = tf.keras.layers.Conv2D(filters = 128, kernel_size=(int(params['layer3Kernel']), int(params['layer3Kernel'])),activation=params['conv3Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
        if params['batchNorm'] == 1:
           x = tf.keras.layers.BatchNormalization()(x)
        if params['pooling'] == 1:
           x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
        if params['dropout'] > 0:
           x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
        encoder3 = x


        if params['layer4'] == 1:
            x = tf.keras.layers.Conv2D(filters = 256, kernel_size=(int(params['layer4Kernel']), int(params['layer4Kernel'])),activation=params['conv4Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
            if params['batchNorm'] == 1:
                x = tf.keras.layers.BatchNormalization()(x)
            if params['pooling'] == 1:
                x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
            if params['dropout'] > 0:
                x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
            encoder4 = x


            if params['layer5'] == 1:
                x = tf.keras.layers.Conv2D(filters = 512, kernel_size=(int(params['layer5Kernel']), int(params['layer5Kernel'])),activation=params['conv5Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                if params['batchNorm'] == 1:
                    x = tf.keras.layers.BatchNormalization()(x)
                if params['pooling'] == 1:
                    x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                if params['dropout'] > 0:
                    x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                encoder5 = x


                if params['layer6'] == 1:
                    x = tf.keras.layers.Conv2D(filters = 1024, kernel_size=(int(params['layer6Kernel']), int(params['layer6Kernel'])),activation=params['conv6Activation'], data_format='channels_last', padding='same', kernel_regularizer=regularizer) (x)
                    if params['batchNorm'] == 1:
                        x = tf.keras.layers.BatchNormalization()(x)
                    if params['pooling'] == 1:
                        x = tf.keras.layers.MaxPooling2D((2, 2), strides=1, padding='same')(x)
                    if params['dropout'] > 0:
                        x = tf.keras.layers.SpatialDropout2D(rate = params['dropout'])(x)
                    encoder6 = x

                    if params['ActivationUp'] == 0:
                       temp_activation = 'linear'
                    else:
                       temp_activation = params['conv6Activation']

                    x = tf.keras.layers.Conv2DTranspose(filters = 512, kernel_size = (int(params['layer6Kernel']),int(params['layer6Kernel'])),  padding='same',activation=temp_activation)(x)
                    if params['skipConnections'] == 1:
                      x = tf.keras.layers.Concatenate()([x, encoder5])


                if params['ActivationUp'] == 0:
                    temp_activation = 'linear'
                else:
                    temp_activation = params['conv5Activation']

                x = tf.keras.layers.Conv2DTranspose(filters = 256, kernel_size = (int(params['layer5Kernel']),int(params['layer5Kernel'])),  padding='same',activation=temp_activation)(x)
                if params['skipConnections'] == 1:
                  x = tf.keras.layers.Concatenate()([x, encoder4])
            
            
            if params['type'] == 'dense':
              y = tf.keras.layers.Flatten()(x)
              y = tf.keras.layers.Dense(64, activation='relu')(y)
              y = tf.keras.layers.Dense(outputShape[0]*outputShape[1])(y)
              y = tf.keras.layers.Reshape(outputShape)(y)

            if params['ActivationUp'] == 0:
                temp_activation = 'linear'
            else:
                temp_activation = params['conv4Activation']
            
            x = tf.keras.layers.Conv2DTranspose(filters = 128, kernel_size = (int(params['layer4Kernel']),int(params['layer4Kernel'])),  padding='same',activation=temp_activation)(x)
            if params['skipConnections'] == 1:
              x = tf.keras.layers.Concatenate()([x, encoder3])

        if params['ActivationUp'] == 0:
            temp_activation = 'linear'
        else:
            temp_activation = params['conv3Activation']
        
        x = tf.keras.layers.Conv2DTranspose(filters = 64, kernel_size = (int(params['layer3Kernel']),int(params['layer3Kernel'])),  padding='same',activation=temp_activation)(x)
        if params['skipConnections'] == 1:
          x = tf.keras.layers.Concatenate()([x, encoder2])

    if params['ActivationUp'] == 0:
        temp_activation = 'linear'
    else:
        temp_activation = params['conv2Activation']
    
    x = tf.keras.layers.Conv2DTranspose(filters = 32, kernel_size = (int(params['layer2Kernel']),int(params['layer2Kernel'])),  padding='same',activation=temp_activation)(x)
    if params['skipConnections'] == 1:
      x = tf.keras.layers.Concatenate()([x, encoder1])

   # Custom activation function is linear between 0 and 1 and otherwise constant
  def custom_activation(x):
      return tf.math.minimum(K.relu(x), 1)

  x = tf.keras.layers.Conv2DTranspose(filters = 1, kernel_size = (int(params['layer1Kernel']),int(params['layer1Kernel'])),  padding='same',activation='linear')(x)

  if params['type'] == 'dense': # For the dense model we jsut pull the output y
     output = y
  else:
    output = x

  model = tf.keras.Model(inputs=input, outputs=output) # Create model

  # Default initial learning rate is 0.001. If the the decay rate is 1 this will be held constant.
  lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=params['initial_lr'],
    decay_steps=steps_per_epoch*epochs,
    decay_rate=params['lr_decay_rate'])

  def custom_loss(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.nn.relu(y_true))))
    loss = tf.reduce_mean(loss)
    return loss
  
  def custom_loss5(y_true,y_pred):
    SE_base = tf.math.square(tf.math.subtract(y_true,y_pred))
    loss = tf.math.multiply(SE_base,(tf.math.add(tf.constant(1,dtype=tf.float32),tf.math.multiply(tf.nn.relu(y_true),5))))
    loss = tf.reduce_mean(loss)
    return loss

  def peak_loss(y_true,y_pred):
    peakVal = tf.reduce_max(y_true, keepdims=True)
    cond = tf.equal(y_true, peakVal)
    # peakLoc = tf.where(cond)
    # peakLoc_1d = tf.squeeze(peakLoc)
    errorGrid = tf.math.subtract(y_true,y_pred)
    zeroGrid = tf.math.subtract(y_true,y_true) # Grid of zeros so we only get loss in peak location
    # peakPred = y_pred[peakLoc_1d.numpy()[0]]
    # peakPred = tf.slice(y_pred, peakLoc, [1,1])
    loss = tf.where(cond, errorGrid, zeroGrid)
    loss = tf.reduce_mean(loss)

    # loss = peakPred-peakVal
    return loss


#   Loss functions can be swept
  if params['loss'] == 'MSE':
    lossfunc = tf.keras.losses.MeanSquaredError()
  elif params['loss'] == 'MAE':
    lossfunc = tf.keras.losses.MeanAbsoluteError()
  elif params['loss'] == 'Custom':
    lossfunc = custom_loss
  elif params['loss'] == 'Peak':
    lossfunc = peak_loss
  elif params['loss'] == 'Custom5':
    lossfunc = custom_loss5
    

  # Additional metrics to computes
  def SSIM_metric(y_true, y_pred):
      return 1 - tf.reduce_mean(tf.image.ssim(
    img1 = y_true,
    img2 = y_pred,
    max_val = np.max(y_true)-np.min(y_true),
    filter_size=winKernel,
    filter_sigma=1.5,
    k1=0.01,
    k2=0.03,
    return_index_map=False
))



  # Compile model with the optimizer in the sweep definition
  if params['optimizer'] == 'Adadelta':
     model.compile(optimizer=tf.keras.optimizers.Adadelta(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error', SSIM_metric])
  elif params['optimizer'] == 'Nadam':
     model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error', SSIM_metric])
  else:
     model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule,epsilon = params['epsilon']), # Compile
              loss=lossfunc, 
              metrics=['mean_absolute_error','mean_squared_error', SSIM_metric])

  return model

# %%
#####################################################################
# Training callbacks
#####################################################################

# Checkpoints to allow saving best model at various points
# checkpoint_path = 'training_checkpoints_{jn}_{num}/cp.ckpt'.format(jn='TESTJOB', num = 1)
checkpoint_path = 'training_checkpoints_{jn}_{num}/model.weights.h5'.format(jn='TESTJOB', num = 1)
checkpoint_dir = os.path.dirname(checkpoint_path)

try:
  os.mkdir(checkpoint_dir) # Make checkpoint directory
except:
  pass

# Save best weights to checkpoint
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 save_best_only = True,
                                                 monitor = 'val_loss',
                                                 verbose=1)

# Early stopping callback which monitors improvements and stops training if
# it stagnates.
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', # Monitor validation loss
    min_delta=0, # Minimum improvement to consider an improvement
    patience=60, # Number of epochs with no improvement before stopping training
    verbose=1, # Records message when earlystopping
    mode='auto',
    baseline=None, 
    restore_best_weights=False # Do not restore best weights after early stopping, we do this manually to allow recording of the full training history
)

# %%
#####################################################################
# Model instantiation
#####################################################################

tf.keras.backend.clear_session() # Clear the state and frees up memory

# CNN Model creation
# modelCNN = TBDCNet_modelCNN(inputShape = train_in_shape[1:], outputShape = train_out_shape[1:], params = params)
modelCNN = TBDCNet_modelCNN(inputShape = X_trainShape[1:], outputShape = y_trainShape[1:], params = params)

modelCNNname = 'CNNModel1'

# %%
#####################################################################
# Model training
#####################################################################

# Known issue: sometimes throws error related to the shape of the labels...
# Fit model to Failure index
epochs = 80
modelCNN_history = modelCNN.fit(train_ds,
                                epochs=epochs,
                                steps_per_epoch=steps_per_epoch,
                                validation_data=val_ds,
                                validation_steps = validation_steps,
                                callbacks=[early_stopping_monitor, cp_callback]
                                )
# Out:
# Epoch 1/80
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[144], line 9
#       1 #%%
#       2 #####################################################################
#       3 # Model training
#    (...)
#       6 # Known issue: sometimes throws error related to the shape of the labels...
#       7 # Fit model to Failure index
#       8 epochs = 80
# ----> 9 modelCNN_history = modelCNN.fit(train_ds,
#      10                                 epochs=epochs,
#      11                                 steps_per_epoch=steps_per_epoch,
#      12                                 validation_data=val_ds,
#      13                                 validation_steps = validation_steps,
#      14                                 callbacks=[early_stopping_monitor, cp_callback]
#      15                                 )
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# Cell In[141], line 226, in TBDCNet_modelCNN.<locals>.SSIM_metric(y_true, y_pred)
#     222   def SSIM_metric(y_true, y_pred):
#     223       return 1 - tf.reduce_mean(tf.image.ssim(
#     224     img1 = y_true,
#     225     img2 = y_pred,
# --> 226     max_val = np.max(y_true)-np.min(y_true),
#     227     filter_size=winKernel,
#     228     filter_sigma=1.5,
#     229     k1=0.01,
#     230     k2=0.03,
#     231     return_index_map=False
#     232 ))
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:2899, in max(a, axis, out, keepdims, initial, where)
#    2781 @array_function_dispatch(_max_dispatcher)
#    2782 @set_module('numpy')
#    2783 def max(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2784          where=np._NoValue):
#    2785     """
#    2786     Return the maximum of an array or maximum along an axis.
#    2787
#    (...)
#    2897     5
#    2898     """
# -> 2899     return _wrapreduction(a, np.maximum, 'max', axis, None, out,
#    2900                           keepdims=keepdims, initial=initial, where=where)
#
# File c:\Users\kfh23\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# NotImplementedError: Cannot convert a symbolic tf.Tensor (data_1:0) to a numpy array. This error may indicate that you're trying to pass a Tensor to a NumPy call, which is not supported.

# %%
def SSIM_metric(y_true, y_pred):
      return 1 - tf.reduce_mean(tf.image.ssim(
    img1 = y_true,
    img2 = y_pred,
    max_val = np.max(y_true)-np.min(y_true),
    filter_size=winKernel,
    filter_sigma=1.5,
    k1=0.01,
    k2=0.03,
    return_index_map=False
  ))

# %%
SSIM_metric(y_true = predCNN, y_pred = predCNN)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.0>
